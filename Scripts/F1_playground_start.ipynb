# %%
# Data transformation for Static Model
# Initial Tests with code

# %%
import jupyterthemes as jt
from jupyterthemes import get_themes
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme("monokai")
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #cdd2e9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #a2b0c7;
#  background-color: #1a2028;
#  background: #1a2028;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1a2028;
#  background: #1a2028;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #a2b0c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #dbe1ea;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #dbe1ea;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #a2b0c7;
#  padding: 8px 8px;
#  background: #252b35;
#  background-color: #252b35;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #a2b0c7;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #a2b0c7;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #2d3846;
#  background-color: #2d3846;
#  padding: 2px;
#  border-bottom: 2px solid rgba(75,95,118,.30);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #2d3846;
#  background-color: #2d3846;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #0b98c8;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #4c8be2;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #009cd1;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #4c8be2;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #48a667 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #92a2bd !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #546386;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #a2b0c7;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid #252e3a;
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #009cd1;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #009cd1;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #fefefe;
#  background-color: #a2b0c7;
#  background: #a2b0c7;
#  border-color: #a2b0c7;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1a2028;
#  background-color: #1a2028;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(75,95,118,.30);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #4c8be2;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: #252e3a !important;
#  background: #252e3a !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #dbe1ea;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(75,95,118,.10);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #a2b0c7;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-serif;
#  font-size: 13.5p

# %%
import pandas as pd 
from pandas import DataFrame as df 
import numpy as np
import os 

import fastf1 as f1 
from pyergast import pyergast

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 40)

# %% [markdown]
# # Load the data

# %%
results = pd.read_csv(os.path.join(os.getcwd(),"data/results.csv"))
races = pd.read_csv(os.path.join(os.getcwd(),"data/races.csv"))
quali = pd.read_csv(os.path.join(os.getcwd(),"data/qualifying.csv"))
drivers = pd.read_csv(os.path.join(os.getcwd(),"data/drivers.csv"))
constructors = pd.read_csv(os.path.join(os.getcwd(),"data/constructors.csv"))
circuit = pd.read_csv(os.path.join(os.getcwd(),"data/circuits.csv"))

# %%
df1 = pd.merge(races,results,how='inner',on=['raceId'])
df2 = pd.merge(df1,quali,how='inner',on=['raceId','driverId','constructorId'])
df3 = pd.merge(df2,drivers,how='inner',on=['driverId'])
df4 = pd.merge(df3,constructors,how='inner',on=['constructorId'])
df5 = pd.merge(df4,circuit,how='inner',on=['circuitId'])

# %%
active_constructors = ['Renault', 'Williams', 'McLaren', 'Ferrari', 'Mercedes',
                       'AlphaTauri', 'Racing Point', 'Alfa Romeo', 'Red Bull',
                       'Haas F1 Team']

active_drivers = ['Daniel Ricciardo', 'Kevin Magnussen', 'Carlos Sainz',
                  'Valtteri Bottas', 'Lance Stroll', 'George Russell',
                  'Lando Norris', 'Sebastian Vettel', 'Kimi Räikkönen',
                  'Charles Leclerc', 'Lewis Hamilton', 'Daniil Kvyat',
                  'Max Verstappen', 'Pierre Gasly', 'Alexander Albon',
                  'Sergio Pérez', 'Esteban Ocon', 'Antonio Giovinazzi',
                  'Romain Grosjean','Nicholas Latifi']

# %%
data = df5

# %% [markdown]
# # Data for Static model

# %%
# Only data from 2010 onwards
data_static = df5[df5["year"] >= 2009].sort_values(by=["year","round"],ascending=True)

# Rename
data_static.rename(columns={'name_x':'GP name',
                            'name_y':'constructor',
                            'position_y':'quali_position',
                           'grid':'starting_grid_position',
                           'positionOrder':'end_position'},inplace=True)

# Create age at gp column
data_static['date'] = pd.to_datetime(data_static['date'])
data_static['dob'] = pd.to_datetime(data_static['dob'])
data_static['age_at_gp_in_days'] = abs(data_static['dob']-data_static['date'])
data_static['age_at_gp_in_days'] = data_static['age_at_gp_in_days'].apply(lambda x: str(x).split(' ')[0])

# Create driver column
data_static['driver'] = data_static['forename']+' '+data_static['surname']

# Create active driver column
data_static["active_driver"] = data_static['driver'].apply(lambda x: int(x in active_drivers))
data_static["active_constructor"] = data_static['constructor'].apply(lambda x: int(x in active_constructors))

# %%
#Some of the constructors changed their name over the year so replacing old names with current name
data_static['constructor'] = data_static['constructor'].apply(lambda x: 'Racing Point' if x=='Force India' else x)
data_static['constructor'] = data_static['constructor'].apply(lambda x: 'Alfa Romeo' if x=='Sauber' else x)
data_static['constructor'] = data_static['constructor'].apply(lambda x: 'Renault' if x=='Lotus F1' else x)
data_static['constructor'] = data_static['constructor'].apply(lambda x: 'AlphaTauri' if x=='Toro Rosso' else x)

# %%
# might need some tweaking; http://ergast.com/api/f1/status?limit=30 
not_dnf = [1,11,12]

def get_dnf(row):
    # if the statusId is has a number different than 1, 11 or 12 than the driver dnf    
    if row["statusId"] in not_dnf:
        return 0
    return 1
    
data_static["dnf"] = data_static.apply(get_dnf,axis=1)

# %%
data_static["start_and_end_position_diff"] = data_static["starting_grid_position"] - data_static["end_position"]

def get_the_average(row):
    mean = data_static[(data_static["driver"]==row["driver"])&
                      (data_static["GP name"]==row["GP name"])].mean()["start_and_end_position_diff"]
    return mean
data_static["average_position_change_for_this_driver"] = data_static.apply(get_the_average,axis=1)
# Out:
# <ipython-input-31-af85ed5dda8b>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean = data_static[(data_static["driver"]==row["driver"])&

# %%
def find_position_prev_gp(row):
    if (row["year"] == 2009):
        return 0
    
    same_gp_diff_year = data_static[(data_static["driver"]==row["driver"]) & 
                                    (data_static["GP name"]==row["GP name"]) &
                                    (data_static["year"]<row["year"])
                                   ]
    prev_gp = same_gp_diff_year["year"].max()
    try:
        prev_position = same_gp_diff_year[same_gp_diff_year["year"]==prev_gp]["end_position"].iloc[0]
    except: 
        return 0
        
    return prev_position

data_static["previous_finish_position_at_this_gp"] = data_static.apply(find_position_prev_gp, axis=1)

# %%
def get_last_round(year,data):
    season = data[data["year"]==year]
    last_round = season["round"].max()
    return last_round

def find_position(row):
    # return position from final race from previous race 
    if row["year"] == 2009:
        return 0
    
    if row["round"] == 1:
        
        prev_year = data_static[(data_static["year"] == (row["year"] - 1)) & (data_static["driver"] == row["driver"])]
        prev_season_last_round=get_last_round(row["year"],data_static)
        try:
            return prev_year[prev_year["round"]==prev_season_last_round]["positionOrder"].iloc[0]
        except:
            return 0
            
    try:
        specific_driver = data_static[(data_static["year"] == row["year"])&(data_static["driver"]==row["driver"])]
        prev_round = specific_driver[specific_driver["round"] == row["round"]-1]["round"].iloc[0]
        return specific_driver[specific_driver["round"]==prev_round]["positionOrder"].iloc[0]
    except:
        return 0
    
data_static["position_at_previous_race"] = data_static.apply(find_position,axis=1)

# %%
data_static = data_static[data_static["active_driver"]==1]
data_static = data_static[data_static["active_constructor"]==1]
data_static = data_static[data_static["year"] >= 2010].sort_values(by=["year","round"],ascending=True)

# %%
target = data_static["end_position"]
data_static_final = data_static[["year",
                           "GP name",
                           "round",
                           "driver",
                           "constructor",
                           "age_at_gp_in_days",
                            "quali_position",
                           "starting_grid_position",
                           "position_at_previous_race",
                           "previous_finish_position_at_this_gp",
                           "dnf",
                           "average_position_change_for_this_driver"
                          ]]

# %%
data_static_final.to_csv("features.csv",index=False)
target.to_csv("target.csv",index=False)

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder

le = LabelEncoder()

# data_static["GP name"] = le.fit_transform(data_static["GP name"])
classes = le.fit(data_static["driver"])
# data_static["constructor"] = le.fit_transform(data_static["constructor"])
# data_static["position_at_previous_race"] = le.fit_transform(data_static["position_at_previous_race"])
# data_static["previous_finish_position_at_this_gp"] = le.fit_transform(data_static["previous_finish_position_at_this_gp"])

# %%
transformed2 = le.fit_transform(data_static["GP name"])
transformed = le.fit_transform(data_static["driver"])


le.classes_
# Out:
# array(['Alexander Albon', 'Antonio Giovinazzi', 'Carlos Sainz',
#        'Charles Leclerc', 'Daniel Ricciardo', 'Daniil Kvyat',
#        'Esteban Ocon', 'George Russell', 'Kevin Magnussen',
#        'Kimi Räikkönen', 'Lance Stroll', 'Lando Norris', 'Lewis Hamilton',
#        'Max Verstappen', 'Nicholas Latifi', 'Pierre Gasly',
#        'Romain Grosjean', 'Sebastian Vettel', 'Sergio Pérez',
#        'Valtteri Bottas'], dtype=object)

# %%
inverse = le.inverse_transform(transformed)

# %%
inverse
transformed
# Out:
# array([12, 17, 12, ..., 10,  5, 15])

# %% [markdown]
# # Dynamic model

# %%
# Load first race of 2021
race = f1.get_session(2018,"Bahrain","R")
# Out:
# C:\Users\Michauu\anaconda3\lib\site-packages\fastf1\ergast.py:49: UserWarning: Request returned: 403
#   warnings.warn(f"Request returned: {r.status_code}")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f95b24ccb088> in <module>
#       1 # Load first race of 2021
# ----> 2 race = f1.get_session(2018,"Bahrain","R")
#
# ~\anaconda3\lib\site-packages\fastf1\core.py in get_session(year, gp, event)
#     156
#     157     if type(gp) is str:
# --> 158         gp = get_round(year, gp)
#     159     weekend = Weekend(year, gp)
#     160     if event == 'R':
#
# ~\anaconda3\lib\site-packages\fastf1\core.py in get_round(year, match)
#     197                 + f"{l['country']}")
#     198
# --> 199     races = ergast.fetch_season(year)
#     200     to_match = [build_string(block) for block in races]
#     201     ratios = np.array([fuzz.partial_ratio(match.casefold(), ref.casefold())
#
# ~\anaconda3\lib\site-packages\fastf1\ergast.py in fetch_season(year)
#      20 def fetch_season(year):
#      21     url = f"{base_url}/{year}.json"
# ---> 22     return _parse_ergast(_parse_json_response(requests.get(url, headers=_headers)))
#      23
#      24
#
# ~\anaconda3\lib\site-packages\fastf1\ergast.py in _parse_ergast(data)
#      52
#      53 def _parse_ergast(data):
# ---> 54     return data['MRData']['RaceTable']['Races']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Get info on each lap with telemetry data - USE CACHE DATA
laps = race.load_laps(with_telemetry=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-44e08e477f6a> in <module>
#       1 # Get info on each lap with telemetry data - USE CACHE DATA
# ----> 2 laps = race.load_laps(with_telemetry=True)
#
# NameError: name 'race' is not defined

# %%
laps
# Out:
#                        Time DriverNumber                LapTime  LapNumber  \
# 0    0 days 00:34:16.815000           16                    NaT        0.0
# 1    0 days 00:34:16.815000           33                    NaT        1.0
# 2    0 days 00:35:34.295000           33 0 days 00:01:17.480000        2.0
# 3    0 days 00:36:51.593000           33 0 days 00:01:17.298000        3.0
# 4    0 days 00:38:08.830000           33 0 days 00:01:17.237000        4.0
# ...                     ...          ...                    ...        ...
# 1415 0 days 02:07:22.450000           47 0 days 00:01:16.778000       71.0
# 1416 0 days 02:08:39.287000           47 0 days 00:01:16.837000       72.0
# 1417 0 days 02:09:56.351000           47 0 days 00:01:17.064000       73.0
# 1418 0 days 02:11:13.513000           47 0 days 00:01:17.162000       74.0
# 1419 0 days 02:12:31.146000           47 0 days 00:01:17.633000       75.0
#
#       Stint             PitOutTime PitInTime            Sector1Time  \
# 0       1.0                    NaT       NaT                    NaT
# 1       1.0 0 days 00:00:04.827000       NaT                    NaT
# 2       1.0                    NaT       NaT 0 days 00:00:20.615000
# 3       1.0                    NaT       NaT 0 days 00:00:20.460000
# 4       1.0                    NaT       NaT 0 days 00:00:20.609000
# ...     ...                    ...       ...                    ...
# 1415    2.0                    NaT       NaT 0 days 00:00:20.242000
# 1416    2.0                    NaT       NaT 0 days 00:00:20.377000
# 1417    2.0                    NaT       NaT 0 days 00:00:20.331000
# 1418    2.0                    NaT       NaT 0 days 00:00:20.341000
# 1419    2.0                    NaT       NaT 0 days 00:00:20.482000
#
#                 Sector2Time            Sector3Time     Sector1SessionTime  \
# 0                       NaT                    NaT                    NaT
# 1    0 days 00:00:36.535000 0 days 00:00:20.724000                    NaT
# 2    0 days 00:00:36.346000 0 days 00:00:20.519000 0 days 00:34:37.430000
# 3    0 days 00:00:36.305000 0 days 00:00:20.533000 0 days 00:35:54.755000
# 4    0 days 00:00:36.124000 0 days 00:00:20.504000 0 days 00:37:12.202000
# ...                     ...                    ...                    ...
# 1415 0 days 00:00:35.893000 0 days 00:00:20.643000 0 days 02:06:25.914000
# 1416 0 days 00:00:35.874000 0 days 00:00:20.586000 0 days 02:07:42.827000
# 1417 0 days 00:00:36.037000 0 days 00:00:20.696000 0 days 02:08:59.618000
# 1418 0 days 00:00:36.049000 0 days 00:00:20.772000 0 days 02:10:16.692000
# 1419 0 days 00:00:36.137000 0 days 00:00:21.014000 0 days 02:11:33.995000
#
#          Sector2SessionTime     Sector3SessionTime  SpeedI1  SpeedI2  SpeedFL  \
# 0                       NaT                    NaT      NaN      NaN      NaN
# 1    0 days 00:33:56.247000 0 days 00:34:17.009000    192.0    187.0    250.0
# 2    0 days 00:35:13.776000 0 days 00:35:34.295000    193.0    191.0    250.0
# 3    0 days 00:36:31.060000 0 days 00:36:51.593000    199.0    191.0    251.0
# 4    0 days 00:37:48.326000 0 days 00:38:08.830000      NaN    192.0    251.0
# ...                     ...                    ...      ...      ...      ...
# 1415 0 days 02:07:01.807000 0 days 02:07:22.450000    198.0    196.0    258.0
# 1416 0 days 02:08:18.701000 0 days 02:08:39.287000    194.0    192.0    259.0
# 1417 0 days 02:09:35.655000 0 days 02:09:56.351000    192.0    196.0    258.0
# 1418 0 days 02:10:52.741000 0 days 02:11:13.513000    195.0    194.0    259.0
# 1419 0 days 02:12:10.132000 0 days 02:12:31.146000      NaN    191.0    259.0
#
#       SpeedST Compound  TyreLife FreshTyre           LapStartTime  \
# 0         NaN     SOFT       5.0     False 0 days 00:32:54.677000
# 1       258.0     SOFT       6.0     False 0 days 00:32:54.677000
# 2       259.0     SOFT       7.0     False 0 days 00:34:16.815000
# 3       258.0     SOFT       8.0     False 0 days 00:35:34.295000
# 4       260.0     SOFT       9.0     False 0 days 00:36:51.593000
# ...       ...      ...       ...       ...                    ...
# 1415    281.0     HARD      34.0      True 0 days 02:06:05.672000
# 1416    281.0     HARD      35.0      True 0 days 02:07:22.450000
# 1417    281.0     HARD      36.0      True 0 days 02:08:39.287000
# 1418    280.0     HARD      37.0      True 0 days 02:09:56.351000
# 1419    280.0     HARD      38.0      True 0 days 02:11:13.513000
#
#               Team Driver TrackStatus IsAccurate            LapStartDate
# 0          Ferrari    LEC           1      False 2021-05-23 13:02:55.440
# 1         Red Bull    VER           1      False 2021-05-23 13:02:55.440
# 2         Red Bull    VER           1       True 2021-05-23 13:04:17.578
# 3         Red Bull    VER           1       True 2021-05-23 13:05:35.058
# 4         Red Bull    VER           1       True 2021-05-23 13:06:52.356
# ...            ...    ...         ...        ...                     ...
# 1415  Haas F1 Team    MSC           1       True 2021-05-23 14:36:06.435
# 1416  Haas F1 Team    MSC           1       True 2021-05-23 14:37:23.213
# 1417  Haas F1 Team    MSC           1       True 2021-05-23 14:38:40.050
# 1418  Haas F1 Team    MSC           1       True 2021-05-23 14:39:57.114
# 1419  Haas F1 Team    MSC           1       True 2021-05-23 14:41:14.276
#
# [1420 rows x 26 columns]

# %%
# Save only the columns that we need - rename driverNumber for convenience sake
laps_info = laps[["LapNumber","Driver","Compound","DriverNumber"]]
laps_info = laps_info.rename(columns={"DriverNumber":"number"})

# %%
# Check what races are there 
GP_name_list = pyergast.get_schedule(2021)["raceName"]

# %%
# Get info on quali and grid position
quali_info = pyergast.get_qualifying_result(2021,5)[["number","position"]]
grid_info = pyergast.get_race_result(2021,5)[["number","grid"]]

# %%
quali_info
# Out:
#    number position
# 0      16        1
# 1      33        2
# 2      77        3
# 3      55        4
# 4       4        5
# 5      10        6
# 6      44        7
# 7       5        8
# 8      11        9
# 9      99       10
# 10     31       11
# 11      3       12
# 12     18       13
# 13      7       14
# 14     63       15
# 15     22       16
# 16     14       17
# 17      6       18
# 18      9       19

# %%
# you can automate the process with loops here - but it might require some more work 
round_number = 4

# Create two columns: GP_name and round that are just equal to one value - name of GP and round number 
laps_info["GP_name"] = GP_name_list.iloc[round_number]
laps_info["round"] = round_number + 1
laps_info
# Out:
#       LapNumber Driver Compound number            GP_name  round
# 0           0.0    LEC     SOFT     16  Monaco Grand Prix      5
# 1           1.0    VER     SOFT     33  Monaco Grand Prix      5
# 2           2.0    VER     SOFT     33  Monaco Grand Prix      5
# 3           3.0    VER     SOFT     33  Monaco Grand Prix      5
# 4           4.0    VER     SOFT     33  Monaco Grand Prix      5
# 5           5.0    VER     SOFT     33  Monaco Grand Prix      5
# 6           6.0    VER     SOFT     33  Monaco Grand Prix      5
# 7           7.0    VER     SOFT     33  Monaco Grand Prix      5
# 8           8.0    VER     SOFT     33  Monaco Grand Prix      5
# 9           9.0    VER     SOFT     33  Monaco Grand Prix      5
# 10         10.0    VER     SOFT     33  Monaco Grand Prix      5
# 11         11.0    VER     SOFT     33  Monaco Grand Prix      5
# 12         12.0    VER     SOFT     33  Monaco Grand Prix      5
# 13         13.0    VER     SOFT     33  Monaco Grand Prix      5
# 14         14.0    VER     SOFT     33  Monaco Grand Prix      5
# 15         15.0    VER     SOFT     33  Monaco Grand Prix      5
# 16         16.0    VER     SOFT     33  Monaco Grand Prix      5
# 17         17.0    VER     SOFT     33  Monaco Grand Prix      5
# 18         18.0    VER     SOFT     33  Monaco Grand Prix      5
# 19         19.0    VER     SOFT     33  Monaco Grand Prix      5
# 20         20.0    VER     SOFT     33  Monaco Grand Prix      5
# 21         21.0    VER     SOFT     33  Monaco Grand Prix      5
# 22         22.0    VER     SOFT     33  Monaco Grand Prix      5
# 23         23.0    VER     SOFT     33  Monaco Grand Prix      5
# 24         24.0    VER     SOFT     33  Monaco Grand Prix      5
# 25         25.0    VER     SOFT     33  Monaco Grand Prix      5
# 26         26.0    VER     SOFT     33  Monaco Grand Prix      5
# 27         27.0    VER     SOFT     33  Monaco Grand Prix      5
# 28         28.0    VER     SOFT     33  Monaco Grand Prix      5
# 29         29.0    VER     SOFT     33  Monaco Grand Prix      5
# 30         30.0    VER     SOFT     33  Monaco Grand Prix      5
# 31         31.0    VER     SOFT     33  Monaco Grand Prix      5
# 32         32.0    VER     SOFT     33  Monaco Grand Prix      5
# 33         33.0    VER     SOFT     33  Monaco Grand Prix      5
# 34         34.0    VER     SOFT     33  Monaco Grand Prix      5
# 35         35.0    VER     HARD     33  Monaco Grand Prix      5
# 36         36.0    VER     HARD     33  Monaco Grand Prix      5
# 37         37.0    VER     HARD     33  Monaco Grand Prix      5
# 38         38.0    VER     HARD     33  Monaco Grand Prix      5
# 39         39.0    VER     HARD     33  Monaco Grand Prix      5
# 40         40.0    VER     HARD     33  Monaco Grand Prix      5
# 41         41.0    VER     HARD     33  Monaco Grand Prix      5
# 42         42.0    VER     HARD     33  Monaco Grand Prix      5
# 43         43.0    VER     HARD     33  Monaco Grand Prix      5
# 44         44.0    VER     HARD     33  Monaco Grand Prix      5
# 45         45.0    VER     HARD     33  Monaco Grand Prix      5
# 46         46.0    VER     HARD     33  Monaco Grand Prix      5
# 47         47.0    VER     HARD     33  Monaco Grand Prix      5
# 48         48.0    VER     HARD     33  Monaco Grand Prix      5
# 49         49.0    VER     HARD     33  Monaco Grand Prix      5
# 50         50.0    VER     HARD     33  Monaco Grand Prix      5
# 51         51.0    VER     HARD     33  Monaco Grand Prix      5
# 52         52.0    VER     HARD     33  Monaco Grand Prix      5
# 53         53.0    VER     HARD     33  Monaco Grand Prix      5
# 54         54.0    VER     HARD     33  Monaco Grand Prix      5
# 55         55.0    VER     HARD     33  Monaco Grand Prix      5
# 56         56.0    VER     HARD     33  Monaco Grand Prix      5
# 57         57.0    VER     HARD     33  Monaco Grand Prix      5
# 58         58.0    VER     HARD     33  Monaco Grand Prix      5
# 59         59.0    VER     HARD     33  Monaco Grand Prix      5
# 60         60.0    VER     HARD     33  Monaco Grand Prix      5
# 61         61.0    VER     HARD     33  Monaco Grand Prix      5
# 62         62.0    VER     HARD     33  Monaco Grand Prix      5
# 63         63.0    VER     HARD     33  Monaco Grand Prix      5
# 64         64.0    VER     HARD     33  Monaco Grand Prix      5
# 65         65.0    VER     HARD     33  Monaco Grand Prix      5
# 66         66.0    VER     HARD     33  Monaco Grand Prix      5
# 67         67.0    VER     HARD     33  Monaco Grand Prix      5
# 68         68.0    VER     HARD     33  Monaco Grand Prix      5
# 69         69.0    VER     HARD     33  Monaco Grand Prix      5
# 70         70.0    VER     HARD     33  Monaco Grand Prix      5
# 71         71.0    VER     HARD     33  Monaco Grand Prix      5
# 72         72.0    VER     HARD     33  Monaco Grand Prix      5
# 73         73.0    VER     HARD     33  Monaco Grand Prix      5
# 74         74.0    VER     HARD     33  Monaco Grand Prix      5
# 75         75.0    VER     HARD     33  Monaco Grand Prix      5
# 76         76.0    VER     HARD     33  Monaco Grand Prix      5
# 77         77.0    VER     HARD     33  Monaco Grand Prix      5
# 78         78.0    VER     HARD     33  Monaco Grand Prix      5
# 79          1.0    BOT     SOFT     77  Monaco Grand Prix      5
# 80          2.0    BOT     SOFT     77  Monaco Grand Prix      5
# 81          3.0    BOT     SOFT     77  Monaco Grand Prix      5
# 82          4.0    BOT     SOFT     77  Monaco Grand Prix      5
# 83          5.0    BOT     SOFT     77  Monaco Grand Prix      5
# 84          6.0    BOT     SOFT     77  Monaco Grand Prix      5
# 85          7.0    BOT     SOFT     77  Monaco Grand Prix      5
# 86          8.0    BOT     SOFT     77  Monaco Grand Prix      5
# 87          9.0    BOT     SOFT     77  Monaco Grand Prix      5
# 88         10.0    BOT     SOFT     77  Monaco Grand Prix      5
# 89         11.0    BOT     SOFT     77  Monaco Grand Prix      5
# 90         12.0    BOT     SOFT     77  Monaco Grand Prix      5
# 91         13.0    BOT     SOFT     77  Monaco Grand Prix      5
# 92         14.0    BOT     SOFT     77  Monaco Grand Prix      5
# 93         15.0    BOT     SOFT     77  Monaco Grand Prix      5
# 94         16.0    BOT     SOFT     77  Monaco Grand Prix      5
# 95         17.0    BOT     SOFT     77  Monaco Grand Prix      5
# 96         18.0    BOT     SOFT     77  Monaco Grand Prix      5
# 97         19.0    BOT     SOFT     77  Monaco Grand Prix      5
# 98         20.0    BOT     SOFT     77  Monaco Grand Prix      5
# 99         21.0    BOT     SOFT     77  Monaco Grand Prix      5
# 100        22.0    BOT     SOFT     77  Monaco Grand Prix      5
# 101        23.0    BOT     SOFT     77  Monaco Grand Prix      5
# 102        24.0    BOT     SOFT     77  Monaco Grand Prix      5
# 103        25.0    BOT     SOFT     77  Monaco Grand Prix      5
# 104        26.0    BOT     SOFT     77  Monaco Grand Prix      5
# 105        27.0    BOT     SOFT     77  Monaco Grand Prix      5
# 106        28.0    BOT     SOFT     77  Monaco Grand Prix      5
# 107        29.0    BOT     SOFT     77  Monaco Grand Prix      5
# 108        30.0    BOT     SOFT     77  Monaco Grand Prix      5
# 109         1.0    SAI     SOFT     55  Monaco Grand Prix      5
# 110         2.0    SAI     SOFT     55  Monaco Grand Prix      5
# 111         3.0    SAI     SOFT     55  Monaco Grand Prix      5
# 112         4.0    SAI     SOFT     55  Monaco Grand Prix      5
# 113         5.0    SAI     SOFT     55  Monaco Grand Prix      5
# 114         6.0    SAI     SOFT     55  Monaco Grand Prix      5
# 115         7.0    SAI     SOFT     55  Monaco Grand Prix      5
# 116         8.0    SAI     SOFT     55  Monaco Grand Prix      5
# 117         9.0    SAI     SOFT     55  Monaco Grand Prix      5
# 118        10.0    SAI     SOFT     55  Monaco Grand Prix      5
# 119        11.0    SAI     SOFT     55  Monaco Grand Prix      5
# 120        12.0    SAI     SOFT     55  Monaco Grand Prix      5
# 121        13.0    SAI     SOFT     55  Monaco Grand Prix      5
# 122        14.0    SAI     SOFT     55  Monaco Grand Prix      5
# 123        15.0    SAI     SOFT     55  Monaco Grand Prix      5
# 124        16.0    SAI     SOFT     55  Monaco Grand Prix      5
# 125        17.0    SAI     SOFT     55  Monaco Grand Prix      5
# 126        18.0    SAI     SOFT     55  Monaco Grand Prix      5
# 127        19.0    SAI     SOFT     55  Monaco Grand Prix      5
# 128        20.0    SAI     SOFT     55  Monaco Grand Prix      5
# 129        21.0    SAI     SOFT     55  Monaco Grand Prix      5
# 130        22.0    SAI     SOFT     55  Monaco Grand Prix      5
# 131        23.0    SAI     SOFT     55  Monaco Grand Prix      5
# 132        24.0    SAI     SOFT     55  Monaco Grand Prix      5
# 133        25.0    SAI     SOFT     55  Monaco Grand Prix      5
# 134        26.0    SAI     SOFT     55  Monaco Grand Prix      5
# 135        27.0    SAI     SOFT     55  Monaco Grand Prix      5
# 136        28.0    SAI     SOFT     55  Monaco Grand Prix      5
# 137        29.0    SAI     SOFT     55  Monaco Grand Prix      5
# 138        30.0    SAI     SOFT     55  Monaco Grand Prix      5
# 139        31.0    SAI     SOFT     55  Monaco Grand Prix      5
# 140        32.0    SAI     SOFT     55  Monaco Grand Prix      5
# 141        33.0    SAI     HARD     55  Monaco Grand Prix      5
# 142        34.0    SAI     HARD     55  Monaco Grand Prix      5
# 143        35.0    SAI     HARD     55  Monaco Grand Prix      5
# 144        36.0    SAI     HARD     55  Monaco Grand Prix      5
# 145        37.0    SAI     HARD     55  Monaco Grand Prix      5
# 146        38.0    SAI     HARD     55  Monaco Grand Prix      5
# 147        39.0    SAI     HARD     55  Monaco Grand Prix      5
# 148        40.0    SAI     HARD     55  Monaco Grand Prix      5
# 149        41.0    SAI     HARD     55  Monaco Grand Prix      5
# 150        42.0    SAI     HARD     55  Monaco Grand Prix      5
# 151        43.0    SAI     HARD     55  Monaco Grand Prix      5
# 152        44.0    SAI     HARD     55  Monaco Grand Prix      5
# 153        45.0    SAI     HARD     55  Monaco Grand Prix      5
# 154        46.0    SAI     HARD     55  Monaco Grand Prix      5
# 155        47.0    SAI     HARD     55  Monaco Grand Prix      5
# 156        48.0    SAI     HARD     55  Monaco Grand Prix      5
# 157        49.0    SAI     HARD     55  Monaco Grand Prix      5
# 158        50.0    SAI     HARD     55  Monaco Grand Prix      5
# 159        51.0    SAI     HARD     55  Monaco Grand Prix      5
# 160        52.0    SAI     HARD     55  Monaco Grand Prix      5
# 161        53.0    SAI     HARD     55  Monaco Grand Prix      5
# 162        54.0    SAI     HARD     55  Monaco Grand Prix      5
# 163        55.0    SAI     HARD     55  Monaco Grand Prix      5
# 164        56.0    SAI     HARD     55  Monaco Grand Prix      5
# 165        57.0    SAI     HARD     55  Monaco Grand Prix      5
# 166        58.0    SAI     HARD     55  Monaco Grand Prix      5
# 167        59.0    SAI     HARD     55  Monaco Grand Prix      5
# 168        60.0    SAI     HARD     55  Monaco Grand Prix      5
# 169        61.0    SAI     HARD     55  Monaco Grand Prix      5
# 170        62.0    SAI     HARD     55  Monaco Grand Prix      5
# 171        63.0    SAI     HARD     55  Monaco Grand Prix      5
# 172        64.0    SAI     HARD     55  Monaco Grand Prix      5
# 173        65.0    SAI     HARD     55  Monaco Grand Prix      5
# 174        66.0    SAI     HARD     55  Monaco Grand Prix      5
# 175        67.0    SAI     HARD     55  Monaco Grand Prix      5
# 176        68.0    SAI     HARD     55  Monaco Grand Prix      5
# 177        69.0    SAI     HARD     55  Monaco Grand Prix      5
# 178        70.0    SAI     HARD     55  Monaco Grand Prix      5
# 179        71.0    SAI     HARD     55  Monaco Grand Prix      5
# 180        72.0    SAI     HARD     55  Monaco Grand Prix      5
# 181        73.0    SAI     HARD     55  Monaco Grand Prix      5
# 182        74.0    SAI     HARD     55  Monaco Grand Prix      5
# 183        75.0    SAI     HARD     55  Monaco Grand Prix      5
# 184        76.0    SAI     HARD     55  Monaco Grand Prix      5
# 185        77.0    SAI     HARD     55  Monaco Grand Prix      5
# 186        78.0    SAI     HARD     55  Monaco Grand Prix      5
# 187         1.0    NOR     SOFT      4  Monaco Grand Prix      5
# 188         2.0    NOR     SOFT      4  Monaco Grand Prix      5
# 189         3.0    NOR     SOFT      4  Monaco Grand Prix      5
# 190         4.0    NOR     SOFT      4  Monaco Grand Prix      5
# 191         5.0    NOR     SOFT      4  Monaco Grand Prix      5
# 192         6.0    NOR     SOFT      4  Monaco Grand Prix      5
# 193         7.0    NOR     SOFT      4  Monaco Grand Prix      5
# 194         8.0    NOR     SOFT      4  Monaco Grand Prix      5
# 195         9.0    NOR     SOFT      4  Monaco Grand Prix      5
# 196        10.0    NOR     SOFT      4  Monaco Grand Prix      5
# 197        11.0    NOR     SOFT      4  Monaco Grand Prix      5
# 198        12.0    NOR     SOFT      4  Monaco Grand Prix      5
# 199        13.0    NOR     SOFT      4  Monaco Grand Prix      5
# 200        14.0    NOR     SOFT      4  Monaco Grand Prix      5
# 201        15.0    NOR     SOFT      4  Monaco Grand Prix      5
# 202        16.0    NOR     SOFT      4  Monaco Grand Prix      5
# 203        17.0    NOR     SOFT      4  Monaco Grand Prix      5
# 204        18.0    NOR     SOFT      4  Monaco Grand Prix      5
# 205        19.0    NOR     SOFT      4  Monaco Grand Prix      5
# 206        20.0    NOR     SOFT      4  Monaco Grand Prix      5
# 207        21.0    NOR     SOFT      4  Monaco Grand Prix      5
# 208        22.0    NOR     SOFT      4  Monaco Grand Prix      5
# 209        23.0    NOR     SOFT      4  Monaco Grand Prix      5
# 210        24.0    NOR     SOFT      4  Monaco Grand Prix      5
# 211        25.0    NOR     SOFT      4  Monaco Grand Prix      5
# 212        26.0    NOR     SOFT      4  Monaco Grand Prix      5
# 213        27.0    NOR     SOFT      4  Monaco Grand Prix      5
# 214        28.0    NOR     SOFT      4  Monaco Grand Prix      5
# 215        29.0    NOR     SOFT      4  Monaco Grand Prix      5
# 216        30.0    NOR     SOFT      4  Monaco Grand Prix      5
# 217        31.0    NOR     HARD      4  Monaco Grand Prix      5
# 218        32.0    NOR     HARD      4  Monaco Grand Prix      5
# 219        33.0    NOR     HARD      4  Monaco Grand Prix      5
# 220        34.0    NOR     HARD      4  Monaco Grand Prix      5
# 221        35.0    NOR     HARD      4  Monaco Grand Prix      5
# 222        36.0    NOR     HARD      4  Monaco Grand Prix      5
# 223        37.0    NOR     HARD      4  Monaco Grand Prix      5
# 224        38.0    NOR     HARD      4  Monaco Grand Prix      5
# 225        39.0    NOR     HARD      4  Monaco Grand Prix      5
# 226        40.0    NOR     HARD      4  Monaco Grand Prix      5
# 227        41.0    NOR     HARD      4  Monaco Grand Prix      5
# 228        42.0    NOR     HARD      4  Monaco Grand Prix      5
# 229        43.0    NOR     HARD      4  Monaco Grand Prix      5
# 230        44.0    NOR     HARD      4  Monaco Grand Prix      5
# 231        45.0    NOR     HARD      4  Monaco Grand Prix      5
# 232        46.0    NOR     HARD      4  Monaco Grand Prix      5
# 233        47.0    NOR     HARD      4  Monaco Grand Prix      5
# 234        48.0    NOR     HARD      4  Monaco Grand Prix      5
# 235        49.0    NOR     HARD      4  Monaco Grand Prix      5
# 236        50.0    NOR     HARD      4  Monaco Grand Prix      5
# 237        51.0    NOR     HARD      4  Monaco Grand Prix      5
# 238        52.0    NOR     HARD      4  Monaco Grand Prix      5
# 239        53.0    NOR     HARD      4  Monaco Grand Prix      5
# 240        54.0    NOR     HARD      4  Monaco Grand Prix      5
# 241        55.0    NOR     HARD      4  Monaco Grand Prix      5
# 242        56.0    NOR     HARD      4  Monaco Grand Prix      5
# 243        57.0    NOR     HARD      4  Monaco Grand Prix      5
# 244        58.0    NOR     HARD      4  Monaco Grand Prix      5
# 245        59.0    NOR     HARD      4  Monaco Grand Prix      5
# 246        60.0    NOR     HARD      4  Monaco Grand Prix      5
# 247        61.0    NOR     HARD      4  Monaco Grand Prix      5
# 248        62.0    NOR     HARD      4  Monaco Grand Prix      5
# 249        63.0    NOR     HARD      4  Monaco Grand Prix      5
# 250        64.0    NOR     HARD      4  Monaco Grand Prix      5
# 251        65.0    NOR     HARD      4  Monaco Grand Prix      5
# 252        66.0    NOR     HARD      4  Monaco Grand Prix      5
# 253        67.0    NOR     HARD      4  Monaco Grand Prix      5
# 254        68.0    NOR     HARD      4  Monaco Grand Prix      5
# 255        69.0    NOR     HARD      4  Monaco Grand Prix      5
# 256        70.0    NOR     HARD      4  Monaco Grand Prix      5
# 257        71.0    NOR     HARD      4  Monaco Grand Prix      5
# 258        72.0    NOR     HARD      4  Monaco Grand Prix      5
# 259        73.0    NOR     HARD      4  Monaco Grand Prix      5
# 260        74.0    NOR     HARD      4  Monaco Grand Prix      5
# 261        75.0    NOR     HARD      4  Monaco Grand Prix      5
# 262        76.0    NOR     HARD      4  Monaco Grand Prix      5
# 263        77.0    NOR     HARD      4  Monaco Grand Prix      5
# 264        78.0    NOR     HARD      4  Monaco Grand Prix      5
# 265         1.0    GAS     SOFT     10  Monaco Grand Prix      5
# 266         2.0    GAS     SOFT     10  Monaco Grand Prix      5
# 267         3.0    GAS     SOFT     10  Monaco Grand Prix      5
# 268         4.0    GAS     SOFT     10  Monaco Grand Prix      5
# 269         5.0    GAS     SOFT     10  Monaco Grand Prix      5
# 270         6.0    GAS     SOFT     10  Monaco Grand Prix      5
# 271         7.0    GAS     SOFT     10  Monaco Grand Prix      5
# 272         8.0    GAS     SOFT     10  Monaco Grand Prix      5
# 273         9.0    GAS     SOFT     10  Monaco Grand Prix      5
# 274        10.0    GAS     SOFT     10  Monaco Grand Prix      5
# 275        11.0    GAS     SOFT     10  Monaco Grand Prix      5
# 276        12.0    GAS     SOFT     10  Monaco Grand Prix      5
# 277        13.0    GAS     SOFT     10  Monaco Grand Prix      5
# 278        14.0    GAS     SOFT     10  Monaco Grand Prix      5
# 279        15.0    GAS     SOFT     10  Monaco Grand Prix      5
# 280        16.0    GAS     SOFT     10  Monaco Grand Prix      5
# 281        17.0    GAS     SOFT     10  Monaco Grand Prix      5
# 282        18.0    GAS     SOFT     10  Monaco Grand Prix      5
# 283        19.0    GAS     SOFT     10  Monaco Grand Prix      5
# 284        20.0    GAS     SOFT     10  Monaco Grand Prix      5
# 285        21.0    GAS     SOFT     10  Monaco Grand Prix      5
# 286        22.0    GAS     SOFT     10  Monaco Grand Prix      5
# 287        23.0    GAS     SOFT     10  Monaco Grand Prix      5
# 288        24.0    GAS     SOFT     10  Monaco Grand Prix      5
# 289        25.0    GAS     SOFT     10  Monaco Grand Prix      5
# 290        26.0    GAS     SOFT     10  Monaco Grand Prix      5
# 291        27.0    GAS     SOFT     10  Monaco Grand Prix      5
# 292        28.0    GAS     SOFT     10  Monaco Grand Prix      5
# 293        29.0    GAS     SOFT     10  Monaco Grand Prix      5
# 294        30.0    GAS     SOFT     10  Monaco Grand Prix      5
# 295        31.0    GAS     HARD     10  Monaco Grand Prix      5
# 296        32.0    GAS     HARD     10  Monaco Grand Prix      5
# 297        33.0    GAS     HARD     10  Monaco Grand Prix      5
# 298        34.0    GAS     HARD     10  Monaco Grand Prix      5
# 299        35.0    GAS     HARD     10  Monaco Grand Prix      5
# 300        36.0    GAS     HARD     10  Monaco Grand Prix      5
# 301        37.0    GAS     HARD     10  Monaco Grand Prix      5
# 302        38.0    GAS     HARD     10  Monaco Grand Prix      5
# 303        39.0    GAS     HARD     10  Monaco Grand Prix      5
# 304        40.0    GAS     HARD     10  Monaco Grand Prix      5
# 305        41.0    GAS     HARD     10  Monaco Grand Prix      5
# 306        42.0    GAS     HARD     10  Monaco Grand Prix      5
# 307        43.0    GAS     HARD     10  Monaco Grand Prix      5
# 308        44.0    GAS     HARD     10  Monaco Grand Prix      5
# 309        45.0    GAS     HARD     10  Monaco Grand Prix      5
# 310        46.0    GAS     HARD     10  Monaco Grand Prix      5
# 311        47.0    GAS     HARD     10  Monaco Grand Prix      5
# 312        48.0    GAS     HARD     10  Monaco Grand Prix      5
# 313        49.0    GAS     HARD     10  Monaco Grand Prix      5
# 314        50.0    GAS     HARD     10  Monaco Grand Prix      5
# 315        51.0    GAS     HARD     10  Monaco Grand Prix      5
# 316        52.0    GAS     HARD     10  Monaco Grand Prix      5
# 317        53.0    GAS     HARD     10  Monaco Grand Prix      5
# 318        54.0    GAS     HARD     10  Monaco Grand Prix      5
# 319        55.0    GAS     HARD     10  Monaco Grand Prix      5
# 320        56.0    GAS     HARD     10  Monaco Grand Prix      5
# 321        57.0    GAS     HARD     10  Monaco Grand Prix      5
# 322        58.0    GAS     HARD     10  Monaco Grand Prix      5
# 323        59.0    GAS     HARD     10  Monaco Grand Prix      5
# 324        60.0    GAS     HARD     10  Monaco Grand Prix      5
# 325        61.0    GAS     HARD     10  Monaco Grand Prix      5
# 326        62.0    GAS     HARD     10  Monaco Grand Prix      5
# 327        63.0    GAS     HARD     10  Monaco Grand Prix      5
# 328        64.0    GAS     HARD     10  Monaco Grand Prix      5
# 329        65.0    GAS     HARD     10  Monaco Grand Prix      5
# 330        66.0    GAS     HARD     10  Monaco Grand Prix      5
# 331        67.0    GAS     HARD     10  Monaco Grand Prix      5
# 332        68.0    GAS     HARD     10  Monaco Grand Prix      5
# 333        69.0    GAS     HARD     10  Monaco Grand Prix      5
# 334        70.0    GAS     HARD     10  Monaco Grand Prix      5
# 335        71.0    GAS     HARD     10  Monaco Grand Prix      5
# 336        72.0    GAS     HARD     10  Monaco Grand Prix      5
# 337        73.0    GAS     HARD     10  Monaco Grand Prix      5
# 338        74.0    GAS     HARD     10  Monaco Grand Prix      5
# 339        75.0    GAS     HARD     10  Monaco Grand Prix      5
# 340        76.0    GAS     HARD     10  Monaco Grand Prix      5
# 341        77.0    GAS     HARD     10  Monaco Grand Prix      5
# 342        78.0    GAS     HARD     10  Monaco Grand Prix      5
# 343         1.0    HAM     SOFT     44  Monaco Grand Prix      5
# 344         2.0    HAM     SOFT     44  Monaco Grand Prix      5
# 345         3.0    HAM     SOFT     44  Monaco Grand Prix      5
# 346         4.0    HAM     SOFT     44  Monaco Grand Prix      5
# 347         5.0    HAM     SOFT     44  Monaco Grand Prix      5
# 348         6.0    HAM     SOFT     44  Monaco Grand Prix      5
# 349         7.0    HAM     SOFT     44  Monaco Grand Prix      5
# 350         8.0    HAM     SOFT     44  Monaco Grand Prix      5
# 351         9.0    HAM     SOFT     44  Monaco Grand Prix      5
# 352        10.0    HAM     SOFT     44  Monaco Grand Prix      5
# 353        11.0    HAM     SOFT     44  Monaco Grand Prix      5
# 354        12.0    HAM     SOFT     44  Monaco Grand Prix      5
# 355        13.0    HAM     SOFT     44  Monaco Grand Prix      5
# 356        14.0    HAM     SOFT     44  Monaco Grand Prix      5
# 357        15.0    HAM     SOFT     44  Monaco Grand Prix      5
# 358        16.0    HAM     SOFT     44  Monaco Grand Prix      5
# 359        17.0    HAM     SOFT     44  Monaco Grand Prix      5
# 360        18.0    HAM     SOFT     44  Monaco Grand Prix      5
# 361        19.0    HAM     SOFT     44  Monaco Grand Prix      5
# 362        20.0    HAM     SOFT     44  Monaco Grand Prix      5
# 363        21.0    HAM     SOFT     44  Monaco Grand Prix      5
# 364        22.0    HAM     SOFT     44  Monaco Grand Prix      5
# 365        23.0    HAM     SOFT     44  Monaco Grand Prix      5
# 366        24.0    HAM     SOFT     44  Monaco Grand Prix      5
# 367        25.0    HAM     SOFT     44  Monaco Grand Prix      5
# 368        26.0    HAM     SOFT     44  Monaco Grand Prix      5
# 369        27.0    HAM     SOFT     44  Monaco Grand Prix      5
# 370        28.0    HAM     SOFT     44  Monaco Grand Prix      5
# 371        29.0    HAM     SOFT     44  Monaco Grand Prix      5
# 372        30.0    HAM     HARD     44  Monaco Grand Prix      5
# 373        31.0    HAM     HARD     44  Monaco Grand Prix      5
# 374        32.0    HAM     HARD     44  Monaco Grand Prix      5
# 375        33.0    HAM     HARD     44  Monaco Grand Prix      5
# 376        34.0    HAM     HARD     44  Monaco Grand Prix      5
# 377        35.0    HAM     HARD     44  Monaco Grand Prix      5
# 378        36.0    HAM     HARD     44  Monaco Grand Prix      5
# 379        37.0    HAM     HARD     44  Monaco Grand Prix      5
# 380        38.0    HAM     HARD     44  Monaco Grand Prix      5
# 381        39.0    HAM     HARD     44  Monaco Grand Prix      5
# 382        40.0    HAM     HARD     44  Monaco Grand Prix      5
# 383        41.0    HAM     HARD     44  Monaco Grand Prix      5
# 384        42.0    HAM     HARD     44  Monaco Grand Prix      5
# 385        43.0    HAM     HARD     44  Monaco Grand Prix      5
# 386        44.0    HAM     HARD     44  Monaco Grand Prix      5
# 387        45.0    HAM     HARD     44  Monaco Grand Prix      5
# 388        46.0    HAM     HARD     44  Monaco Grand Prix      5
# 389        47.0    HAM     HARD     44  Monaco Grand Prix      5
# 390        48.0    HAM     HARD     44  Monaco Grand Prix      5
# 391        49.0    HAM     HARD     44  Monaco Grand Prix      5
# 392        50.0    HAM     HARD     44  Monaco Grand Prix      5
# 393        51.0    HAM     HARD     44  Monaco Grand Prix      5
# 394        52.0    HAM     HARD     44  Monaco Grand Prix      5
# 395        53.0    HAM     HARD     44  Monaco Grand Prix      5
# 396        54.0    HAM     HARD     44  Monaco Grand Prix      5
# 397        55.0    HAM     HARD     44  Monaco Grand Prix      5
# 398        56.0    HAM     HARD     44  Monaco Grand Prix      5
# 399        57.0    HAM     HARD     44  Monaco Grand Prix      5
# 400        58.0    HAM     HARD     44  Monaco Grand Prix      5
# 401        59.0    HAM     HARD     44  Monaco Grand Prix      5
# 402        60.0    HAM     HARD     44  Monaco Grand Prix      5
# 403        61.0    HAM     HARD     44  Monaco Grand Prix      5
# 404        62.0    HAM     HARD     44  Monaco Grand Prix      5
# 405        63.0    HAM     HARD     44  Monaco Grand Prix      5
# 406        64.0    HAM     HARD     44  Monaco Grand Prix      5
# 407        65.0    HAM     HARD     44  Monaco Grand Prix      5
# 408        66.0    HAM     HARD     44  Monaco Grand Prix      5
# 409        67.0    HAM     HARD     44  Monaco Grand Prix      5
# 410        68.0    HAM     SOFT     44  Monaco Grand Prix      5
# 411        69.0    HAM     SOFT     44  Monaco Grand Prix      5
# 412        70.0    HAM     SOFT     44  Monaco Grand Prix      5
# 413        71.0    HAM     SOFT     44  Monaco Grand Prix      5
# 414        72.0    HAM     SOFT     44  Monaco Grand Prix      5
# 415        73.0    HAM     SOFT     44  Monaco Grand Prix      5
# 416        74.0    HAM     SOFT     44  Monaco Grand Prix      5
# 417        75.0    HAM     SOFT     44  Monaco Grand Prix      5
# 418        76.0    HAM     SOFT     44  Monaco Grand Prix      5
# 419        77.0    HAM     SOFT     44  Monaco Grand Prix      5
# 420        78.0    HAM     SOFT     44  Monaco Grand Prix      5
# 421         1.0    VET     SOFT      5  Monaco Grand Prix      5
# 422         2.0    VET     SOFT      5  Monaco Grand Prix      5
# 423         3.0    VET     SOFT      5  Monaco Grand Prix      5
# 424         4.0    VET     SOFT      5  Monaco Grand Prix      5
# 425         5.0    VET     SOFT      5  Monaco Grand Prix      5
# 426         6.0    VET     SOFT      5  Monaco Grand Prix      5
# 427         7.0    VET     SOFT      5  Monaco Grand Prix      5
# 428         8.0    VET     SOFT      5  Monaco Grand Prix      5
# 429         9.0    VET     SOFT      5  Monaco Grand Prix      5
# 430        10.0    VET     SOFT      5  Monaco Grand Prix      5
# 431        11.0    VET     SOFT      5  Monaco Grand Prix      5
# 432        12.0    VET     SOFT      5  Monaco Grand Prix      5
# 433        13.0    VET     SOFT      5  Monaco Grand Prix      5
# 434        14.0    VET     SOFT      5  Monaco Grand Prix      5
# 435        15.0    VET     SOFT      5  Monaco Grand Prix      5
# 436        16.0    VET     SOFT      5  Monaco Grand Prix      5
# 437        17.0    VET     SOFT      5  Monaco Grand Prix      5
# 438        18.0    VET     SOFT      5  Monaco Grand Prix      5
# 439        19.0    VET     SOFT      5  Monaco Grand Prix      5
# 440        20.0    VET     SOFT      5  Monaco Grand Prix      5
# 441        21.0    VET     SOFT      5  Monaco Grand Prix      5
# 442        22.0    VET     SOFT      5  Monaco Grand Prix      5
# 443        23.0    VET     SOFT      5  Monaco Grand Prix      5
# 444        24.0    VET     SOFT      5  Monaco Grand Prix      5
# 445        25.0    VET     SOFT      5  Monaco Grand Prix      5
# 446        26.0    VET     SOFT      5  Monaco Grand Prix      5
# 447        27.0    VET     SOFT      5  Monaco Grand Prix      5
# 448        28.0    VET     SOFT      5  Monaco Grand Prix      5
# 449        29.0    VET     SOFT      5  Monaco Grand Prix      5
# 450        30.0    VET     SOFT      5  Monaco Grand Prix      5
# 451        31.0    VET     SOFT      5  Monaco Grand Prix      5
# 452        32.0    VET     HARD      5  Monaco Grand Prix      5
# 453        33.0    VET     HARD      5  Monaco Grand Prix      5
# 454        34.0    VET     HARD      5  Monaco Grand Prix      5
# 455        35.0    VET     HARD      5  Monaco Grand Prix      5
# 456        36.0    VET     HARD      5  Monaco Grand Prix      5
# 457        37.0    VET     HARD      5  Monaco Grand Prix      5
# 458        38.0    VET     HARD      5  Monaco Grand Prix      5
# 459        39.0    VET     HARD      5  Monaco Grand Prix      5
# 460        40.0    VET     HARD      5  Monaco Grand Prix      5
# 461        41.0    VET     HARD      5  Monaco Grand Prix      5
# 462        42.0    VET     HARD      5  Monaco Grand Prix      5
# 463        43.0    VET     HARD      5  Monaco Grand Prix      5
# 464        44.0    VET     HARD      5  Monaco Grand Prix      5
# 465        45.0    VET     HARD      5  Monaco Grand Prix      5
# 466        46.0    VET     HARD      5  Monaco Grand Prix      5
# 467        47.0    VET     HARD      5  Monaco Grand Prix      5
# 468        48.0    VET     HARD      5  Monaco Grand Prix      5
# 469        49.0    VET     HARD      5  Monaco Grand Prix      5
# 470        50.0    VET     HARD      5  Monaco Grand Prix      5
# 471        51.0    VET     HARD      5  Monaco Grand Prix      5
# 472        52.0    VET     HARD      5  Monaco Grand Prix      5
# 473        53.0    VET     HARD      5  Monaco Grand Prix      5
# 474        54.0    VET     HARD      5  Monaco Grand Prix      5
# 475        55.0    VET     HARD      5  Monaco Grand Prix      5
# 476        56.0    VET     HARD      5  Monaco Grand Prix      5
# 477        57.0    VET     HARD      5  Monaco Grand Prix      5
# 478        58.0    VET     HARD      5  Monaco Grand Prix      5
# 479        59.0    VET     HARD      5  Monaco Grand Prix      5
# 480        60.0    VET     HARD      5  Monaco Grand Prix      5
# 481        61.0    VET     HARD      5  Monaco Grand Prix      5
# 482        62.0    VET     HARD      5  Monaco Grand Prix      5
# 483        63.0    VET     HARD      5  Monaco Grand Prix      5
# 484        64.0    VET     HARD      5  Monaco Grand Prix      5
# 485        65.0    VET     HARD      5  Monaco Grand Prix      5
# 486        66.0    VET     HARD      5  Monaco Grand Prix      5
# 487        67.0    VET     HARD      5  Monaco Grand Prix      5
# 488        68.0    VET     HARD      5  Monaco Grand Prix      5
# 489        69.0    VET     HARD      5  Monaco Grand Prix      5
# 490        70.0    VET     HARD      5  Monaco Grand Prix      5
# 491        71.0    VET     HARD      5  Monaco Grand Prix      5
# 492        72.0    VET     HARD      5  Monaco Grand Prix      5
# 493        73.0    VET     HARD      5  Monaco Grand Prix      5
# 494        74.0    VET     HARD      5  Monaco Grand Prix      5
# 495        75.0    VET     HARD      5  Monaco Grand Prix      5
# 496        76.0    VET     HARD      5  Monaco Grand Prix      5
# 497        77.0    VET     HARD      5  Monaco Grand Prix      5
# 498        78.0    VET     HARD      5  Monaco Grand Prix      5
# 499         1.0    PER     SOFT     11  Monaco Grand Prix      5
# 500         2.0    PER     SOFT     11  Monaco Grand Prix      5
# 501         3.0    PER     SOFT     11  Monaco Grand Prix      5
# 502         4.0    PER     SOFT     11  Monaco Grand Prix      5
# 503         5.0    PER     SOFT     11  Monaco Grand Prix      5
# 504         6.0    PER     SOFT     11  Monaco Grand Prix      5
# 505         7.0    PER     SOFT     11  Monaco Grand Prix      5
# 506         8.0    PER     SOFT     11  Monaco Grand Prix      5
# 507         9.0    PER     SOFT     11  Monaco Grand Prix      5
# 508        10.0    PER     SOFT     11  Monaco Grand Prix      5
# 509        11.0    PER     SOFT     11  Monaco Grand Prix      5
# 510        12.0    PER     SOFT     11  Monaco Grand Prix      5
# 511        13.0    PER     SOFT     11  Monaco Grand Prix      5
# 512        14.0    PER     SOFT     11  Monaco Grand Prix      5
# 513        15.0    PER     SOFT     11  Monaco Grand Prix      5
# 514        16.0    PER     SOFT     11  Monaco Grand Prix      5
# 515        17.0    PER     SOFT     11  Monaco Grand Prix      5
# 516        18.0    PER     SOFT     11  Monaco Grand Prix      5
# 517        19.0    PER     SOFT     11  Monaco Grand Prix      5
# 518        20.0    PER     SOFT     11  Monaco Grand Prix      5
# 519        21.0    PER     SOFT     11  Monaco Grand Prix      5
# 520        22.0    PER     SOFT     11  Monaco Grand Prix      5
# 521        23.0    PER     SOFT     11  Monaco Grand Prix      5
# 522        24.0    PER     SOFT     11  Monaco Grand Prix      5
# 523        25.0    PER     SOFT     11  Monaco Grand Prix      5
# 524        26.0    PER     SOFT     11  Monaco Grand Prix      5
# 525        27.0    PER     SOFT     11  Monaco Grand Prix      5
# 526        28.0    PER     SOFT     11  Monaco Grand Prix      5
# 527        29.0    PER     SOFT     11  Monaco Grand Prix      5
# 528        30.0    PER     SOFT     11  Monaco Grand Prix      5
# 529        31.0    PER     SOFT     11  Monaco Grand Prix      5
# 530        32.0    PER     SOFT     11  Monaco Grand Prix      5
# 531        33.0    PER     SOFT     11  Monaco Grand Prix      5
# 532        34.0    PER     SOFT     11  Monaco Grand Prix      5
# 533        35.0    PER     SOFT     11  Monaco Grand Prix      5
# 534        36.0    PER     HARD     11  Monaco Grand Prix      5
# 535        37.0    PER     HARD     11  Monaco Grand Prix      5
# 536        38.0    PER     HARD     11  Monaco Grand Prix      5
# 537        39.0    PER     HARD     11  Monaco Grand Prix      5
# 538        40.0    PER     HARD     11  Monaco Grand Prix      5
# 539        41.0    PER     HARD     11  Monaco Grand Prix      5
# 540        42.0    PER     HARD     11  Monaco Grand Prix      5
# 541        43.0    PER     HARD     11  Monaco Grand Prix      5
# 542        44.0    PER     HARD     11  Monaco Grand Prix      5
# 543        45.0    PER     HARD     11  Monaco Grand Prix      5
# 544        46.0    PER     HARD     11  Monaco Grand Prix      5
# 545        47.0    PER     HARD     11  Monaco Grand Prix      5
# 546        48.0    PER     HARD     11  Monaco Grand Prix      5
# 547        49.0    PER     HARD     11  Monaco Grand Prix      5
# 548        50.0    PER     HARD     11  Monaco Grand Prix      5
# 549        51.0    PER     HARD     11  Monaco Grand Prix      5
# 550        52.0    PER     HARD     11  Monaco Grand Prix      5
# 551        53.0    PER     HARD     11  Monaco Grand Prix      5
# 552        54.0    PER     HARD     11  Monaco Grand Prix      5
# 553        55.0    PER     HARD     11  Monaco Grand Prix      5
# 554        56.0    PER     HARD     11  Monaco Grand Prix      5
# 555        57.0    PER     HARD     11  Monaco Grand Prix      5
# 556        58.0    PER     HARD     11  Monaco Grand Prix      5
# 557        59.0    PER     HARD     11  Monaco Grand Prix      5
# 558        60.0    PER     HARD     11  Monaco Grand Prix      5
# 559        61.0    PER     HARD     11  Monaco Grand Prix      5
# 560        62.0    PER     HARD     11  Monaco Grand Prix      5
# 561        63.0    PER     HARD     11  Monaco Grand Prix      5
# 562        64.0    PER     HARD     11  Monaco Grand Prix      5
# 563        65.0    PER     HARD     11  Monaco Grand Prix      5
# 564        66.0    PER     HARD     11  Monaco Grand Prix      5
# 565        67.0    PER     HARD     11  Monaco Grand Prix      5
# 566        68.0    PER     HARD     11  Monaco Grand Prix      5
# 567        69.0    PER     HARD     11  Monaco Grand Prix      5
# 568        70.0    PER     HARD     11  Monaco Grand Prix      5
# 569        71.0    PER     HARD     11  Monaco Grand Prix      5
# 570        72.0    PER     HARD     11  Monaco Grand Prix      5
# 571        73.0    PER     HARD     11  Monaco Grand Prix      5
# 572        74.0    PER     HARD     11  Monaco Grand Prix      5
# 573        75.0    PER     HARD     11  Monaco Grand Prix      5
# 574        76.0    PER     HARD     11  Monaco Grand Prix      5
# 575        77.0    PER     HARD     11  Monaco Grand Prix      5
# 576        78.0    PER     HARD     11  Monaco Grand Prix      5
# 577         1.0    GIO     SOFT     99  Monaco Grand Prix      5
# 578         2.0    GIO     SOFT     99  Monaco Grand Prix      5
# 579         3.0    GIO     SOFT     99  Monaco Grand Prix      5
# 580         4.0    GIO     SOFT     99  Monaco Grand Prix      5
# 581         5.0    GIO     SOFT     99  Monaco Grand Prix      5
# 582         6.0    GIO     SOFT     99  Monaco Grand Prix      5
# 583         7.0    GIO     SOFT     99  Monaco Grand Prix      5
# 584         8.0    GIO     SOFT     99  Monaco Grand Prix      5
# 585         9.0    GIO     SOFT     99  Monaco Grand Prix      5
# 586        10.0    GIO     SOFT     99  Monaco Grand Prix      5
# 587        11.0    GIO     SOFT     99  Monaco Grand Prix      5
# 588        12.0    GIO     SOFT     99  Monaco Grand Prix      5
# 589        13.0    GIO     SOFT     99  Monaco Grand Prix      5
# 590        14.0    GIO     SOFT     99  Monaco Grand Prix      5
# 591        15.0    GIO     SOFT     99  Monaco Grand Prix      5
# 592        16.0    GIO     SOFT     99  Monaco Grand Prix      5
# 593        17.0    GIO     SOFT     99  Monaco Grand Prix      5
# 594        18.0    GIO     SOFT     99  Monaco Grand Prix      5
# 595        19.0    GIO     SOFT     99  Monaco Grand Prix      5
# 596        20.0    GIO     SOFT     99  Monaco Grand Prix      5
# 597        21.0    GIO     SOFT     99  Monaco Grand Prix      5
# 598        22.0    GIO     SOFT     99  Monaco Grand Prix      5
# 599        23.0    GIO     SOFT     99  Monaco Grand Prix      5
# 600        24.0    GIO     SOFT     99  Monaco Grand Prix      5
# 601        25.0    GIO     SOFT     99  Monaco Grand Prix      5
# 602        26.0    GIO     SOFT     99  Monaco Grand Prix      5
# 603        27.0    GIO     SOFT     99  Monaco Grand Prix      5
# 604        28.0    GIO     SOFT     99  Monaco Grand Prix      5
# 605        29.0    GIO     SOFT     99  Monaco Grand Prix      5
# 606        30.0    GIO     SOFT     99  Monaco Grand Prix      5
# 607        31.0    GIO     SOFT     99  Monaco Grand Prix      5
# 608        32.0    GIO     SOFT     99  Monaco Grand Prix      5
# 609        33.0    GIO     SOFT     99  Monaco Grand Prix      5
# 610        34.0    GIO     HARD     99  Monaco Grand Prix      5
# 611        35.0    GIO     HARD     99  Monaco Grand Prix      5
# 612        36.0    GIO     HARD     99  Monaco Grand Prix      5
# 613        37.0    GIO     HARD     99  Monaco Grand Prix      5
# 614        38.0    GIO     HARD     99  Monaco Grand Prix      5
# 615        39.0    GIO     HARD     99  Monaco Grand Prix      5
# 616        40.0    GIO     HARD     99  Monaco Grand Prix      5
# 617        41.0    GIO     HARD     99  Monaco Grand Prix      5
# 618        42.0    GIO     HARD     99  Monaco Grand Prix      5
# 619        43.0    GIO     HARD     99  Monaco Grand Prix      5
# 620        44.0    GIO     HARD     99  Monaco Grand Prix      5
# 621        45.0    GIO     HARD     99  Monaco Grand Prix      5
# 622        46.0    GIO     HARD     99  Monaco Grand Prix      5
# 623        47.0    GIO     HARD     99  Monaco Grand Prix      5
# 624        48.0    GIO     HARD     99  Monaco Grand Prix      5
# 625        49.0    GIO     HARD     99  Monaco Grand Prix      5
# 626        50.0    GIO     HARD     99  Monaco Grand Prix      5
# 627        51.0    GIO     HARD     99  Monaco Grand Prix      5
# 628        52.0    GIO     HARD     99  Monaco Grand Prix      5
# 629        53.0    GIO     HARD     99  Monaco Grand Prix      5
# 630        54.0    GIO     HARD     99  Monaco Grand Prix      5
# 631        55.0    GIO     HARD     99  Monaco Grand Prix      5
# 632        56.0    GIO     HARD     99  Monaco Grand Prix      5
# 633        57.0    GIO     HARD     99  Monaco Grand Prix      5
# 634        58.0    GIO     HARD     99  Monaco Grand Prix      5
# 635        59.0    GIO     HARD     99  Monaco Grand Prix      5
# 636        60.0    GIO     HARD     99  Monaco Grand Prix      5
# 637        61.0    GIO     HARD     99  Monaco Grand Prix      5
# 638        62.0    GIO     HARD     99  Monaco Grand Prix      5
# 639        63.0    GIO     HARD     99  Monaco Grand Prix      5
# 640        64.0    GIO     HARD     99  Monaco Grand Prix      5
# 641        65.0    GIO     HARD     99  Monaco Grand Prix      5
# 642        66.0    GIO     HARD     99  Monaco Grand Prix      5
# 643        67.0    GIO     HARD     99  Monaco Grand Prix      5
# 644        68.0    GIO     HARD     99  Monaco Grand Prix      5
# 645        69.0    GIO     HARD     99  Monaco Grand Prix      5
# 646        70.0    GIO     HARD     99  Monaco Grand Prix      5
# 647        71.0    GIO     HARD     99  Monaco Grand Prix      5
# 648        72.0    GIO     HARD     99  Monaco Grand Prix      5
# 649        73.0    GIO     HARD     99  Monaco Grand Prix      5
# 650        74.0    GIO     HARD     99  Monaco Grand Prix      5
# 651        75.0    GIO     HARD     99  Monaco Grand Prix      5
# 652        76.0    GIO     HARD     99  Monaco Grand Prix      5
# 653        77.0    GIO     HARD     99  Monaco Grand Prix      5
# 654         1.0    OCO     SOFT     31  Monaco Grand Prix      5
# 655         2.0    OCO     SOFT     31  Monaco Grand Prix      5
# 656         3.0    OCO     SOFT     31  Monaco Grand Prix      5
# 657         4.0    OCO     SOFT     31  Monaco Grand Prix      5
# 658         5.0    OCO     SOFT     31  Monaco Grand Prix      5
# 659         6.0    OCO     SOFT     31  Monaco Grand Prix      5
# 660         7.0    OCO     SOFT     31  Monaco Grand Prix      5
# 661         8.0    OCO     SOFT     31  Monaco Grand Prix      5
# 662         9.0    OCO     SOFT     31  Monaco Grand Prix      5
# 663        10.0    OCO     SOFT     31  Monaco Grand Prix      5
# 664        11.0    OCO     SOFT     31  Monaco Grand Prix      5
# 665        12.0    OCO     SOFT     31  Monaco Grand Prix      5
# 666        13.0    OCO     SOFT     31  Monaco Grand Prix      5
# 667        14.0    OCO     SOFT     31  Monaco Grand Prix      5
# 668        15.0    OCO     SOFT     31  Monaco Grand Prix      5
# 669        16.0    OCO     SOFT     31  Monaco Grand Prix      5
# 670        17.0    OCO     SOFT     31  Monaco Grand Prix      5
# 671        18.0    OCO     SOFT     31  Monaco Grand Prix      5
# 672        19.0    OCO     SOFT     31  Monaco Grand Prix      5
# 673        20.0    OCO     SOFT     31  Monaco Grand Prix      5
# 674        21.0    OCO     SOFT     31  Monaco Grand Prix      5
# 675        22.0    OCO     SOFT     31  Monaco Grand Prix      5
# 676        23.0    OCO     SOFT     31  Monaco Grand Prix      5
# 677        24.0    OCO     SOFT     31  Monaco Grand Prix      5
# 678        25.0    OCO     SOFT     31  Monaco Grand Prix      5
# 679        26.0    OCO     SOFT     31  Monaco Grand Prix      5
# 680        27.0    OCO     SOFT     31  Monaco Grand Prix      5
# 681        28.0    OCO     SOFT     31  Monaco Grand Prix      5
# 682        29.0    OCO     SOFT     31  Monaco Grand Prix      5
# 683        30.0    OCO     SOFT     31  Monaco Grand Prix      5
# 684        31.0    OCO     SOFT     31  Monaco Grand Prix      5
# 685        32.0    OCO     SOFT     31  Monaco Grand Prix      5
# 686        33.0    OCO     SOFT     31  Monaco Grand Prix      5
# 687        34.0    OCO     SOFT     31  Monaco Grand Prix      5
# 688        35.0    OCO     SOFT     31  Monaco Grand Prix      5
# 689        36.0    OCO     SOFT     31  Monaco Grand Prix      5
# 690        37.0    OCO     SOFT     31  Monaco Grand Prix      5
# 691        38.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 692        39.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 693        40.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 694        41.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 695        42.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 696        43.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 697        44.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 698        45.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 699        46.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 700        47.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 701        48.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 702        49.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 703        50.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 704        51.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 705        52.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 706        53.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 707        54.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 708        55.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 709        56.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 710        57.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 711        58.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 712        59.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 713        60.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 714        61.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 715        62.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 716        63.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 717        64.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 718        65.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 719        66.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 720        67.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 721        68.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 722        69.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 723        70.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 724        71.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 725        72.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 726        73.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 727        74.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 728        75.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 729        76.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 730        77.0    OCO   MEDIUM     31  Monaco Grand Prix      5
# 731         1.0    RIC   MEDIUM      3  Monaco Grand Prix      5
# 732         2.0    RIC   MEDIUM      3  Monaco Grand Prix      5
# 733         3.0    RIC   MEDIUM      3  Monaco Grand Prix      5
# 734         4.0    RIC   MEDIUM      3  Monaco Grand Prix      5
# 735         5.0    RIC   MEDIUM      3  Monaco Grand Prix      5
# 736         6.0    RIC   MEDIUM      3  Monaco Grand Prix      5
# ...
# 1174       59.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1175       60.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1176       61.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1177       62.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1178       63.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1179       64.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1180       65.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1181       66.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1182       67.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1183       68.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1184       69.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1185       70.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1186       71.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1187       72.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1188       73.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1189       74.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1190       75.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1191       76.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1192       77.0    ALO     SOFT     14  Monaco Grand Prix      5
# 1193        1.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1194        2.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1195        3.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1196        4.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1197        5.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1198        6.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1199        7.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1200        8.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1201        9.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1202       10.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1203       11.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1204       12.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1205       13.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1206       14.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1207       15.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1208       16.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1209       17.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1210       18.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1211       19.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1212       20.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1213       21.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1214       22.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1215       23.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1216       24.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1217       25.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1218       26.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1219       27.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1220       28.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1221       29.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1222       30.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1223       31.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1224       32.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1225       33.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1226       34.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1227       35.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1228       36.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1229       37.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1230       38.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1231       39.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1232       40.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1233       41.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1234       42.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1235       43.0    LAT   MEDIUM      6  Monaco Grand Prix      5
# 1236       44.0    LAT     HARD      6  Monaco Grand Prix      5
# 1237       45.0    LAT     HARD      6  Monaco Grand Prix      5
# 1238       46.0    LAT     HARD      6  Monaco Grand Prix      5
# 1239       47.0    LAT     HARD      6  Monaco Grand Prix      5
# 1240       48.0    LAT     HARD      6  Monaco Grand Prix      5
# 1241       49.0    LAT     HARD      6  Monaco Grand Prix      5
# 1242       50.0    LAT     HARD      6  Monaco Grand Prix      5
# 1243       51.0    LAT     HARD      6  Monaco Grand Prix      5
# 1244       52.0    LAT     HARD      6  Monaco Grand Prix      5
# 1245       53.0    LAT     HARD      6  Monaco Grand Prix      5
# 1246       54.0    LAT     HARD      6  Monaco Grand Prix      5
# 1247       55.0    LAT     HARD      6  Monaco Grand Prix      5
# 1248       56.0    LAT     HARD      6  Monaco Grand Prix      5
# 1249       57.0    LAT     HARD      6  Monaco Grand Prix      5
# 1250       58.0    LAT     HARD      6  Monaco Grand Prix      5
# 1251       59.0    LAT     HARD      6  Monaco Grand Prix      5
# 1252       60.0    LAT     HARD      6  Monaco Grand Prix      5
# 1253       61.0    LAT     HARD      6  Monaco Grand Prix      5
# 1254       62.0    LAT     HARD      6  Monaco Grand Prix      5
# 1255       63.0    LAT     HARD      6  Monaco Grand Prix      5
# 1256       64.0    LAT     HARD      6  Monaco Grand Prix      5
# 1257       65.0    LAT     HARD      6  Monaco Grand Prix      5
# 1258       66.0    LAT     HARD      6  Monaco Grand Prix      5
# 1259       67.0    LAT     HARD      6  Monaco Grand Prix      5
# 1260       68.0    LAT     HARD      6  Monaco Grand Prix      5
# 1261       69.0    LAT     HARD      6  Monaco Grand Prix      5
# 1262       70.0    LAT     HARD      6  Monaco Grand Prix      5
# 1263       71.0    LAT     HARD      6  Monaco Grand Prix      5
# 1264       72.0    LAT     HARD      6  Monaco Grand Prix      5
# 1265       73.0    LAT     HARD      6  Monaco Grand Prix      5
# 1266       74.0    LAT     HARD      6  Monaco Grand Prix      5
# 1267       75.0    LAT     HARD      6  Monaco Grand Prix      5
# 1268       76.0    LAT     HARD      6  Monaco Grand Prix      5
# 1269       77.0    LAT     HARD      6  Monaco Grand Prix      5
# 1270        1.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1271        2.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1272        3.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1273        4.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1274        5.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1275        6.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1276        7.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1277        8.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1278        9.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1279       10.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1280       11.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1281       12.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1282       13.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1283       14.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1284       15.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1285       16.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1286       17.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1287       18.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1288       19.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1289       20.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1290       21.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1291       22.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1292       23.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1293       24.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1294       25.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1295       26.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1296       27.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1297       28.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1298       29.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1299       30.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1300       31.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1301       32.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1302       33.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1303       34.0    MAZ     SOFT      9  Monaco Grand Prix      5
# 1304       35.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1305       36.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1306       37.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1307       38.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1308       39.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1309       40.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1310       41.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1311       42.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1312       43.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1313       44.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1314       45.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1315       46.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1316       47.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1317       48.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1318       49.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1319       50.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1320       51.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1321       52.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1322       53.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1323       54.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1324       55.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1325       56.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1326       57.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1327       58.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1328       59.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1329       60.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1330       61.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1331       62.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1332       63.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1333       64.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1334       65.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1335       66.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1336       67.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1337       68.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1338       69.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1339       70.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1340       71.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1341       72.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1342       73.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1343       74.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1344       75.0    MAZ     HARD      9  Monaco Grand Prix      5
# 1345        1.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1346        2.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1347        3.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1348        4.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1349        5.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1350        6.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1351        7.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1352        8.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1353        9.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1354       10.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1355       11.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1356       12.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1357       13.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1358       14.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1359       15.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1360       16.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1361       17.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1362       18.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1363       19.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1364       20.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1365       21.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1366       22.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1367       23.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1368       24.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1369       25.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1370       26.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1371       27.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1372       28.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1373       29.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1374       30.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1375       31.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1376       32.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1377       33.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1378       34.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1379       35.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1380       36.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1381       37.0    MSC     SOFT     47  Monaco Grand Prix      5
# 1382       38.0    MSC     HARD     47  Monaco Grand Prix      5
# 1383       39.0    MSC     HARD     47  Monaco Grand Prix      5
# 1384       40.0    MSC     HARD     47  Monaco Grand Prix      5
# 1385       41.0    MSC     HARD     47  Monaco Grand Prix      5
# 1386       42.0    MSC     HARD     47  Monaco Grand Prix      5
# 1387       43.0    MSC     HARD     47  Monaco Grand Prix      5
# 1388       44.0    MSC     HARD     47  Monaco Grand Prix      5
# 1389       45.0    MSC     HARD     47  Monaco Grand Prix      5
# 1390       46.0    MSC     HARD     47  Monaco Grand Prix      5
# 1391       47.0    MSC     HARD     47  Monaco Grand Prix      5
# 1392       48.0    MSC     HARD     47  Monaco Grand Prix      5
# 1393       49.0    MSC     HARD     47  Monaco Grand Prix      5
# 1394       50.0    MSC     HARD     47  Monaco Grand Prix      5
# 1395       51.0    MSC     HARD     47  Monaco Grand Prix      5
# 1396       52.0    MSC     HARD     47  Monaco Grand Prix      5
# 1397       53.0    MSC     HARD     47  Monaco Grand Prix      5
# 1398       54.0    MSC     HARD     47  Monaco Grand Prix      5
# 1399       55.0    MSC     HARD     47  Monaco Grand Prix      5
# 1400       56.0    MSC     HARD     47  Monaco Grand Prix      5
# 1401       57.0    MSC     HARD     47  Monaco Grand Prix      5
# 1402       58.0    MSC     HARD     47  Monaco Grand Prix      5
# 1403       59.0    MSC     HARD     47  Monaco Grand Prix      5
# 1404       60.0    MSC     HARD     47  Monaco Grand Prix      5
# 1405       61.0    MSC     HARD     47  Monaco Grand Prix      5
# 1406       62.0    MSC     HARD     47  Monaco Grand Prix      5
# 1407       63.0    MSC     HARD     47  Monaco Grand Prix      5
# 1408       64.0    MSC     HARD     47  Monaco Grand Prix      5
# 1409       65.0    MSC     HARD     47  Monaco Grand Prix      5
# 1410       66.0    MSC     HARD     47  Monaco Grand Prix      5
# 1411       67.0    MSC     HARD     47  Monaco Grand Prix      5
# 1412       68.0    MSC     HARD     47  Monaco Grand Prix      5
# 1413       69.0    MSC     HARD     47  Monaco Grand Prix      5
# 1414       70.0    MSC     HARD     47  Monaco Grand Prix      5
# 1415       71.0    MSC     HARD     47  Monaco Grand Prix      5
# 1416       72.0    MSC     HARD     47  Monaco Grand Prix      5
# 1417       73.0    MSC     HARD     47  Monaco Grand Prix      5
# 1418       74.0    MSC     HARD     47  Monaco Grand Prix      5
# 1419       75.0    MSC     HARD     47  Monaco Grand Prix      5

# %%
# Function  for correctly assigning the grid position to each driver. x is a row from our list 
def get_grid(x):
    
    # Save the driver number of the row      
    driver_number = x["number"]
    
    
    # Find in grid list the driver that we are looking for  
    
    driver_row = grid_info[grid_info["number"]==driver_number]
    try:
        grid_position = driver_row["grid"].iloc[0]
    except:
        return 
    
    # Return for this driver the grid position     
    return grid_position

# Apply get_grid to each row of our table and create at the same time a new columns "grid" that will
# get the right value of grid position for each driver
laps_info["grid"] = laps_info.apply(get_grid ,axis=1)

# %%
# Same as previous function just change the names of some lists and variables
def get_quali_position(x):
    driver_number = x["number"]
    driver_row = quali_info[quali_info["number"]==driver_number]
    try:
        quali_position = driver_row["position"].iloc[0]
    except:
        return
    return quali_position

laps_info["quali_position"] = laps_info.apply(get_quali_position ,axis=1)

# %%
pd.set_option('display.max_rows', None)

laps_info
# Out:
#       LapNumber Driver Compound number            GP_name  round grid  \
# 0           0.0    LEC     SOFT     16  Monaco Grand Prix      5    1
# 1           1.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 2           2.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 3           3.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 4           4.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 5           5.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 6           6.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 7           7.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 8           8.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 9           9.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 10         10.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 11         11.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 12         12.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 13         13.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 14         14.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 15         15.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 16         16.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 17         17.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 18         18.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 19         19.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 20         20.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 21         21.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 22         22.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 23         23.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 24         24.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 25         25.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 26         26.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 27         27.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 28         28.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 29         29.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 30         30.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 31         31.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 32         32.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 33         33.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 34         34.0    VER     SOFT     33  Monaco Grand Prix      5    2
# 35         35.0    VER     HARD     33  Monaco Grand Prix      5    2
# 36         36.0    VER     HARD     33  Monaco Grand Prix      5    2
# 37         37.0    VER     HARD     33  Monaco Grand Prix      5    2
# 38         38.0    VER     HARD     33  Monaco Grand Prix      5    2
# 39         39.0    VER     HARD     33  Monaco Grand Prix      5    2
# 40         40.0    VER     HARD     33  Monaco Grand Prix      5    2
# 41         41.0    VER     HARD     33  Monaco Grand Prix      5    2
# 42         42.0    VER     HARD     33  Monaco Grand Prix      5    2
# 43         43.0    VER     HARD     33  Monaco Grand Prix      5    2
# 44         44.0    VER     HARD     33  Monaco Grand Prix      5    2
# 45         45.0    VER     HARD     33  Monaco Grand Prix      5    2
# 46         46.0    VER     HARD     33  Monaco Grand Prix      5    2
# 47         47.0    VER     HARD     33  Monaco Grand Prix      5    2
# 48         48.0    VER     HARD     33  Monaco Grand Prix      5    2
# 49         49.0    VER     HARD     33  Monaco Grand Prix      5    2
# 50         50.0    VER     HARD     33  Monaco Grand Prix      5    2
# 51         51.0    VER     HARD     33  Monaco Grand Prix      5    2
# 52         52.0    VER     HARD     33  Monaco Grand Prix      5    2
# 53         53.0    VER     HARD     33  Monaco Grand Prix      5    2
# 54         54.0    VER     HARD     33  Monaco Grand Prix      5    2
# 55         55.0    VER     HARD     33  Monaco Grand Prix      5    2
# 56         56.0    VER     HARD     33  Monaco Grand Prix      5    2
# 57         57.0    VER     HARD     33  Monaco Grand Prix      5    2
# 58         58.0    VER     HARD     33  Monaco Grand Prix      5    2
# 59         59.0    VER     HARD     33  Monaco Grand Prix      5    2
# 60         60.0    VER     HARD     33  Monaco Grand Prix      5    2
# 61         61.0    VER     HARD     33  Monaco Grand Prix      5    2
# 62         62.0    VER     HARD     33  Monaco Grand Prix      5    2
# 63         63.0    VER     HARD     33  Monaco Grand Prix      5    2
# 64         64.0    VER     HARD     33  Monaco Grand Prix      5    2
# 65         65.0    VER     HARD     33  Monaco Grand Prix      5    2
# 66         66.0    VER     HARD     33  Monaco Grand Prix      5    2
# 67         67.0    VER     HARD     33  Monaco Grand Prix      5    2
# 68         68.0    VER     HARD     33  Monaco Grand Prix      5    2
# 69         69.0    VER     HARD     33  Monaco Grand Prix      5    2
# 70         70.0    VER     HARD     33  Monaco Grand Prix      5    2
# 71         71.0    VER     HARD     33  Monaco Grand Prix      5    2
# 72         72.0    VER     HARD     33  Monaco Grand Prix      5    2
# 73         73.0    VER     HARD     33  Monaco Grand Prix      5    2
# 74         74.0    VER     HARD     33  Monaco Grand Prix      5    2
# 75         75.0    VER     HARD     33  Monaco Grand Prix      5    2
# 76         76.0    VER     HARD     33  Monaco Grand Prix      5    2
# 77         77.0    VER     HARD     33  Monaco Grand Prix      5    2
# 78         78.0    VER     HARD     33  Monaco Grand Prix      5    2
# 79          1.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 80          2.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 81          3.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 82          4.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 83          5.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 84          6.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 85          7.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 86          8.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 87          9.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 88         10.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 89         11.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 90         12.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 91         13.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 92         14.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 93         15.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 94         16.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 95         17.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 96         18.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 97         19.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 98         20.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 99         21.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 100        22.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 101        23.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 102        24.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 103        25.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 104        26.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 105        27.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 106        28.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 107        29.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 108        30.0    BOT     SOFT     77  Monaco Grand Prix      5    3
# 109         1.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 110         2.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 111         3.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 112         4.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 113         5.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 114         6.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 115         7.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 116         8.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 117         9.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 118        10.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 119        11.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 120        12.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 121        13.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 122        14.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 123        15.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 124        16.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 125        17.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 126        18.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 127        19.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 128        20.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 129        21.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 130        22.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 131        23.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 132        24.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 133        25.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 134        26.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 135        27.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 136        28.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 137        29.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 138        30.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 139        31.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 140        32.0    SAI     SOFT     55  Monaco Grand Prix      5    4
# 141        33.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 142        34.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 143        35.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 144        36.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 145        37.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 146        38.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 147        39.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 148        40.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 149        41.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 150        42.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 151        43.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 152        44.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 153        45.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 154        46.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 155        47.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 156        48.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 157        49.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 158        50.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 159        51.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 160        52.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 161        53.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 162        54.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 163        55.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 164        56.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 165        57.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 166        58.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 167        59.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 168        60.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 169        61.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 170        62.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 171        63.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 172        64.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 173        65.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 174        66.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 175        67.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 176        68.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 177        69.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 178        70.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 179        71.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 180        72.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 181        73.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 182        74.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 183        75.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 184        76.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 185        77.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 186        78.0    SAI     HARD     55  Monaco Grand Prix      5    4
# 187         1.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 188         2.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 189         3.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 190         4.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 191         5.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 192         6.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 193         7.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 194         8.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 195         9.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 196        10.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 197        11.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 198        12.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 199        13.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 200        14.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 201        15.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 202        16.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 203        17.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 204        18.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 205        19.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 206        20.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 207        21.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 208        22.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 209        23.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 210        24.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 211        25.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 212        26.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 213        27.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 214        28.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 215        29.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 216        30.0    NOR     SOFT      4  Monaco Grand Prix      5    5
# 217        31.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 218        32.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 219        33.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 220        34.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 221        35.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 222        36.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 223        37.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 224        38.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 225        39.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 226        40.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 227        41.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 228        42.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 229        43.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 230        44.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 231        45.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 232        46.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 233        47.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 234        48.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 235        49.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 236        50.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 237        51.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 238        52.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 239        53.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 240        54.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 241        55.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 242        56.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 243        57.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 244        58.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 245        59.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 246        60.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 247        61.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 248        62.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 249        63.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 250        64.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 251        65.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 252        66.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 253        67.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 254        68.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 255        69.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 256        70.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 257        71.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 258        72.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 259        73.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 260        74.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 261        75.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 262        76.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 263        77.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 264        78.0    NOR     HARD      4  Monaco Grand Prix      5    5
# 265         1.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 266         2.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 267         3.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 268         4.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 269         5.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 270         6.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 271         7.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 272         8.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 273         9.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 274        10.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 275        11.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 276        12.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 277        13.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 278        14.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 279        15.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 280        16.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 281        17.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 282        18.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 283        19.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 284        20.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 285        21.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 286        22.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 287        23.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 288        24.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 289        25.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 290        26.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 291        27.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 292        28.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 293        29.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 294        30.0    GAS     SOFT     10  Monaco Grand Prix      5    6
# 295        31.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 296        32.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 297        33.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 298        34.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 299        35.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 300        36.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 301        37.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 302        38.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 303        39.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 304        40.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 305        41.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 306        42.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 307        43.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 308        44.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 309        45.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 310        46.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 311        47.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 312        48.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 313        49.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 314        50.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 315        51.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 316        52.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 317        53.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 318        54.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 319        55.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 320        56.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 321        57.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 322        58.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 323        59.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 324        60.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 325        61.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 326        62.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 327        63.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 328        64.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 329        65.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 330        66.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 331        67.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 332        68.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 333        69.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 334        70.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 335        71.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 336        72.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 337        73.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 338        74.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 339        75.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 340        76.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 341        77.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 342        78.0    GAS     HARD     10  Monaco Grand Prix      5    6
# 343         1.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 344         2.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 345         3.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 346         4.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 347         5.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 348         6.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 349         7.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 350         8.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 351         9.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 352        10.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 353        11.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 354        12.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 355        13.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 356        14.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 357        15.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 358        16.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 359        17.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 360        18.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 361        19.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 362        20.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 363        21.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 364        22.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 365        23.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 366        24.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 367        25.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 368        26.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 369        27.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 370        28.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 371        29.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 372        30.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 373        31.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 374        32.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 375        33.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 376        34.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 377        35.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 378        36.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 379        37.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 380        38.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 381        39.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 382        40.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 383        41.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 384        42.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 385        43.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 386        44.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 387        45.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 388        46.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 389        47.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 390        48.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 391        49.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 392        50.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 393        51.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 394        52.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 395        53.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 396        54.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 397        55.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 398        56.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 399        57.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 400        58.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 401        59.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 402        60.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 403        61.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 404        62.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 405        63.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 406        64.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 407        65.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 408        66.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 409        67.0    HAM     HARD     44  Monaco Grand Prix      5    7
# 410        68.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 411        69.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 412        70.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 413        71.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 414        72.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 415        73.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 416        74.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 417        75.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 418        76.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 419        77.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 420        78.0    HAM     SOFT     44  Monaco Grand Prix      5    7
# 421         1.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 422         2.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 423         3.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 424         4.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 425         5.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 426         6.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 427         7.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 428         8.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 429         9.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 430        10.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 431        11.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 432        12.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 433        13.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 434        14.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 435        15.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 436        16.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 437        17.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 438        18.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 439        19.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 440        20.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 441        21.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 442        22.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 443        23.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 444        24.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 445        25.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 446        26.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 447        27.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 448        28.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 449        29.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 450        30.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 451        31.0    VET     SOFT      5  Monaco Grand Prix      5    8
# 452        32.0    VET     HARD      5  Monaco Grand Prix      5    8
# 453        33.0    VET     HARD      5  Monaco Grand Prix      5    8
# 454        34.0    VET     HARD      5  Monaco Grand Prix      5    8
# 455        35.0    VET     HARD      5  Monaco Grand Prix      5    8
# 456        36.0    VET     HARD      5  Monaco Grand Prix      5    8
# 457        37.0    VET     HARD      5  Monaco Grand Prix      5    8
# 458        38.0    VET     HARD      5  Monaco Grand Prix      5    8
# 459        39.0    VET     HARD      5  Monaco Grand Prix      5    8
# 460        40.0    VET     HARD      5  Monaco Grand Prix      5    8
# 461        41.0    VET     HARD      5  Monaco Grand Prix      5    8
# 462        42.0    VET     HARD      5  Monaco Grand Prix      5    8
# 463        43.0    VET     HARD      5  Monaco Grand Prix      5    8
# 464        44.0    VET     HARD      5  Monaco Grand Prix      5    8
# 465        45.0    VET     HARD      5  Monaco Grand Prix      5    8
# 466        46.0    VET     HARD      5  Monaco Grand Prix      5    8
# 467        47.0    VET     HARD      5  Monaco Grand Prix      5    8
# 468        48.0    VET     HARD      5  Monaco Grand Prix      5    8
# 469        49.0    VET     HARD      5  Monaco Grand Prix      5    8
# 470        50.0    VET     HARD      5  Monaco Grand Prix      5    8
# 471        51.0    VET     HARD      5  Monaco Grand Prix      5    8
# 472        52.0    VET     HARD      5  Monaco Grand Prix      5    8
# 473        53.0    VET     HARD      5  Monaco Grand Prix      5    8
# 474        54.0    VET     HARD      5  Monaco Grand Prix      5    8
# 475        55.0    VET     HARD      5  Monaco Grand Prix      5    8
# 476        56.0    VET     HARD      5  Monaco Grand Prix      5    8
# 477        57.0    VET     HARD      5  Monaco Grand Prix      5    8
# 478        58.0    VET     HARD      5  Monaco Grand Prix      5    8
# 479        59.0    VET     HARD      5  Monaco Grand Prix      5    8
# 480        60.0    VET     HARD      5  Monaco Grand Prix      5    8
# 481        61.0    VET     HARD      5  Monaco Grand Prix      5    8
# 482        62.0    VET     HARD      5  Monaco Grand Prix      5    8
# 483        63.0    VET     HARD      5  Monaco Grand Prix      5    8
# 484        64.0    VET     HARD      5  Monaco Grand Prix      5    8
# 485        65.0    VET     HARD      5  Monaco Grand Prix      5    8
# 486        66.0    VET     HARD      5  Monaco Grand Prix      5    8
# 487        67.0    VET     HARD      5  Monaco Grand Prix      5    8
# 488        68.0    VET     HARD      5  Monaco Grand Prix      5    8
# 489        69.0    VET     HARD      5  Monaco Grand Prix      5    8
# 490        70.0    VET     HARD      5  Monaco Grand Prix      5    8
# 491        71.0    VET     HARD      5  Monaco Grand Prix      5    8
# 492        72.0    VET     HARD      5  Monaco Grand Prix      5    8
# 493        73.0    VET     HARD      5  Monaco Grand Prix      5    8
# 494        74.0    VET     HARD      5  Monaco Grand Prix      5    8
# 495        75.0    VET     HARD      5  Monaco Grand Prix      5    8
# 496        76.0    VET     HARD      5  Monaco Grand Prix      5    8
# 497        77.0    VET     HARD      5  Monaco Grand Prix      5    8
# 498        78.0    VET     HARD      5  Monaco Grand Prix      5    8
# 499         1.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 500         2.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 501         3.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 502         4.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 503         5.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 504         6.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 505         7.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 506         8.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 507         9.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 508        10.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 509        11.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 510        12.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 511        13.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 512        14.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 513        15.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 514        16.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 515        17.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 516        18.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 517        19.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 518        20.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 519        21.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 520        22.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 521        23.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 522        24.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 523        25.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 524        26.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 525        27.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 526        28.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 527        29.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 528        30.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 529        31.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 530        32.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 531        33.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 532        34.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 533        35.0    PER     SOFT     11  Monaco Grand Prix      5    9
# 534        36.0    PER     HARD     11  Monaco Grand Prix      5    9
# 535        37.0    PER     HARD     11  Monaco Grand Prix      5    9
# 536        38.0    PER     HARD     11  Monaco Grand Prix      5    9
# 537        39.0    PER     HARD     11  Monaco Grand Prix      5    9
# 538        40.0    PER     HARD     11  Monaco Grand Prix      5    9
# 539        41.0    PER     HARD     11  Monaco Grand Prix      5    9
# 540        42.0    PER     HARD     11  Monaco Grand Prix      5    9
# 541        43.0    PER     HARD     11  Monaco Grand Prix      5    9
# 542        44.0    PER     HARD     11  Monaco Grand Prix      5    9
# 543        45.0    PER     HARD     11  Monaco Grand Prix      5    9
# 544        46.0    PER     HARD     11  Monaco Grand Prix      5    9
# 545        47.0    PER     HARD     11  Monaco Grand Prix      5    9
# 546        48.0    PER     HARD     11  Monaco Grand Prix      5    9
# 547        49.0    PER     HARD     11  Monaco Grand Prix      5    9
# 548        50.0    PER     HARD     11  Monaco Grand Prix      5    9
# 549        51.0    PER     HARD     11  Monaco Grand Prix      5    9
# 550        52.0    PER     HARD     11  Monaco Grand Prix      5    9
# 551        53.0    PER     HARD     11  Monaco Grand Prix      5    9
# 552        54.0    PER     HARD     11  Monaco Grand Prix      5    9
# 553        55.0    PER     HARD     11  Monaco Grand Prix      5    9
# 554        56.0    PER     HARD     11  Monaco Grand Prix      5    9
# 555        57.0    PER     HARD     11  Monaco Grand Prix      5    9
# 556        58.0    PER     HARD     11  Monaco Grand Prix      5    9
# 557        59.0    PER     HARD     11  Monaco Grand Prix      5    9
# 558        60.0    PER     HARD     11  Monaco Grand Prix      5    9
# 559        61.0    PER     HARD     11  Monaco Grand Prix      5    9
# 560        62.0    PER     HARD     11  Monaco Grand Prix      5    9
# 561        63.0    PER     HARD     11  Monaco Grand Prix      5    9
# 562        64.0    PER     HARD     11  Monaco Grand Prix      5    9
# 563        65.0    PER     HARD     11  Monaco Grand Prix      5    9
# 564        66.0    PER     HARD     11  Monaco Grand Prix      5    9
# 565        67.0    PER     HARD     11  Monaco Grand Prix      5    9
# 566        68.0    PER     HARD     11  Monaco Grand Prix      5    9
# 567        69.0    PER     HARD     11  Monaco Grand Prix      5    9
# 568        70.0    PER     HARD     11  Monaco Grand Prix      5    9
# 569        71.0    PER     HARD     11  Monaco Grand Prix      5    9
# 570        72.0    PER     HARD     11  Monaco Grand Prix      5    9
# 571        73.0    PER     HARD     11  Monaco Grand Prix      5    9
# 572        74.0    PER     HARD     11  Monaco Grand Prix      5    9
# 573        75.0    PER     HARD     11  Monaco Grand Prix      5    9
# 574        76.0    PER     HARD     11  Monaco Grand Prix      5    9
# 575        77.0    PER     HARD     11  Monaco Grand Prix      5    9
# 576        78.0    PER     HARD     11  Monaco Grand Prix      5    9
# 577         1.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 578         2.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 579         3.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 580         4.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 581         5.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 582         6.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 583         7.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 584         8.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 585         9.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 586        10.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 587        11.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 588        12.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 589        13.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 590        14.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 591        15.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 592        16.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 593        17.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 594        18.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 595        19.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 596        20.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 597        21.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 598        22.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 599        23.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 600        24.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 601        25.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 602        26.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 603        27.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 604        28.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 605        29.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 606        30.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 607        31.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 608        32.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 609        33.0    GIO     SOFT     99  Monaco Grand Prix      5   10
# 610        34.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 611        35.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 612        36.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 613        37.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 614        38.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 615        39.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 616        40.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 617        41.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 618        42.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 619        43.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 620        44.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 621        45.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 622        46.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 623        47.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 624        48.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 625        49.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 626        50.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 627        51.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 628        52.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 629        53.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 630        54.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 631        55.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 632        56.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 633        57.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 634        58.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 635        59.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 636        60.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 637        61.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 638        62.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 639        63.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 640        64.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 641        65.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 642        66.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 643        67.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 644        68.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 645        69.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 646        70.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 647        71.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 648        72.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 649        73.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 650        74.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 651        75.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 652        76.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 653        77.0    GIO     HARD     99  Monaco Grand Prix      5   10
# 654         1.0    OCO     SOFT     31  Monaco Grand Prix      5   11
# 655         2.0    OCO     SOFT     31  Monaco Grand Prix      5   11
# ...
# 693              11
# 694              11
# 695              11
# 696              11
# 697              11
# 698              11
# 699              11
# 700              11
# 701              11
# 702              11
# 703              11
# 704              11
# 705              11
# 706              11
# 707              11
# 708              11
# 709              11
# 710              11
# 711              11
# 712              11
# 713              11
# 714              11
# 715              11
# 716              11
# 717              11
# 718              11
# 719              11
# 720              11
# 721              11
# 722              11
# 723              11
# 724              11
# 725              11
# 726              11
# 727              11
# 728              11
# 729              11
# 730              11
# 731              12
# 732              12
# 733              12
# 734              12
# 735              12
# 736              12
# 737              12
# 738              12
# 739              12
# 740              12
# 741              12
# 742              12
# 743              12
# 744              12
# 745              12
# 746              12
# 747              12
# 748              12
# 749              12
# 750              12
# 751              12
# 752              12
# 753              12
# 754              12
# 755              12
# 756              12
# 757              12
# 758              12
# 759              12
# 760              12
# 761              12
# 762              12
# 763              12
# 764              12
# 765              12
# 766              12
# 767              12
# 768              12
# 769              12
# 770              12
# 771              12
# 772              12
# 773              12
# 774              12
# 775              12
# 776              12
# 777              12
# 778              12
# 779              12
# 780              12
# 781              12
# 782              12
# 783              12
# 784              12
# 785              12
# 786              12
# 787              12
# 788              12
# 789              12
# 790              12
# 791              12
# 792              12
# 793              12
# 794              12
# 795              12
# 796              12
# 797              12
# 798              12
# 799              12
# 800              12
# 801              12
# 802              12
# 803              12
# 804              12
# 805              12
# 806              12
# 807              12
# 808              13
# 809              13
# 810              13
# 811              13
# 812              13
# 813              13
# 814              13
# 815              13
# 816              13
# 817              13
# 818              13
# 819              13
# 820              13
# 821              13
# 822              13
# 823              13
# 824              13
# 825              13
# 826              13
# 827              13
# 828              13
# 829              13
# 830              13
# 831              13
# 832              13
# 833              13
# 834              13
# 835              13
# 836              13
# 837              13
# 838              13
# 839              13
# 840              13
# 841              13
# 842              13
# 843              13
# 844              13
# 845              13
# 846              13
# 847              13
# 848              13
# 849              13
# 850              13
# 851              13
# 852              13
# 853              13
# 854              13
# 855              13
# 856              13
# 857              13
# 858              13
# 859              13
# 860              13
# 861              13
# 862              13
# 863              13
# 864              13
# 865              13
# 866              13
# 867              13
# 868              13
# 869              13
# 870              13
# 871              13
# 872              13
# 873              13
# 874              13
# 875              13
# 876              13
# 877              13
# 878              13
# 879              13
# 880              13
# 881              13
# 882              13
# 883              13
# 884              13
# 885              14
# 886              14
# 887              14
# 888              14
# 889              14
# 890              14
# 891              14
# 892              14
# 893              14
# 894              14
# 895              14
# 896              14
# 897              14
# 898              14
# 899              14
# 900              14
# 901              14
# 902              14
# 903              14
# 904              14
# 905              14
# 906              14
# 907              14
# 908              14
# 909              14
# 910              14
# 911              14
# 912              14
# 913              14
# 914              14
# 915              14
# 916              14
# 917              14
# 918              14
# 919              14
# 920              14
# 921              14
# 922              14
# 923              14
# 924              14
# 925              14
# 926              14
# 927              14
# 928              14
# 929              14
# 930              14
# 931              14
# 932              14
# 933              14
# 934              14
# 935              14
# 936              14
# 937              14
# 938              14
# 939              14
# 940              14
# 941              14
# 942              14
# 943              14
# 944              14
# 945              14
# 946              14
# 947              14
# 948              14
# 949              14
# 950              14
# 951              14
# 952              14
# 953              14
# 954              14
# 955              14
# 956              14
# 957              14
# 958              14
# 959              14
# 960              14
# 961              14
# 962              15
# 963              15
# 964              15
# 965              15
# 966              15
# 967              15
# 968              15
# 969              15
# 970              15
# 971              15
# 972              15
# 973              15
# 974              15
# 975              15
# 976              15
# 977              15
# 978              15
# 979              15
# 980              15
# 981              15
# 982              15
# 983              15
# 984              15
# 985              15
# 986              15
# 987              15
# 988              15
# 989              15
# 990              15
# 991              15
# 992              15
# 993              15
# 994              15
# 995              15
# 996              15
# 997              15
# 998              15
# 999              15
# 1000             15
# 1001             15
# 1002             15
# 1003             15
# 1004             15
# 1005             15
# 1006             15
# 1007             15
# 1008             15
# 1009             15
# 1010             15
# 1011             15
# 1012             15
# 1013             15
# 1014             15
# 1015             15
# 1016             15
# 1017             15
# 1018             15
# 1019             15
# 1020             15
# 1021             15
# 1022             15
# 1023             15
# 1024             15
# 1025             15
# 1026             15
# 1027             15
# 1028             15
# 1029             15
# 1030             15
# 1031             15
# 1032             15
# 1033             15
# 1034             15
# 1035             15
# 1036             15
# 1037             15
# 1038             15
# 1039             16
# 1040             16
# 1041             16
# 1042             16
# 1043             16
# 1044             16
# 1045             16
# 1046             16
# 1047             16
# 1048             16
# 1049             16
# 1050             16
# 1051             16
# 1052             16
# 1053             16
# 1054             16
# 1055             16
# 1056             16
# 1057             16
# 1058             16
# 1059             16
# 1060             16
# 1061             16
# 1062             16
# 1063             16
# 1064             16
# 1065             16
# 1066             16
# 1067             16
# 1068             16
# 1069             16
# 1070             16
# 1071             16
# 1072             16
# 1073             16
# 1074             16
# 1075             16
# 1076             16
# 1077             16
# 1078             16
# 1079             16
# 1080             16
# 1081             16
# 1082             16
# 1083             16
# 1084             16
# 1085             16
# 1086             16
# 1087             16
# 1088             16
# 1089             16
# 1090             16
# 1091             16
# 1092             16
# 1093             16
# 1094             16
# 1095             16
# 1096             16
# 1097             16
# 1098             16
# 1099             16
# 1100             16
# 1101             16
# 1102             16
# 1103             16
# 1104             16
# 1105             16
# 1106             16
# 1107             16
# 1108             16
# 1109             16
# 1110             16
# 1111             16
# 1112             16
# 1113             16
# 1114             16
# 1115             16
# 1116             17
# 1117             17
# 1118             17
# 1119             17
# 1120             17
# 1121             17
# 1122             17
# 1123             17
# 1124             17
# 1125             17
# 1126             17
# 1127             17
# 1128             17
# 1129             17
# 1130             17
# 1131             17
# 1132             17
# 1133             17
# 1134             17
# 1135             17
# 1136             17
# 1137             17
# 1138             17
# 1139             17
# 1140             17
# 1141             17
# 1142             17
# 1143             17
# 1144             17
# 1145             17
# 1146             17
# 1147             17
# 1148             17
# 1149             17
# 1150             17
# 1151             17
# 1152             17
# 1153             17
# 1154             17
# 1155             17
# 1156             17
# 1157             17
# 1158             17
# 1159             17
# 1160             17
# 1161             17
# 1162             17
# 1163             17
# 1164             17
# 1165             17
# 1166             17
# 1167             17
# 1168             17
# 1169             17
# 1170             17
# 1171             17
# 1172             17
# 1173             17
# 1174             17
# 1175             17
# 1176             17
# 1177             17
# 1178             17
# 1179             17
# 1180             17
# 1181             17
# 1182             17
# 1183             17
# 1184             17
# 1185             17
# 1186             17
# 1187             17
# 1188             17
# 1189             17
# 1190             17
# 1191             17
# 1192             17
# 1193             18
# 1194             18
# 1195             18
# 1196             18
# 1197             18
# 1198             18
# 1199             18
# 1200             18
# 1201             18
# 1202             18
# 1203             18
# 1204             18
# 1205             18
# 1206             18
# 1207             18
# 1208             18
# 1209             18
# 1210             18
# 1211             18
# 1212             18
# 1213             18
# 1214             18
# 1215             18
# 1216             18
# 1217             18
# 1218             18
# 1219             18
# 1220             18
# 1221             18
# 1222             18
# 1223             18
# 1224             18
# 1225             18
# 1226             18
# 1227             18
# 1228             18
# 1229             18
# 1230             18
# 1231             18
# 1232             18
# 1233             18
# 1234             18
# 1235             18
# 1236             18
# 1237             18
# 1238             18
# 1239             18
# 1240             18
# 1241             18
# 1242             18
# 1243             18
# 1244             18
# 1245             18
# 1246             18
# 1247             18
# 1248             18
# 1249             18
# 1250             18
# 1251             18
# 1252             18
# 1253             18
# 1254             18
# 1255             18
# 1256             18
# 1257             18
# 1258             18
# 1259             18
# 1260             18
# 1261             18
# 1262             18
# 1263             18
# 1264             18
# 1265             18
# 1266             18
# 1267             18
# 1268             18
# 1269             18
# 1270             19
# 1271             19
# 1272             19
# 1273             19
# 1274             19
# 1275             19
# 1276             19
# 1277             19
# 1278             19
# 1279             19
# 1280             19
# 1281             19
# 1282             19
# 1283             19
# 1284             19
# 1285             19
# 1286             19
# 1287             19
# 1288             19
# 1289             19
# 1290             19
# 1291             19
# 1292             19
# 1293             19
# 1294             19
# 1295             19
# 1296             19
# 1297             19
# 1298             19
# 1299             19
# 1300             19
# 1301             19
# 1302             19
# 1303             19
# 1304             19
# 1305             19
# 1306             19
# 1307             19
# 1308             19
# 1309             19
# 1310             19
# 1311             19
# 1312             19
# 1313             19
# 1314             19
# 1315             19
# 1316             19
# 1317             19
# 1318             19
# 1319             19
# 1320             19
# 1321             19
# 1322             19
# 1323             19
# 1324             19
# 1325             19
# 1326             19
# 1327             19
# 1328             19
# 1329             19
# 1330             19
# 1331             19
# 1332             19
# 1333             19
# 1334             19
# 1335             19
# 1336             19
# 1337             19
# 1338             19
# 1339             19
# 1340             19
# 1341             19
# 1342             19
# 1343             19
# 1344             19
# 1345           None
# 1346           None
# 1347           None
# 1348           None
# 1349           None
# 1350           None
# 1351           None
# 1352           None
# 1353           None
# 1354           None
# 1355           None
# 1356           None
# 1357           None
# 1358           None
# 1359           None
# 1360           None
# 1361           None
# 1362           None
# 1363           None
# 1364           None
# 1365           None
# 1366           None
# 1367           None
# 1368           None
# 1369           None
# 1370           None
# 1371           None
# 1372           None
# 1373           None
# 1374           None
# 1375           None
# 1376           None
# 1377           None
# 1378           None
# 1379           None
# 1380           None
# 1381           None
# 1382           None
# 1383           None
# 1384           None
# 1385           None
# 1386           None
# 1387           None
# 1388           None
# 1389           None
# 1390           None
# 1391           None
# 1392           None
# 1393           None
# 1394           None
# 1395           None
# 1396           None
# 1397           None
# 1398           None
# 1399           None
# 1400           None
# 1401           None
# 1402           None
# 1403           None
# 1404           None
# 1405           None
# 1406           None
# 1407           None
# 1408           None
# 1409           None
# 1410           None
# 1411           None
# 1412           None
# 1413           None
# 1414           None
# 1415           None
# 1416           None
# 1417           None
# 1418           None
# 1419           None

# %%
race2 = f1.get_session(2021,2,"R")
laps_2 = race2.load_laps(with_telemetry=True)
# Out:
# core           INFO 	Loading laps for Emilia Romagna Grand Prix - Race [v2.1.13]
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching car data...
# api            INFO 	Parsing car data...
# api            INFO 	Fetching position data...
# api            INFO 	Parsing position data...
# api            INFO 	Fetching weather data...
# core           INFO 	Loaded data for 20 drivers: ['3', '10', '9', '77', '33', '6', '5', '31', '63', '14', '22', '16', '7', '18', '11', '44', '99', '55', '47', '4']

# %%
laps_2_info = laps_2[["LapNumber","Driver","Compound","DriverNumber"]]
laps_info = laps[["LapNumber","Driver","Compound","DriverNumber"]]
laps_info
# Out:
#       LapNumber Driver Compound DriverNumber
# 0           1.0    VER   MEDIUM           33
# 1           2.0    VER   MEDIUM           33
# 2           3.0    VER   MEDIUM           33
# 3           4.0    VER   MEDIUM           33
# 4           5.0    VER   MEDIUM           33
# 5           6.0    VER   MEDIUM           33
# 6           7.0    VER   MEDIUM           33
# 7           8.0    VER   MEDIUM           33
# 8           9.0    VER   MEDIUM           33
# 9          10.0    VER   MEDIUM           33
# 10         11.0    VER   MEDIUM           33
# 11         12.0    VER   MEDIUM           33
# 12         13.0    VER   MEDIUM           33
# 13         14.0    VER   MEDIUM           33
# 14         15.0    VER   MEDIUM           33
# 15         16.0    VER   MEDIUM           33
# 16         17.0    VER   MEDIUM           33
# 17         18.0    VER   MEDIUM           33
# 18         19.0    VER   MEDIUM           33
# 19         20.0    VER   MEDIUM           33
# 20         21.0    VER   MEDIUM           33
# 21         22.0    VER   MEDIUM           33
# 22         23.0    VER   MEDIUM           33
# 23         24.0    VER   MEDIUM           33
# 24         25.0    VER   MEDIUM           33
# 25         26.0    VER   MEDIUM           33
# 26         27.0    VER   MEDIUM           33
# 27         28.0    VER   MEDIUM           33
# 28         29.0    VER   MEDIUM           33
# 29         30.0    VER   MEDIUM           33
# 30         31.0    VER   MEDIUM           33
# 31         32.0    VER   MEDIUM           33
# 32         33.0    VER   MEDIUM           33
# 33         34.0    VER   MEDIUM           33
# 34         35.0    VER   MEDIUM           33
# 35         36.0    VER   MEDIUM           33
# 36         37.0    VER   MEDIUM           33
# 37         38.0    VER   MEDIUM           33
# 38         39.0    VER   MEDIUM           33
# 39         40.0    VER     HARD           33
# 40         41.0    VER     HARD           33
# 41         42.0    VER     HARD           33
# 42         43.0    VER     HARD           33
# 43         44.0    VER     HARD           33
# 44         45.0    VER     HARD           33
# 45         46.0    VER     HARD           33
# 46         47.0    VER     HARD           33
# 47         48.0    VER     HARD           33
# 48         49.0    VER     HARD           33
# 49         50.0    VER     HARD           33
# 50         51.0    VER     HARD           33
# 51         52.0    VER     HARD           33
# 52         53.0    VER     HARD           33
# 53         54.0    VER     HARD           33
# 54         55.0    VER     HARD           33
# 55         56.0    VER     HARD           33
# 56          1.0    HAM   MEDIUM           44
# 57          2.0    HAM   MEDIUM           44
# 58          3.0    HAM   MEDIUM           44
# 59          4.0    HAM   MEDIUM           44
# 60          5.0    HAM   MEDIUM           44
# 61          6.0    HAM   MEDIUM           44
# 62          7.0    HAM   MEDIUM           44
# 63          8.0    HAM   MEDIUM           44
# 64          9.0    HAM   MEDIUM           44
# 65         10.0    HAM   MEDIUM           44
# 66         11.0    HAM   MEDIUM           44
# 67         12.0    HAM   MEDIUM           44
# 68         13.0    HAM   MEDIUM           44
# 69         14.0    HAM     HARD           44
# 70         15.0    HAM     HARD           44
# 71         16.0    HAM     HARD           44
# 72         17.0    HAM     HARD           44
# 73         18.0    HAM     HARD           44
# 74         19.0    HAM     HARD           44
# 75         20.0    HAM     HARD           44
# 76         21.0    HAM     HARD           44
# 77         22.0    HAM     HARD           44
# 78         23.0    HAM     HARD           44
# 79         24.0    HAM     HARD           44
# 80         25.0    HAM     HARD           44
# 81         26.0    HAM     HARD           44
# 82         27.0    HAM     HARD           44
# 83         28.0    HAM     HARD           44
# 84         29.0    HAM     HARD           44
# 85         30.0    HAM     HARD           44
# 86         31.0    HAM     HARD           44
# 87         32.0    HAM     HARD           44
# 88         33.0    HAM     HARD           44
# 89         34.0    HAM     HARD           44
# 90         35.0    HAM     HARD           44
# 91         36.0    HAM     HARD           44
# 92         37.0    HAM     HARD           44
# 93         38.0    HAM     HARD           44
# 94         39.0    HAM     HARD           44
# 95         40.0    HAM     HARD           44
# 96         41.0    HAM     HARD           44
# 97         42.0    HAM     HARD           44
# 98         43.0    HAM     HARD           44
# 99         44.0    HAM     HARD           44
# 100        45.0    HAM     HARD           44
# 101        46.0    HAM     HARD           44
# 102        47.0    HAM     HARD           44
# 103        48.0    HAM     HARD           44
# 104        49.0    HAM     HARD           44
# 105        50.0    HAM     HARD           44
# 106        51.0    HAM     HARD           44
# 107        52.0    HAM     HARD           44
# 108        53.0    HAM     HARD           44
# 109        54.0    HAM     HARD           44
# 110        55.0    HAM     HARD           44
# 111        56.0    HAM     HARD           44
# 112         1.0    BOT   MEDIUM           77
# 113         2.0    BOT   MEDIUM           77
# 114         3.0    BOT   MEDIUM           77
# 115         4.0    BOT   MEDIUM           77
# 116         5.0    BOT   MEDIUM           77
# 117         6.0    BOT   MEDIUM           77
# 118         7.0    BOT   MEDIUM           77
# 119         8.0    BOT   MEDIUM           77
# 120         9.0    BOT   MEDIUM           77
# 121        10.0    BOT   MEDIUM           77
# 122        11.0    BOT   MEDIUM           77
# 123        12.0    BOT   MEDIUM           77
# 124        13.0    BOT   MEDIUM           77
# 125        14.0    BOT   MEDIUM           77
# 126        15.0    BOT   MEDIUM           77
# 127        16.0    BOT   MEDIUM           77
# 128        17.0    BOT     HARD           77
# 129        18.0    BOT     HARD           77
# 130        19.0    BOT     HARD           77
# 131        20.0    BOT     HARD           77
# 132        21.0    BOT     HARD           77
# 133        22.0    BOT     HARD           77
# 134        23.0    BOT     HARD           77
# 135        24.0    BOT     HARD           77
# 136        25.0    BOT     HARD           77
# 137        26.0    BOT     HARD           77
# 138        27.0    BOT     HARD           77
# 139        28.0    BOT     HARD           77
# 140        29.0    BOT     HARD           77
# 141        30.0    BOT     HARD           77
# 142        31.0    BOT     HARD           77
# 143        32.0    BOT     HARD           77
# 144        33.0    BOT     HARD           77
# 145        34.0    BOT     HARD           77
# 146        35.0    BOT     HARD           77
# 147        36.0    BOT     HARD           77
# 148        37.0    BOT     HARD           77
# 149        38.0    BOT     HARD           77
# 150        39.0    BOT     HARD           77
# 151        40.0    BOT     HARD           77
# 152        41.0    BOT     HARD           77
# 153        42.0    BOT     HARD           77
# 154        43.0    BOT     HARD           77
# 155        44.0    BOT     HARD           77
# 156        45.0    BOT     HARD           77
# 157        46.0    BOT     HARD           77
# 158        47.0    BOT     HARD           77
# 159        48.0    BOT     HARD           77
# 160        49.0    BOT     HARD           77
# 161        50.0    BOT     HARD           77
# 162        51.0    BOT     HARD           77
# 163        52.0    BOT     HARD           77
# 164        53.0    BOT     HARD           77
# 165        54.0    BOT     HARD           77
# 166        55.0    BOT   MEDIUM           77
# 167        56.0    BOT   MEDIUM           77
# 168         1.0    LEC     SOFT           16
# 169         2.0    LEC     SOFT           16
# 170         3.0    LEC     SOFT           16
# 171         4.0    LEC     SOFT           16
# 172         5.0    LEC     SOFT           16
# 173         6.0    LEC     SOFT           16
# 174         7.0    LEC     SOFT           16
# 175         8.0    LEC     SOFT           16
# 176         9.0    LEC     SOFT           16
# 177        10.0    LEC     SOFT           16
# 178        11.0    LEC     SOFT           16
# 179        12.0    LEC     SOFT           16
# 180        13.0    LEC   MEDIUM           16
# 181        14.0    LEC   MEDIUM           16
# 182        15.0    LEC   MEDIUM           16
# 183        16.0    LEC   MEDIUM           16
# 184        17.0    LEC   MEDIUM           16
# 185        18.0    LEC   MEDIUM           16
# 186        19.0    LEC   MEDIUM           16
# 187        20.0    LEC   MEDIUM           16
# 188        21.0    LEC   MEDIUM           16
# 189        22.0    LEC   MEDIUM           16
# 190        23.0    LEC   MEDIUM           16
# 191        24.0    LEC   MEDIUM           16
# 192        25.0    LEC   MEDIUM           16
# 193        26.0    LEC   MEDIUM           16
# 194        27.0    LEC   MEDIUM           16
# 195        28.0    LEC   MEDIUM           16
# 196        29.0    LEC   MEDIUM           16
# 197        30.0    LEC   MEDIUM           16
# 198        31.0    LEC   MEDIUM           16
# 199        32.0    LEC   MEDIUM           16
# 200        33.0    LEC     HARD           16
# 201        34.0    LEC     HARD           16
# 202        35.0    LEC     HARD           16
# 203        36.0    LEC     HARD           16
# 204        37.0    LEC     HARD           16
# 205        38.0    LEC     HARD           16
# 206        39.0    LEC     HARD           16
# 207        40.0    LEC     HARD           16
# 208        41.0    LEC     HARD           16
# 209        42.0    LEC     HARD           16
# 210        43.0    LEC     HARD           16
# 211        44.0    LEC     HARD           16
# 212        45.0    LEC     HARD           16
# 213        46.0    LEC     HARD           16
# 214        47.0    LEC     HARD           16
# 215        48.0    LEC     HARD           16
# 216        49.0    LEC     HARD           16
# 217        50.0    LEC     HARD           16
# 218        51.0    LEC     HARD           16
# 219        52.0    LEC     HARD           16
# 220        53.0    LEC     HARD           16
# 221        54.0    LEC     HARD           16
# 222        55.0    LEC     HARD           16
# 223        56.0    LEC     HARD           16
# 224         1.0    GAS   MEDIUM           10
# 225         2.0    GAS   MEDIUM           10
# 226         3.0    GAS   MEDIUM           10
# 227         4.0    GAS   MEDIUM           10
# 228         5.0    GAS     HARD           10
# 229         6.0    GAS     HARD           10
# 230         7.0    GAS     HARD           10
# 231         8.0    GAS     HARD           10
# 232         9.0    GAS     HARD           10
# 233        10.0    GAS     HARD           10
# 234        11.0    GAS     HARD           10
# 235        12.0    GAS     HARD           10
# 236        13.0    GAS     HARD           10
# 237        14.0    GAS     HARD           10
# 238        15.0    GAS     HARD           10
# 239        16.0    GAS     HARD           10
# 240        17.0    GAS     HARD           10
# 241        18.0    GAS     HARD           10
# 242        19.0    GAS     HARD           10
# 243        20.0    GAS   MEDIUM           10
# 244        21.0    GAS   MEDIUM           10
# 245        22.0    GAS   MEDIUM           10
# 246        23.0    GAS   MEDIUM           10
# 247        24.0    GAS   MEDIUM           10
# 248        25.0    GAS   MEDIUM           10
# 249        26.0    GAS   MEDIUM           10
# 250        27.0    GAS   MEDIUM           10
# 251        28.0    GAS   MEDIUM           10
# 252        29.0    GAS   MEDIUM           10
# 253        30.0    GAS   MEDIUM           10
# 254        31.0    GAS   MEDIUM           10
# 255        32.0    GAS   MEDIUM           10
# 256        33.0    GAS   MEDIUM           10
# 257        34.0    GAS   MEDIUM           10
# 258        35.0    GAS   MEDIUM           10
# 259        36.0    GAS   MEDIUM           10
# 260        37.0    GAS   MEDIUM           10
# 261        38.0    GAS   MEDIUM           10
# 262        39.0    GAS   MEDIUM           10
# 263        40.0    GAS     HARD           10
# 264        41.0    GAS     HARD           10
# 265        42.0    GAS     HARD           10
# 266        43.0    GAS     HARD           10
# 267        44.0    GAS     HARD           10
# 268        45.0    GAS     HARD           10
# 269        46.0    GAS     HARD           10
# 270        47.0    GAS     HARD           10
# 271        48.0    GAS     HARD           10
# 272        49.0    GAS     HARD           10
# 273        50.0    GAS     HARD           10
# 274        51.0    GAS     HARD           10
# 275        52.0    GAS     HARD           10
# 276         1.0    RIC     SOFT            3
# 277         2.0    RIC     SOFT            3
# 278         3.0    RIC     SOFT            3
# 279         4.0    RIC     SOFT            3
# 280         5.0    RIC     SOFT            3
# 281         6.0    RIC     SOFT            3
# 282         7.0    RIC     SOFT            3
# 283         8.0    RIC     SOFT            3
# 284         9.0    RIC     SOFT            3
# 285        10.0    RIC     SOFT            3
# 286        11.0    RIC     SOFT            3
# 287        12.0    RIC     SOFT            3
# 288        13.0    RIC     SOFT            3
# 289        14.0    RIC   MEDIUM            3
# 290        15.0    RIC   MEDIUM            3
# 291        16.0    RIC   MEDIUM            3
# 292        17.0    RIC   MEDIUM            3
# 293        18.0    RIC   MEDIUM            3
# 294        19.0    RIC   MEDIUM            3
# 295        20.0    RIC   MEDIUM            3
# 296        21.0    RIC   MEDIUM            3
# 297        22.0    RIC   MEDIUM            3
# 298        23.0    RIC   MEDIUM            3
# 299        24.0    RIC   MEDIUM            3
# 300        25.0    RIC   MEDIUM            3
# 301        26.0    RIC   MEDIUM            3
# 302        27.0    RIC   MEDIUM            3
# 303        28.0    RIC   MEDIUM            3
# 304        29.0    RIC   MEDIUM            3
# 305        30.0    RIC   MEDIUM            3
# 306        31.0    RIC   MEDIUM            3
# 307        32.0    RIC   MEDIUM            3
# 308        33.0    RIC     HARD            3
# 309        34.0    RIC     HARD            3
# 310        35.0    RIC     HARD            3
# 311        36.0    RIC     HARD            3
# 312        37.0    RIC     HARD            3
# 313        38.0    RIC     HARD            3
# 314        39.0    RIC     HARD            3
# 315        40.0    RIC     HARD            3
# 316        41.0    RIC     HARD            3
# 317        42.0    RIC     HARD            3
# 318        43.0    RIC     HARD            3
# 319        44.0    RIC     HARD            3
# 320        45.0    RIC     HARD            3
# 321        46.0    RIC     HARD            3
# 322        47.0    RIC     HARD            3
# 323        48.0    RIC     HARD            3
# 324        49.0    RIC     HARD            3
# 325        50.0    RIC     HARD            3
# 326        51.0    RIC     HARD            3
# 327        52.0    RIC     HARD            3
# 328        53.0    RIC     HARD            3
# 329        54.0    RIC     HARD            3
# 330        55.0    RIC     HARD            3
# 331        56.0    RIC     HARD            3
# 332         1.0    NOR     SOFT            4
# 333         2.0    NOR     SOFT            4
# 334         3.0    NOR     SOFT            4
# 335         4.0    NOR     SOFT            4
# 336         5.0    NOR     SOFT            4
# 337         6.0    NOR     SOFT            4
# 338         7.0    NOR     SOFT            4
# 339         8.0    NOR     SOFT            4
# 340         9.0    NOR     SOFT            4
# 341        10.0    NOR     SOFT            4
# 342        11.0    NOR     SOFT            4
# 343        12.0    NOR     SOFT            4
# 344        13.0    NOR   MEDIUM            4
# 345        14.0    NOR   MEDIUM            4
# 346        15.0    NOR   MEDIUM            4
# 347        16.0    NOR   MEDIUM            4
# 348        17.0    NOR   MEDIUM            4
# 349        18.0    NOR   MEDIUM            4
# 350        19.0    NOR   MEDIUM            4
# 351        20.0    NOR   MEDIUM            4
# 352        21.0    NOR   MEDIUM            4
# 353        22.0    NOR   MEDIUM            4
# 354        23.0    NOR   MEDIUM            4
# 355        24.0    NOR   MEDIUM            4
# 356        25.0    NOR   MEDIUM            4
# 357        26.0    NOR   MEDIUM            4
# 358        27.0    NOR   MEDIUM            4
# 359        28.0    NOR   MEDIUM            4
# 360        29.0    NOR   MEDIUM            4
# 361        30.0    NOR   MEDIUM            4
# 362        31.0    NOR   MEDIUM            4
# 363        32.0    NOR   MEDIUM            4
# 364        33.0    NOR   MEDIUM            4
# 365        34.0    NOR     HARD            4
# 366        35.0    NOR     HARD            4
# 367        36.0    NOR     HARD            4
# 368        37.0    NOR     HARD            4
# 369        38.0    NOR     HARD            4
# 370        39.0    NOR     HARD            4
# 371        40.0    NOR     HARD            4
# 372        41.0    NOR     HARD            4
# 373        42.0    NOR     HARD            4
# 374        43.0    NOR     HARD            4
# 375        44.0    NOR     HARD            4
# 376        45.0    NOR     HARD            4
# 377        46.0    NOR     HARD            4
# 378        47.0    NOR     HARD            4
# 379        48.0    NOR     HARD            4
# 380        49.0    NOR     HARD            4
# 381        50.0    NOR     HARD            4
# 382        51.0    NOR     HARD            4
# 383        52.0    NOR     HARD            4
# 384        53.0    NOR     HARD            4
# 385        54.0    NOR     HARD            4
# 386        55.0    NOR     HARD            4
# 387        56.0    NOR     HARD            4
# 388         1.0    SAI     SOFT           55
# 389         2.0    SAI     SOFT           55
# 390         3.0    SAI     SOFT           55
# 391         4.0    SAI     SOFT           55
# 392         5.0    SAI     SOFT           55
# 393         6.0    SAI     SOFT           55
# 394         7.0    SAI     SOFT           55
# 395         8.0    SAI     SOFT           55
# 396         9.0    SAI     SOFT           55
# 397        10.0    SAI     SOFT           55
# 398        11.0    SAI     SOFT           55
# 399        12.0    SAI     SOFT           55
# 400        13.0    SAI     SOFT           55
# 401        14.0    SAI     SOFT           55
# 402        15.0    SAI     SOFT           55
# 403        16.0    SAI   MEDIUM           55
# 404        17.0    SAI   MEDIUM           55
# 405        18.0    SAI   MEDIUM           55
# 406        19.0    SAI   MEDIUM           55
# 407        20.0    SAI   MEDIUM           55
# 408        21.0    SAI   MEDIUM           55
# 409        22.0    SAI   MEDIUM           55
# 410        23.0    SAI   MEDIUM           55
# 411        24.0    SAI   MEDIUM           55
# 412        25.0    SAI   MEDIUM           55
# 413        26.0    SAI   MEDIUM           55
# 414        27.0    SAI   MEDIUM           55
# 415        28.0    SAI   MEDIUM           55
# 416        29.0    SAI   MEDIUM           55
# 417        30.0    SAI   MEDIUM           55
# 418        31.0    SAI   MEDIUM           55
# 419        32.0    SAI   MEDIUM           55
# 420        33.0    SAI   MEDIUM           55
# 421        34.0    SAI   MEDIUM           55
# 422        35.0    SAI   MEDIUM           55
# 423        36.0    SAI   MEDIUM           55
# 424        37.0    SAI   MEDIUM           55
# 425        38.0    SAI     HARD           55
# 426        39.0    SAI     HARD           55
# 427        40.0    SAI     HARD           55
# 428        41.0    SAI     HARD           55
# 429        42.0    SAI     HARD           55
# 430        43.0    SAI     HARD           55
# 431        44.0    SAI     HARD           55
# 432        45.0    SAI     HARD           55
# 433        46.0    SAI     HARD           55
# 434        47.0    SAI     HARD           55
# 435        48.0    SAI     HARD           55
# 436        49.0    SAI     HARD           55
# 437        50.0    SAI     HARD           55
# 438        51.0    SAI     HARD           55
# 439        52.0    SAI     HARD           55
# 440        53.0    SAI     HARD           55
# 441        54.0    SAI     HARD           55
# 442        55.0    SAI     HARD           55
# 443        56.0    SAI     HARD           55
# 444         1.0    ALO     SOFT           14
# 445         2.0    ALO     SOFT           14
# 446         3.0    ALO     SOFT           14
# 447         4.0    ALO     SOFT           14
# 448         5.0    ALO     SOFT           14
# 449         6.0    ALO     SOFT           14
# 450         7.0    ALO     SOFT           14
# 451         8.0    ALO     SOFT           14
# 452         9.0    ALO     SOFT           14
# 453        10.0    ALO     SOFT           14
# 454        11.0    ALO     SOFT           14
# 455        12.0    ALO   MEDIUM           14
# 456        13.0    ALO   MEDIUM           14
# 457        14.0    ALO   MEDIUM           14
# 458        15.0    ALO   MEDIUM           14
# 459        16.0    ALO   MEDIUM           14
# 460        17.0    ALO   MEDIUM           14
# 461        18.0    ALO   MEDIUM           14
# 462        19.0    ALO   MEDIUM           14
# 463        20.0    ALO   MEDIUM           14
# 464        21.0    ALO   MEDIUM           14
# 465        22.0    ALO   MEDIUM           14
# 466        23.0    ALO   MEDIUM           14
# 467        24.0    ALO   MEDIUM           14
# 468        25.0    ALO   MEDIUM           14
# 469        26.0    ALO   MEDIUM           14
# 470        27.0    ALO   MEDIUM           14
# 471        28.0    ALO   MEDIUM           14
# 472        29.0    ALO   MEDIUM           14
# 473        30.0    ALO     HARD           14
# 474        31.0    ALO     HARD           14
# 475        32.0    ALO     HARD           14
# 476         1.0    STR     SOFT           18
# 477         2.0    STR     SOFT           18
# 478         3.0    STR     SOFT           18
# 479         4.0    STR     SOFT           18
# 480         5.0    STR     SOFT           18
# 481         6.0    STR     SOFT           18
# 482         7.0    STR     SOFT           18
# 483         8.0    STR     SOFT           18
# 484         9.0    STR     SOFT           18
# 485        10.0    STR     SOFT           18
# 486        11.0    STR     SOFT           18
# 487        12.0    STR     SOFT           18
# 488        13.0    STR   MEDIUM           18
# 489        14.0    STR   MEDIUM           18
# 490        15.0    STR   MEDIUM           18
# 491        16.0    STR   MEDIUM           18
# 492        17.0    STR   MEDIUM           18
# 493        18.0    STR   MEDIUM           18
# 494        19.0    STR   MEDIUM           18
# 495        20.0    STR   MEDIUM           18
# 496        21.0    STR   MEDIUM           18
# 497        22.0    STR   MEDIUM           18
# 498        23.0    STR   MEDIUM           18
# 499        24.0    STR   MEDIUM           18
# 500        25.0    STR   MEDIUM           18
# 501        26.0    STR   MEDIUM           18
# 502        27.0    STR   MEDIUM           18
# 503        28.0    STR   MEDIUM           18
# 504        29.0    STR  UNKNOWN           18
# 505        30.0    STR     HARD           18
# 506        31.0    STR     HARD           18
# 507        32.0    STR     HARD           18
# 508        33.0    STR     HARD           18
# 509        34.0    STR     HARD           18
# 510        35.0    STR     HARD           18
# 511        36.0    STR     HARD           18
# 512        37.0    STR     HARD           18
# 513        38.0    STR     HARD           18
# 514        39.0    STR     HARD           18
# 515        40.0    STR     HARD           18
# 516        41.0    STR     HARD           18
# 517        42.0    STR     HARD           18
# 518        43.0    STR     HARD           18
# 519        44.0    STR     HARD           18
# 520        45.0    STR     HARD           18
# 521        46.0    STR     HARD           18
# 522        47.0    STR     HARD           18
# 523        48.0    STR     HARD           18
# 524        49.0    STR     HARD           18
# 525        50.0    STR     HARD           18
# 526        51.0    STR     HARD           18
# 527        52.0    STR     HARD           18
# 528        53.0    STR     HARD           18
# 529        54.0    STR     HARD           18
# 530        55.0    STR     HARD           18
# 531        56.0    STR     HARD           18
# 532         1.0    PER   MEDIUM           11
# 533         2.0    PER   MEDIUM           11
# 534         3.0    PER   MEDIUM           11
# 535         4.0    PER   MEDIUM           11
# 536         5.0    PER   MEDIUM           11
# 537         6.0    PER   MEDIUM           11
# 538         7.0    PER   MEDIUM           11
# 539         8.0    PER   MEDIUM           11
# 540         9.0    PER   MEDIUM           11
# 541        10.0    PER   MEDIUM           11
# 542        11.0    PER   MEDIUM           11
# 543        12.0    PER   MEDIUM           11
# 544        13.0    PER   MEDIUM           11
# 545        14.0    PER   MEDIUM           11
# 546        15.0    PER   MEDIUM           11
# 547        16.0    PER   MEDIUM           11
# 548        17.0    PER   MEDIUM           11
# 549        18.0    PER   MEDIUM           11
# 550        19.0    PER   MEDIUM           11
# 551        20.0    PER     HARD           11
# 552        21.0    PER     HARD           11
# 553        22.0    PER     HARD           11
# 554        23.0    PER     HARD           11
# 555        24.0    PER     HARD           11
# 556        25.0    PER     HARD           11
# 557        26.0    PER     HARD           11
# 558        27.0    PER     HARD           11
# 559        28.0    PER     HARD           11
# 560        29.0    PER     HARD           11
# 561        30.0    PER     HARD           11
# 562        31.0    PER     HARD           11
# 563        32.0    PER     HARD           11
# 564        33.0    PER     HARD           11
# 565        34.0    PER     HARD           11
# 566        35.0    PER     HARD           11
# 567        36.0    PER     HARD           11
# 568        37.0    PER     HARD           11
# 569        38.0    PER     HARD           11
# 570        39.0    PER   MEDIUM           11
# 571        40.0    PER   MEDIUM           11
# 572        41.0    PER   MEDIUM           11
# 573        42.0    PER   MEDIUM           11
# 574        43.0    PER   MEDIUM           11
# 575        44.0    PER   MEDIUM           11
# 576        45.0    PER   MEDIUM           11
# 577        46.0    PER   MEDIUM           11
# 578        47.0    PER   MEDIUM           11
# 579        48.0    PER   MEDIUM           11
# 580        49.0    PER   MEDIUM           11
# 581        50.0    PER   MEDIUM           11
# 582        51.0    PER   MEDIUM           11
# 583        52.0    PER   MEDIUM           11
# 584        53.0    PER   MEDIUM           11
# 585        54.0    PER   MEDIUM           11
# 586        55.0    PER   MEDIUM           11
# 587        56.0    PER   MEDIUM           11
# 588         1.0    GIO   MEDIUM           99
# 589         2.0    GIO   MEDIUM           99
# 590         3.0    GIO   MEDIUM           99
# 591         4.0    GIO   MEDIUM           99
# 592         5.0    GIO   MEDIUM           99
# 593         6.0    GIO   MEDIUM           99
# 594         7.0    GIO   MEDIUM           99
# 595         8.0    GIO   MEDIUM           99
# 596         9.0    GIO   MEDIUM           99
# 597        10.0    GIO   MEDIUM           99
# 598        11.0    GIO   MEDIUM           99
# 599        12.0    GIO   MEDIUM           99
# 600        13.0    GIO     HARD           99
# 601        14.0    GIO     HARD           99
# 602        15.0    GIO     HARD           99
# 603        16.0    GIO     HARD           99
# 604        17.0    GIO     HARD           99
# 605        18.0    GIO     HARD           99
# 606        19.0    GIO     HARD           99
# 607        20.0    GIO     HARD           99
# 608        21.0    GIO     HARD           99
# 609        22.0    GIO     HARD           99
# 610        23.0    GIO     HARD           99
# 611        24.0    GIO     HARD           99
# 612        25.0    GIO     HARD           99
# 613        26.0    GIO     HARD           99
# 614        27.0    GIO     HARD           99
# 615        28.0    GIO     HARD           99
# 616        29.0    GIO     HARD           99
# 617        30.0    GIO     HARD           99
# 618        31.0    GIO   MEDIUM           99
# 619        32.0    GIO   MEDIUM           99
# 620        33.0    GIO   MEDIUM           99
# 621        34.0    GIO   MEDIUM           99
# 622        35.0    GIO   MEDIUM           99
# 623        36.0    GIO   MEDIUM           99
# 624        37.0    GIO   MEDIUM           99
# 625        38.0    GIO   MEDIUM           99
# 626        39.0    GIO   MEDIUM           99
# 627        40.0    GIO   MEDIUM           99
# 628        41.0    GIO   MEDIUM           99
# 629        42.0    GIO   MEDIUM           99
# 630        43.0    GIO   MEDIUM           99
# 631        44.0    GIO   MEDIUM           99
# 632        45.0    GIO   MEDIUM           99
# 633        46.0    GIO   MEDIUM           99
# 634        47.0    GIO   MEDIUM           99
# 635        48.0    GIO   MEDIUM           99
# 636        49.0    GIO   MEDIUM           99
# 637        50.0    GIO   MEDIUM           99
# 638        51.0    GIO   MEDIUM           99
# 639        52.0    GIO   MEDIUM           99
# 640        53.0    GIO   MEDIUM           99
# 641        54.0    GIO   MEDIUM           99
# 642        55.0    GIO   MEDIUM           99
# 643         1.0    TSU   MEDIUM           22
# 644         2.0    TSU   MEDIUM           22
# 645         3.0    TSU   MEDIUM           22
# 646         4.0    TSU   MEDIUM           22
# 647         5.0    TSU   MEDIUM           22
# 648         6.0    TSU   MEDIUM           22
# 649         7.0    TSU   MEDIUM           22
# 650         8.0    TSU   MEDIUM           22
# 651         9.0    TSU   MEDIUM           22
# 652        10.0    TSU   MEDIUM           22
# 653        11.0    TSU   MEDIUM           22
# 654        12.0    TSU   MEDIUM           22
# 655        13.0    TSU   MEDIUM           22
# 656        14.0    TSU   MEDIUM           22
# 657        15.0    TSU   MEDIUM           22
# 658        16.0    TSU     HARD           22
# 659        17.0    TSU     HARD           22
# 660        18.0    TSU     HARD           22
# 661        19.0    TSU     HARD           22
# 662        20.0    TSU     HARD           22
# 663        21.0    TSU     HARD           22
# 664        22.0    TSU     HARD           22
# 665        23.0    TSU     HARD           22
# 666        24.0    TSU     HARD           22
# 667        25.0    TSU     HARD           22
# 668        26.0    TSU     HARD           22
# 669        27.0    TSU     HARD           22
# 670        28.0    TSU     HARD           22
# 671        29.0    TSU     HARD           22
# 672        30.0    TSU     HARD           22
# 673        31.0    TSU     HARD           22
# 674        32.0    TSU     HARD           22
# 675        33.0    TSU     HARD           22
# 676        34.0    TSU     HARD           22
# 677        35.0    TSU     HARD           22
# 678        36.0    TSU     HARD           22
# 679        37.0    TSU     HARD           22
# 680        38.0    TSU     HARD           22
# 681        39.0    TSU     HARD           22
# 682        40.0    TSU     HARD           22
# 683        41.0    TSU     HARD           22
# 684        42.0    TSU     HARD           22
# 685        43.0    TSU     HARD           22
# 686        44.0    TSU     HARD           22
# 687        45.0    TSU     HARD           22
# 688        46.0    TSU     HARD           22
# 689        47.0    TSU     HARD           22
# 690        48.0    TSU     HARD           22
# 691        49.0    TSU     HARD           22
# 692        50.0    TSU     HARD           22
# 693        51.0    TSU     HARD           22
# 694        52.0    TSU     HARD           22
# 695        53.0    TSU     HARD           22
# 696        54.0    TSU     HARD           22
# 697        55.0    TSU     HARD           22
# 698        56.0    TSU     HARD           22
# 699         1.0    RAI   MEDIUM            7
# 700         2.0    RAI   MEDIUM            7
# 701         3.0    RAI   MEDIUM            7
# 702         4.0    RAI   MEDIUM            7
# 703         5.0    RAI   MEDIUM            7
# 704         6.0    RAI   MEDIUM            7
# 705         7.0    RAI   MEDIUM            7
# 706         8.0    RAI   MEDIUM            7
# 707         9.0    RAI   MEDIUM            7
# 708        10.0    RAI   MEDIUM            7
# 709        11.0    RAI   MEDIUM            7
# 710        12.0    RAI   MEDIUM            7
# 711        13.0    RAI   MEDIUM            7
# 712        14.0    RAI     HARD            7
# 713        15.0    RAI     HARD            7
# 714        16.0    RAI     HARD            7
# 715        17.0    RAI     HARD            7
# 716        18.0    RAI     HARD            7
# 717        19.0    RAI     HARD            7
# 718        20.0    RAI     HARD            7
# 719        21.0    RAI     HARD            7
# 720        22.0    RAI     HARD            7
# 721        23.0    RAI     HARD            7
# 722        24.0    RAI     HARD            7
# 723        25.0    RAI     HARD            7
# 724        26.0    RAI     HARD            7
# 725        27.0    RAI     HARD            7
# 726        28.0    RAI     HARD            7
# 727        29.0    RAI     HARD            7
# 728        30.0    RAI   MEDIUM            7
# 729        31.0    RAI   MEDIUM            7
# 730        32.0    RAI   MEDIUM            7
# 731        33.0    RAI   MEDIUM            7
# 732        34.0    RAI   MEDIUM            7
# 733        35.0    RAI   MEDIUM            7
# 734        36.0    RAI   MEDIUM            7
# 735        37.0    RAI   MEDIUM            7
# 736        38.0    RAI   MEDIUM            7
# 737        39.0    RAI   MEDIUM            7
# 738        40.0    RAI   MEDIUM            7
# 739        41.0    RAI   MEDIUM            7
# 740        42.0    RAI   MEDIUM            7
# 741        43.0    RAI   MEDIUM            7
# 742        44.0    RAI   MEDIUM            7
# 743        45.0    RAI   MEDIUM            7
# 744        46.0    RAI   MEDIUM            7
# 745        47.0    RAI   MEDIUM            7
# 746        48.0    RAI   MEDIUM            7
# 747        49.0    RAI   MEDIUM            7
# 748        50.0    RAI   MEDIUM            7
# 749        51.0    RAI   MEDIUM            7
# 750        52.0    RAI   MEDIUM            7
# 751        53.0    RAI   MEDIUM            7
# 752        54.0    RAI   MEDIUM            7
# 753        55.0    RAI   MEDIUM            7
# 754        56.0    RAI   MEDIUM            7
# 755         1.0    RUS     SOFT           63
# 756         2.0    RUS     SOFT           63
# 757         3.0    RUS     SOFT           63
# 758         4.0    RUS     SOFT           63
# 759         5.0    RUS     SOFT           63
# 760         6.0    RUS     SOFT           63
# 761         7.0    RUS     SOFT           63
# 762         8.0    RUS     SOFT           63
# 763         9.0    RUS     SOFT           63
# 764        10.0    RUS     SOFT           63
# 765        11.0    RUS     SOFT           63
# 766        12.0    RUS     SOFT           63
# 767        13.0    RUS     SOFT           63
# 768        14.0    RUS   MEDIUM           63
# 769        15.0    RUS   MEDIUM           63
# 770        16.0    RUS   MEDIUM           63
# 771        17.0    RUS   MEDIUM           63
# 772        18.0    RUS   MEDIUM           63
# 773        19.0    RUS   MEDIUM           63
# 774        20.0    RUS   MEDIUM           63
# 775        21.0    RUS   MEDIUM           63
# 776        22.0    RUS   MEDIUM           63
# 777        23.0    RUS   MEDIUM           63
# 778        24.0    RUS   MEDIUM           63
# 779        25.0    RUS   MEDIUM           63
# 780        26.0    RUS   MEDIUM           63
# 781        27.0    RUS   MEDIUM           63
# 782        28.0    RUS   MEDIUM           63
# 783        29.0    RUS   MEDIUM           63
# 784        30.0    RUS   MEDIUM           63
# 785        31.0    RUS   MEDIUM           63
# 786        32.0    RUS   MEDIUM           63
# 787        33.0    RUS   MEDIUM           63
# 788        34.0    RUS   MEDIUM           63
# 789        35.0    RUS   MEDIUM           63
# 790        36.0    RUS   MEDIUM           63
# 791        37.0    RUS   MEDIUM           63
# 792        38.0    RUS   MEDIUM           63
# 793        39.0    RUS   MEDIUM           63
# 794        40.0    RUS   MEDIUM           63
# 795        41.0    RUS   MEDIUM           63
# 796        42.0    RUS   MEDIUM           63
# 797        43.0    RUS   MEDIUM           63
# 798        44.0    RUS   MEDIUM           63
# 799        45.0    RUS   MEDIUM           63
# 800        46.0    RUS   MEDIUM           63
# 801        47.0    RUS   MEDIUM           63
# 802        48.0    RUS   MEDIUM           63
# 803        49.0    RUS   MEDIUM           63
# 804        50.0    RUS   MEDIUM           63
# 805        51.0    RUS   MEDIUM           63
# 806        52.0    RUS   MEDIUM           63
# 807        53.0    RUS   MEDIUM           63
# 808        54.0    RUS   MEDIUM           63
# 809        55.0    RUS   MEDIUM           63
# 810         1.0    OCO     SOFT           31
# 811         2.0    OCO     SOFT           31
# 812         3.0    OCO     SOFT           31
# 813         4.0    OCO     SOFT           31
# 814         5.0    OCO     SOFT           31
# 815         6.0    OCO     SOFT           31
# 816         7.0    OCO     SOFT           31
# 817         8.0    OCO     SOFT           31
# 818         9.0    OCO     SOFT           31
# 819        10.0    OCO     SOFT           31
# 820        11.0    OCO     SOFT           31
# 821        12.0    OCO     SOFT           31
# 822        13.0    OCO     SOFT           31
# 823        14.0    OCO   MEDIUM           31
# 824        15.0    OCO   MEDIUM           31
# 825        16.0    OCO   MEDIUM           31
# 826        17.0    OCO   MEDIUM           31
# 827        18.0    OCO   MEDIUM           31
# 828        19.0    OCO   MEDIUM           31
# 829        20.0    OCO   MEDIUM           31
# 830        21.0    OCO   MEDIUM           31
# 831        22.0    OCO   MEDIUM           31
# 832        23.0    OCO   MEDIUM           31
# 833        24.0    OCO   MEDIUM           31
# 834        25.0    OCO   MEDIUM           31
# 835        26.0    OCO   MEDIUM           31
# 836        27.0    OCO   MEDIUM           31
# 837        28.0    OCO   MEDIUM           31
# 838        29.0    OCO   MEDIUM           31
# 839        30.0    OCO   MEDIUM           31
# 840        31.0    OCO   MEDIUM           31
# 841        32.0    OCO     HARD           31
# 842        33.0    OCO     HARD           31
# 843        34.0    OCO     HARD           31
# 844        35.0    OCO     HARD           31
# 845        36.0    OCO     HARD           31
# 846        37.0    OCO     HARD           31
# 847        38.0    OCO     HARD           31
# 848        39.0    OCO     HARD           31
# 849        40.0    OCO     HARD           31
# 850        41.0    OCO     HARD           31
# 851        42.0    OCO     HARD           31
# 852        43.0    OCO     HARD           31
# 853        44.0    OCO     HARD           31
# 854        45.0    OCO     HARD           31
# 855        46.0    OCO     HARD           31
# 856        47.0    OCO     HARD           31
# 857        48.0    OCO     HARD           31
# 858        49.0    OCO     HARD           31
# 859        50.0    OCO     HARD           31
# 860        51.0    OCO     HARD           31
# 861        52.0    OCO     HARD           31
# 862        53.0    OCO     HARD           31
# 863        54.0    OCO     HARD           31
# 864        55.0    OCO     HARD           31
# 865         1.0    LAT     SOFT            6
# 866         2.0    LAT     SOFT            6
# 867         3.0    LAT     SOFT            6
# 868         4.0    LAT     SOFT            6
# 869         5.0    LAT     SOFT            6
# 870         6.0    LAT     SOFT            6
# 871         7.0    LAT     SOFT            6
# 872         8.0    LAT     SOFT            6
# 873         9.0    LAT     SOFT            6
# 874        10.0    LAT     SOFT            6
# 875        11.0    LAT     SOFT            6
# 876        12.0    LAT     SOFT            6
# 877        13.0    LAT     SOFT            6
# 878        14.0    LAT     SOFT            6
# 879        15.0    LAT   MEDIUM            6
# 880        16.0    LAT   MEDIUM            6
# 881        17.0    LAT   MEDIUM            6
# 882        18.0    LAT   MEDIUM            6
# 883        19.0    LAT   MEDIUM            6
# 884        20.0    LAT   MEDIUM            6
# 885        21.0    LAT   MEDIUM            6
# 886        22.0    LAT   MEDIUM            6
# 887        23.0    LAT   MEDIUM            6
# 888        24.0    LAT   MEDIUM            6
# 889        25.0    LAT   MEDIUM            6
# 890        26.0    LAT   MEDIUM            6
# 891        27.0    LAT   MEDIUM            6
# 892        28.0    LAT   MEDIUM            6
# 893        29.0    LAT   MEDIUM            6
# 894        30.0    LAT   MEDIUM            6
# 895        31.0    LAT   MEDIUM            6
# 896        32.0    LAT   MEDIUM            6
# 897        33.0    LAT   MEDIUM            6
# 898        34.0    LAT   MEDIUM            6
# 899        35.0    LAT   MEDIUM            6
# 900        36.0    LAT   MEDIUM            6
# 901        37.0    LAT   MEDIUM            6
# 902        38.0    LAT   MEDIUM            6
# 903        39.0    LAT   MEDIUM            6
# 904        40.0    LAT   MEDIUM            6
# 905        41.0    LAT   MEDIUM            6
# 906        42.0    LAT   MEDIUM            6
# 907        43.0    LAT   MEDIUM            6
# 908        44.0    LAT   MEDIUM            6
# 909        45.0    LAT   MEDIUM            6
# 910        46.0    LAT   MEDIUM            6
# 911        47.0    LAT   MEDIUM            6
# 912        48.0    LAT   MEDIUM            6
# 913        49.0    LAT   MEDIUM            6
# 914        50.0    LAT   MEDIUM            6
# 915        51.0    LAT   MEDIUM            6
# 916         1.0    MSC   MEDIUM           47
# 917         2.0    MSC   MEDIUM           47
# 918         3.0    MSC   MEDIUM           47
# 919         4.0    MSC   MEDIUM           47
# 920         5.0    MSC   MEDIUM           47
# 921         6.0    MSC   MEDIUM           47
# 922         7.0    MSC   MEDIUM           47
# 923         8.0    MSC   MEDIUM           47
# 924         9.0    MSC   MEDIUM           47
# 925        10.0    MSC   MEDIUM           47
# 926        11.0    MSC   MEDIUM           47
# 927        12.0    MSC   MEDIUM           47
# 928        13.0    MSC   MEDIUM           47
# 929        14.0    MSC   MEDIUM           47
# 930        15.0    MSC   MEDIUM           47
# 931        16.0    MSC   MEDIUM           47
# 932        17.0    MSC   MEDIUM           47
# 933        18.0    MSC   MEDIUM           47
# 934        19.0    MSC   MEDIUM           47
# 935        20.0    MSC   MEDIUM           47
# 936        21.0    MSC   MEDIUM           47
# 937        22.0    MSC   MEDIUM           47
# 938        23.0    MSC   MEDIUM           47
# 939        24.0    MSC   MEDIUM           47
# 940        25.0    MSC   MEDIUM           47
# 941        26.0    MSC   MEDIUM           47
# 942        27.0    MSC   MEDIUM           47
# 943        28.0    MSC   MEDIUM           47
# 944        29.0    MSC   MEDIUM           47
# 945        30.0    MSC   MEDIUM           47
# 946        31.0    MSC   MEDIUM           47
# 947        32.0    MSC   MEDIUM           47
# 948        33.0    MSC   MEDIUM           47
# 949        34.0    MSC     HARD           47
# 950        35.0    MSC     HARD           47
# 951        36.0    MSC     HARD           47
# 952        37.0    MSC     HARD           47
# 953        38.0    MSC     HARD           47
# 954        39.0    MSC     HARD           47
# 955        40.0    MSC     HARD           47
# 956        41.0    MSC     HARD           47
# 957        42.0    MSC     HARD           47
# 958        43.0    MSC     HARD           47
# 959        44.0    MSC     HARD           47
# 960        45.0    MSC     HARD           47
# 961        46.0    MSC     HARD           47
# 962        47.0    MSC     HARD           47
# 963        48.0    MSC     HARD           47
# 964        49.0    MSC     HARD           47
# 965        50.0    MSC     HARD           47
# 966        51.0    MSC     HARD           47
# 967        52.0    MSC     HARD           47
# 968        53.0    MSC     HARD           47
# 969        54.0    MSC     HARD           47
# 970        55.0    MSC     HARD           47
# 971         0.0    MAZ   MEDIUM            9
# 972         1.0    VET   MEDIUM            5
# 973         2.0    VET   MEDIUM            5
# 974         3.0    VET   MEDIUM            5
# 975         4.0    VET   MEDIUM            5
# 976         5.0    VET   MEDIUM            5
# 977         6.0    VET   MEDIUM            5
# 978         7.0    VET   MEDIUM            5
# 979         8.0    VET   MEDIUM            5
# 980         9.0    VET   MEDIUM            5
# 981        10.0    VET   MEDIUM            5
# 982        11.0    VET   MEDIUM            5
# 983        12.0    VET   MEDIUM            5
# 984        13.0    VET   MEDIUM            5
# 985        14.0    VET   MEDIUM            5
# 986        15.0    VET   MEDIUM            5
# 987        16.0    VET   MEDIUM            5
# 988        17.0    VET   MEDIUM            5
# 989        18.0    VET   MEDIUM            5
# 990        19.0    VET   MEDIUM            5
# 991        20.0    VET   MEDIUM            5
# 992        21.0    VET   MEDIUM            5
# 993        22.0    VET   MEDIUM            5
# 994        23.0    VET   MEDIUM            5
# 995        24.0    VET   MEDIUM            5
# 996        25.0    VET     HARD            5
# 997        26.0    VET     HARD            5
# 998        27.0    VET     HARD            5
# 999        28.0    VET     HARD            5
# 1000       29.0    VET     HARD            5
# 1001       30.0    VET     HARD            5
# 1002       31.0    VET     HARD            5
# 1003       32.0    VET     HARD            5
# 1004       33.0    VET     HARD            5
# 1005       34.0    VET     HARD            5
# 1006       35.0    VET     HARD            5
# 1007       36.0    VET     HARD            5
# 1008       37.0    VET     HARD            5
# 1009       38.0    VET     HARD            5
# 1010       39.0    VET     HARD            5
# 1011       40.0    VET     HARD            5
# 1012       41.0    VET     HARD            5
# 1013       42.0    VET     HARD            5
# 1014       43.0    VET     HARD            5
# 1015       44.0    VET     HARD            5
# 1016       45.0    VET     HARD            5
# 1017       46.0    VET     HARD            5
# 1018       47.0    VET     HARD            5
# 1019       48.0    VET     HARD            5
# 1020       49.0    VET     HARD            5
# 1021       50.0    VET     HARD            5
# 1022       51.0    VET     HARD            5
# 1023       52.0    VET     HARD            5
# 1024       53.0    VET     HARD            5
# 1025       54.0    VET     HARD            5
# 1026       55.0    VET     HARD            5

# %%
laps_2_info
# Out:
#       LapNumber Driver      Compound DriverNumber
# 0           1.0    HAM  INTERMEDIATE           44
# 1           2.0    HAM  INTERMEDIATE           44
# 2           3.0    HAM  INTERMEDIATE           44
# 3           4.0    HAM  INTERMEDIATE           44
# 4           5.0    HAM  INTERMEDIATE           44
# 5           6.0    HAM  INTERMEDIATE           44
# 6           7.0    HAM  INTERMEDIATE           44
# 7           8.0    HAM  INTERMEDIATE           44
# 8           9.0    HAM  INTERMEDIATE           44
# 9          10.0    HAM  INTERMEDIATE           44
# 10         11.0    HAM  INTERMEDIATE           44
# 11         12.0    HAM  INTERMEDIATE           44
# 12         13.0    HAM  INTERMEDIATE           44
# 13         14.0    HAM  INTERMEDIATE           44
# 14         15.0    HAM  INTERMEDIATE           44
# 15         16.0    HAM  INTERMEDIATE           44
# 16         17.0    HAM  INTERMEDIATE           44
# 17         18.0    HAM  INTERMEDIATE           44
# 18         19.0    HAM  INTERMEDIATE           44
# 19         20.0    HAM  INTERMEDIATE           44
# 20         21.0    HAM  INTERMEDIATE           44
# 21         22.0    HAM  INTERMEDIATE           44
# 22         23.0    HAM  INTERMEDIATE           44
# 23         24.0    HAM  INTERMEDIATE           44
# 24         25.0    HAM  INTERMEDIATE           44
# 25         26.0    HAM  INTERMEDIATE           44
# 26         27.0    HAM  INTERMEDIATE           44
# 27         28.0    HAM  INTERMEDIATE           44
# 28         29.0    HAM        MEDIUM           44
# 29         30.0    HAM        MEDIUM           44
# 30         31.0    HAM        MEDIUM           44
# 31         32.0    HAM        MEDIUM           44
# 32         33.0    HAM        MEDIUM           44
# 33         34.0    HAM        MEDIUM           44
# 34         35.0    HAM        MEDIUM           44
# 35         36.0    HAM        MEDIUM           44
# 36         37.0    HAM        MEDIUM           44
# 37         38.0    HAM        MEDIUM           44
# 38         39.0    HAM        MEDIUM           44
# 39         40.0    HAM        MEDIUM           44
# 40         41.0    HAM        MEDIUM           44
# 41         42.0    HAM        MEDIUM           44
# 42         43.0    HAM        MEDIUM           44
# 43         44.0    HAM        MEDIUM           44
# 44         45.0    HAM        MEDIUM           44
# 45         46.0    HAM        MEDIUM           44
# 46         47.0    HAM        MEDIUM           44
# 47         48.0    HAM        MEDIUM           44
# 48         49.0    HAM        MEDIUM           44
# 49         50.0    HAM        MEDIUM           44
# 50         51.0    HAM        MEDIUM           44
# 51         52.0    HAM        MEDIUM           44
# 52         53.0    HAM        MEDIUM           44
# 53         54.0    HAM        MEDIUM           44
# 54         55.0    HAM        MEDIUM           44
# 55         56.0    HAM        MEDIUM           44
# 56         57.0    HAM        MEDIUM           44
# 57         58.0    HAM        MEDIUM           44
# 58         59.0    HAM        MEDIUM           44
# 59         60.0    HAM        MEDIUM           44
# 60         61.0    HAM        MEDIUM           44
# 61         62.0    HAM        MEDIUM           44
# 62         63.0    HAM        MEDIUM           44
# 63          1.0    PER  INTERMEDIATE           11
# 64          2.0    PER  INTERMEDIATE           11
# 65          3.0    PER  INTERMEDIATE           11
# 66          4.0    PER  INTERMEDIATE           11
# 67          5.0    PER  INTERMEDIATE           11
# 68          6.0    PER  INTERMEDIATE           11
# 69          7.0    PER  INTERMEDIATE           11
# 70          8.0    PER  INTERMEDIATE           11
# 71          9.0    PER  INTERMEDIATE           11
# 72         10.0    PER  INTERMEDIATE           11
# 73         11.0    PER  INTERMEDIATE           11
# 74         12.0    PER  INTERMEDIATE           11
# 75         13.0    PER  INTERMEDIATE           11
# 76         14.0    PER  INTERMEDIATE           11
# 77         15.0    PER  INTERMEDIATE           11
# 78         16.0    PER  INTERMEDIATE           11
# 79         17.0    PER  INTERMEDIATE           11
# 80         18.0    PER  INTERMEDIATE           11
# 81         19.0    PER  INTERMEDIATE           11
# 82         20.0    PER  INTERMEDIATE           11
# 83         21.0    PER  INTERMEDIATE           11
# 84         22.0    PER  INTERMEDIATE           11
# 85         23.0    PER  INTERMEDIATE           11
# 86         24.0    PER  INTERMEDIATE           11
# 87         25.0    PER  INTERMEDIATE           11
# 88         26.0    PER  INTERMEDIATE           11
# 89         27.0    PER  INTERMEDIATE           11
# 90         28.0    PER  INTERMEDIATE           11
# 91         29.0    PER        MEDIUM           11
# 92         30.0    PER        MEDIUM           11
# 93         31.0    PER        MEDIUM           11
# 94         32.0    PER        MEDIUM           11
# 95         33.0    PER        MEDIUM           11
# 96         34.0    PER          SOFT           11
# 97         35.0    PER          SOFT           11
# 98         36.0    PER          SOFT           11
# 99         37.0    PER          SOFT           11
# 100        38.0    PER          SOFT           11
# 101        39.0    PER          SOFT           11
# 102        40.0    PER          SOFT           11
# 103        41.0    PER          SOFT           11
# 104        42.0    PER          SOFT           11
# 105        43.0    PER          SOFT           11
# 106        44.0    PER          SOFT           11
# 107        45.0    PER          SOFT           11
# 108        46.0    PER          SOFT           11
# 109        47.0    PER          SOFT           11
# 110        48.0    PER          SOFT           11
# 111        49.0    PER          SOFT           11
# 112        50.0    PER          SOFT           11
# 113        51.0    PER          SOFT           11
# 114        52.0    PER          SOFT           11
# 115        53.0    PER          SOFT           11
# 116        54.0    PER          SOFT           11
# 117        55.0    PER          SOFT           11
# 118        56.0    PER          SOFT           11
# 119        57.0    PER          SOFT           11
# 120        58.0    PER          SOFT           11
# 121        59.0    PER          SOFT           11
# 122        60.0    PER          SOFT           11
# 123        61.0    PER          SOFT           11
# 124        62.0    PER          SOFT           11
# 125        63.0    PER          SOFT           11
# 126         1.0    VER  INTERMEDIATE           33
# 127         2.0    VER  INTERMEDIATE           33
# 128         3.0    VER  INTERMEDIATE           33
# 129         4.0    VER  INTERMEDIATE           33
# 130         5.0    VER  INTERMEDIATE           33
# 131         6.0    VER  INTERMEDIATE           33
# 132         7.0    VER  INTERMEDIATE           33
# 133         8.0    VER  INTERMEDIATE           33
# 134         9.0    VER  INTERMEDIATE           33
# 135        10.0    VER  INTERMEDIATE           33
# 136        11.0    VER  INTERMEDIATE           33
# 137        12.0    VER  INTERMEDIATE           33
# 138        13.0    VER  INTERMEDIATE           33
# 139        14.0    VER  INTERMEDIATE           33
# 140        15.0    VER  INTERMEDIATE           33
# 141        16.0    VER  INTERMEDIATE           33
# 142        17.0    VER  INTERMEDIATE           33
# 143        18.0    VER  INTERMEDIATE           33
# 144        19.0    VER  INTERMEDIATE           33
# 145        20.0    VER  INTERMEDIATE           33
# 146        21.0    VER  INTERMEDIATE           33
# 147        22.0    VER  INTERMEDIATE           33
# 148        23.0    VER  INTERMEDIATE           33
# 149        24.0    VER  INTERMEDIATE           33
# 150        25.0    VER  INTERMEDIATE           33
# 151        26.0    VER  INTERMEDIATE           33
# 152        27.0    VER  INTERMEDIATE           33
# 153        28.0    VER        MEDIUM           33
# 154        29.0    VER        MEDIUM           33
# 155        30.0    VER        MEDIUM           33
# 156        31.0    VER        MEDIUM           33
# 157        32.0    VER        MEDIUM           33
# 158        33.0    VER        MEDIUM           33
# 159        34.0    VER        MEDIUM           33
# 160        35.0    VER        MEDIUM           33
# 161        36.0    VER        MEDIUM           33
# 162        37.0    VER        MEDIUM           33
# 163        38.0    VER        MEDIUM           33
# 164        39.0    VER        MEDIUM           33
# 165        40.0    VER        MEDIUM           33
# 166        41.0    VER        MEDIUM           33
# 167        42.0    VER        MEDIUM           33
# 168        43.0    VER        MEDIUM           33
# 169        44.0    VER        MEDIUM           33
# 170        45.0    VER        MEDIUM           33
# 171        46.0    VER        MEDIUM           33
# 172        47.0    VER        MEDIUM           33
# 173        48.0    VER        MEDIUM           33
# 174        49.0    VER        MEDIUM           33
# 175        50.0    VER        MEDIUM           33
# 176        51.0    VER        MEDIUM           33
# 177        52.0    VER        MEDIUM           33
# 178        53.0    VER        MEDIUM           33
# 179        54.0    VER        MEDIUM           33
# 180        55.0    VER        MEDIUM           33
# 181        56.0    VER        MEDIUM           33
# 182        57.0    VER        MEDIUM           33
# 183        58.0    VER        MEDIUM           33
# 184        59.0    VER        MEDIUM           33
# 185        60.0    VER        MEDIUM           33
# 186        61.0    VER        MEDIUM           33
# 187        62.0    VER        MEDIUM           33
# 188        63.0    VER        MEDIUM           33
# 189         1.0    LEC  INTERMEDIATE           16
# 190         2.0    LEC  INTERMEDIATE           16
# 191         3.0    LEC  INTERMEDIATE           16
# 192         4.0    LEC  INTERMEDIATE           16
# 193         5.0    LEC  INTERMEDIATE           16
# 194         6.0    LEC  INTERMEDIATE           16
# 195         7.0    LEC  INTERMEDIATE           16
# 196         8.0    LEC  INTERMEDIATE           16
# 197         9.0    LEC  INTERMEDIATE           16
# 198        10.0    LEC  INTERMEDIATE           16
# 199        11.0    LEC  INTERMEDIATE           16
# 200        12.0    LEC  INTERMEDIATE           16
# 201        13.0    LEC  INTERMEDIATE           16
# 202        14.0    LEC  INTERMEDIATE           16
# 203        15.0    LEC  INTERMEDIATE           16
# 204        16.0    LEC  INTERMEDIATE           16
# 205        17.0    LEC  INTERMEDIATE           16
# 206        18.0    LEC  INTERMEDIATE           16
# 207        19.0    LEC  INTERMEDIATE           16
# 208        20.0    LEC  INTERMEDIATE           16
# 209        21.0    LEC  INTERMEDIATE           16
# 210        22.0    LEC  INTERMEDIATE           16
# 211        23.0    LEC  INTERMEDIATE           16
# 212        24.0    LEC  INTERMEDIATE           16
# 213        25.0    LEC  INTERMEDIATE           16
# 214        26.0    LEC  INTERMEDIATE           16
# 215        27.0    LEC  INTERMEDIATE           16
# 216        28.0    LEC  INTERMEDIATE           16
# 217        29.0    LEC        MEDIUM           16
# 218        30.0    LEC        MEDIUM           16
# 219        31.0    LEC        MEDIUM           16
# 220        32.0    LEC        MEDIUM           16
# 221        33.0    LEC        MEDIUM           16
# 222        34.0    LEC        MEDIUM           16
# 223        35.0    LEC        MEDIUM           16
# 224        36.0    LEC        MEDIUM           16
# 225        37.0    LEC        MEDIUM           16
# 226        38.0    LEC        MEDIUM           16
# 227        39.0    LEC        MEDIUM           16
# 228        40.0    LEC        MEDIUM           16
# 229        41.0    LEC        MEDIUM           16
# 230        42.0    LEC        MEDIUM           16
# 231        43.0    LEC        MEDIUM           16
# 232        44.0    LEC        MEDIUM           16
# 233        45.0    LEC        MEDIUM           16
# 234        46.0    LEC        MEDIUM           16
# 235        47.0    LEC        MEDIUM           16
# 236        48.0    LEC        MEDIUM           16
# 237        49.0    LEC        MEDIUM           16
# 238        50.0    LEC        MEDIUM           16
# 239        51.0    LEC        MEDIUM           16
# 240        52.0    LEC        MEDIUM           16
# 241        53.0    LEC        MEDIUM           16
# 242        54.0    LEC        MEDIUM           16
# 243        55.0    LEC        MEDIUM           16
# 244        56.0    LEC        MEDIUM           16
# 245        57.0    LEC        MEDIUM           16
# 246        58.0    LEC        MEDIUM           16
# 247        59.0    LEC        MEDIUM           16
# 248        60.0    LEC        MEDIUM           16
# 249        61.0    LEC        MEDIUM           16
# 250        62.0    LEC        MEDIUM           16
# 251        63.0    LEC        MEDIUM           16
# 252         1.0    GAS           WET           10
# 253         2.0    GAS           WET           10
# 254         3.0    GAS           WET           10
# 255         4.0    GAS           WET           10
# 256         5.0    GAS           WET           10
# 257         6.0    GAS           WET           10
# 258         7.0    GAS           WET           10
# 259         8.0    GAS           WET           10
# 260         9.0    GAS           WET           10
# 261        10.0    GAS           WET           10
# 262        11.0    GAS           WET           10
# 263        12.0    GAS           WET           10
# 264        13.0    GAS           WET           10
# 265        14.0    GAS           WET           10
# 266        15.0    GAS  INTERMEDIATE           10
# 267        16.0    GAS  INTERMEDIATE           10
# 268        17.0    GAS  INTERMEDIATE           10
# 269        18.0    GAS  INTERMEDIATE           10
# 270        19.0    GAS  INTERMEDIATE           10
# 271        20.0    GAS  INTERMEDIATE           10
# 272        21.0    GAS  INTERMEDIATE           10
# 273        22.0    GAS  INTERMEDIATE           10
# 274        23.0    GAS  INTERMEDIATE           10
# 275        24.0    GAS  INTERMEDIATE           10
# 276        25.0    GAS  INTERMEDIATE           10
# 277        26.0    GAS  INTERMEDIATE           10
# 278        27.0    GAS        MEDIUM           10
# 279        28.0    GAS        MEDIUM           10
# 280        29.0    GAS        MEDIUM           10
# 281        30.0    GAS        MEDIUM           10
# 282        31.0    GAS        MEDIUM           10
# 283        32.0    GAS        MEDIUM           10
# 284        33.0    GAS        MEDIUM           10
# 285        34.0    GAS        MEDIUM           10
# 286        35.0    GAS        MEDIUM           10
# 287        36.0    GAS        MEDIUM           10
# 288        37.0    GAS        MEDIUM           10
# 289        38.0    GAS        MEDIUM           10
# 290        39.0    GAS        MEDIUM           10
# 291        40.0    GAS        MEDIUM           10
# 292        41.0    GAS        MEDIUM           10
# 293        42.0    GAS        MEDIUM           10
# 294        43.0    GAS        MEDIUM           10
# 295        44.0    GAS        MEDIUM           10
# 296        45.0    GAS        MEDIUM           10
# 297        46.0    GAS        MEDIUM           10
# 298        47.0    GAS        MEDIUM           10
# 299        48.0    GAS        MEDIUM           10
# 300        49.0    GAS        MEDIUM           10
# 301        50.0    GAS        MEDIUM           10
# 302        51.0    GAS        MEDIUM           10
# 303        52.0    GAS        MEDIUM           10
# 304        53.0    GAS        MEDIUM           10
# 305        54.0    GAS        MEDIUM           10
# 306        55.0    GAS        MEDIUM           10
# 307        56.0    GAS        MEDIUM           10
# 308        57.0    GAS        MEDIUM           10
# 309        58.0    GAS        MEDIUM           10
# 310        59.0    GAS        MEDIUM           10
# 311        60.0    GAS        MEDIUM           10
# 312        61.0    GAS        MEDIUM           10
# 313        62.0    GAS        MEDIUM           10
# 314        63.0    GAS        MEDIUM           10
# 315         1.0    RIC  INTERMEDIATE            3
# 316         2.0    RIC  INTERMEDIATE            3
# 317         3.0    RIC  INTERMEDIATE            3
# 318         4.0    RIC  INTERMEDIATE            3
# 319         5.0    RIC  INTERMEDIATE            3
# 320         6.0    RIC  INTERMEDIATE            3
# 321         7.0    RIC  INTERMEDIATE            3
# 322         8.0    RIC  INTERMEDIATE            3
# 323         9.0    RIC  INTERMEDIATE            3
# 324        10.0    RIC  INTERMEDIATE            3
# 325        11.0    RIC  INTERMEDIATE            3
# 326        12.0    RIC  INTERMEDIATE            3
# 327        13.0    RIC  INTERMEDIATE            3
# 328        14.0    RIC  INTERMEDIATE            3
# 329        15.0    RIC  INTERMEDIATE            3
# 330        16.0    RIC  INTERMEDIATE            3
# 331        17.0    RIC  INTERMEDIATE            3
# 332        18.0    RIC  INTERMEDIATE            3
# 333        19.0    RIC  INTERMEDIATE            3
# 334        20.0    RIC  INTERMEDIATE            3
# 335        21.0    RIC  INTERMEDIATE            3
# 336        22.0    RIC  INTERMEDIATE            3
# 337        23.0    RIC  INTERMEDIATE            3
# 338        24.0    RIC  INTERMEDIATE            3
# 339        25.0    RIC  INTERMEDIATE            3
# 340        26.0    RIC  INTERMEDIATE            3
# 341        27.0    RIC  INTERMEDIATE            3
# 342        28.0    RIC        MEDIUM            3
# 343        29.0    RIC        MEDIUM            3
# 344        30.0    RIC        MEDIUM            3
# 345        31.0    RIC        MEDIUM            3
# 346        32.0    RIC        MEDIUM            3
# 347        33.0    RIC        MEDIUM            3
# 348        34.0    RIC          SOFT            3
# 349        35.0    RIC          SOFT            3
# 350        36.0    RIC          SOFT            3
# 351        37.0    RIC          SOFT            3
# 352        38.0    RIC          SOFT            3
# 353        39.0    RIC          SOFT            3
# 354        40.0    RIC          SOFT            3
# 355        41.0    RIC          SOFT            3
# 356        42.0    RIC          SOFT            3
# 357        43.0    RIC          SOFT            3
# 358        44.0    RIC          SOFT            3
# 359        45.0    RIC          SOFT            3
# 360        46.0    RIC          SOFT            3
# 361        47.0    RIC          SOFT            3
# 362        48.0    RIC          SOFT            3
# 363        49.0    RIC          SOFT            3
# 364        50.0    RIC          SOFT            3
# 365        51.0    RIC          SOFT            3
# 366        52.0    RIC          SOFT            3
# 367        53.0    RIC          SOFT            3
# 368        54.0    RIC          SOFT            3
# 369        55.0    RIC          SOFT            3
# 370        56.0    RIC          SOFT            3
# 371        57.0    RIC          SOFT            3
# 372        58.0    RIC          SOFT            3
# 373        59.0    RIC          SOFT            3
# 374        60.0    RIC          SOFT            3
# 375        61.0    RIC          SOFT            3
# 376        62.0    RIC          SOFT            3
# 377        63.0    RIC          SOFT            3
# 378         1.0    NOR  INTERMEDIATE            4
# 379         2.0    NOR  INTERMEDIATE            4
# 380         3.0    NOR  INTERMEDIATE            4
# 381         4.0    NOR  INTERMEDIATE            4
# 382         5.0    NOR  INTERMEDIATE            4
# 383         6.0    NOR  INTERMEDIATE            4
# 384         7.0    NOR  INTERMEDIATE            4
# 385         8.0    NOR  INTERMEDIATE            4
# 386         9.0    NOR  INTERMEDIATE            4
# 387        10.0    NOR  INTERMEDIATE            4
# 388        11.0    NOR  INTERMEDIATE            4
# 389        12.0    NOR  INTERMEDIATE            4
# 390        13.0    NOR  INTERMEDIATE            4
# 391        14.0    NOR  INTERMEDIATE            4
# 392        15.0    NOR  INTERMEDIATE            4
# 393        16.0    NOR  INTERMEDIATE            4
# 394        17.0    NOR  INTERMEDIATE            4
# 395        18.0    NOR  INTERMEDIATE            4
# 396        19.0    NOR  INTERMEDIATE            4
# 397        20.0    NOR  INTERMEDIATE            4
# 398        21.0    NOR  INTERMEDIATE            4
# 399        22.0    NOR  INTERMEDIATE            4
# 400        23.0    NOR  INTERMEDIATE            4
# 401        24.0    NOR  INTERMEDIATE            4
# 402        25.0    NOR  INTERMEDIATE            4
# 403        26.0    NOR  INTERMEDIATE            4
# 404        27.0    NOR  INTERMEDIATE            4
# 405        28.0    NOR  INTERMEDIATE            4
# 406        29.0    NOR        MEDIUM            4
# 407        30.0    NOR        MEDIUM            4
# 408        31.0    NOR        MEDIUM            4
# 409        32.0    NOR        MEDIUM            4
# 410        33.0    NOR        MEDIUM            4
# 411        34.0    NOR          SOFT            4
# 412        35.0    NOR          SOFT            4
# 413        36.0    NOR          SOFT            4
# 414        37.0    NOR          SOFT            4
# 415        38.0    NOR          SOFT            4
# 416        39.0    NOR          SOFT            4
# 417        40.0    NOR          SOFT            4
# 418        41.0    NOR          SOFT            4
# 419        42.0    NOR          SOFT            4
# 420        43.0    NOR          SOFT            4
# 421        44.0    NOR          SOFT            4
# 422        45.0    NOR          SOFT            4
# 423        46.0    NOR          SOFT            4
# 424        47.0    NOR          SOFT            4
# 425        48.0    NOR          SOFT            4
# 426        49.0    NOR          SOFT            4
# 427        50.0    NOR          SOFT            4
# 428        51.0    NOR          SOFT            4
# 429        52.0    NOR          SOFT            4
# 430        53.0    NOR          SOFT            4
# 431        54.0    NOR          SOFT            4
# 432        55.0    NOR          SOFT            4
# 433        56.0    NOR          SOFT            4
# 434        57.0    NOR          SOFT            4
# 435        58.0    NOR          SOFT            4
# 436        59.0    NOR          SOFT            4
# 437        60.0    NOR          SOFT            4
# 438        61.0    NOR          SOFT            4
# 439        62.0    NOR          SOFT            4
# 440        63.0    NOR          SOFT            4
# 441         1.0    BOT  INTERMEDIATE           77
# 442         2.0    BOT  INTERMEDIATE           77
# 443         3.0    BOT  INTERMEDIATE           77
# 444         4.0    BOT  INTERMEDIATE           77
# 445         5.0    BOT  INTERMEDIATE           77
# 446         6.0    BOT  INTERMEDIATE           77
# 447         7.0    BOT  INTERMEDIATE           77
# 448         8.0    BOT  INTERMEDIATE           77
# 449         9.0    BOT  INTERMEDIATE           77
# 450        10.0    BOT  INTERMEDIATE           77
# 451        11.0    BOT  INTERMEDIATE           77
# 452        12.0    BOT  INTERMEDIATE           77
# 453        13.0    BOT  INTERMEDIATE           77
# 454        14.0    BOT  INTERMEDIATE           77
# 455        15.0    BOT  INTERMEDIATE           77
# 456        16.0    BOT  INTERMEDIATE           77
# 457        17.0    BOT  INTERMEDIATE           77
# 458        18.0    BOT  INTERMEDIATE           77
# 459        19.0    BOT  INTERMEDIATE           77
# 460        20.0    BOT  INTERMEDIATE           77
# 461        21.0    BOT  INTERMEDIATE           77
# 462        22.0    BOT  INTERMEDIATE           77
# 463        23.0    BOT  INTERMEDIATE           77
# 464        24.0    BOT  INTERMEDIATE           77
# 465        25.0    BOT  INTERMEDIATE           77
# 466        26.0    BOT  INTERMEDIATE           77
# 467        27.0    BOT  INTERMEDIATE           77
# 468        28.0    BOT  INTERMEDIATE           77
# 469        29.0    BOT        MEDIUM           77
# 470        30.0    BOT        MEDIUM           77
# 471        31.0    BOT        MEDIUM           77
# 472         1.0    OCO           WET           31
# 473         2.0    OCO  INTERMEDIATE           31
# 474         3.0    OCO  INTERMEDIATE           31
# 475         4.0    OCO  INTERMEDIATE           31
# 476         5.0    OCO  INTERMEDIATE           31
# 477         6.0    OCO  INTERMEDIATE           31
# 478         7.0    OCO  INTERMEDIATE           31
# 479         8.0    OCO  INTERMEDIATE           31
# 480         9.0    OCO  INTERMEDIATE           31
# 481        10.0    OCO  INTERMEDIATE           31
# 482        11.0    OCO  INTERMEDIATE           31
# 483        12.0    OCO  INTERMEDIATE           31
# 484        13.0    OCO  INTERMEDIATE           31
# 485        14.0    OCO  INTERMEDIATE           31
# 486        15.0    OCO  INTERMEDIATE           31
# 487        16.0    OCO  INTERMEDIATE           31
# 488        17.0    OCO  INTERMEDIATE           31
# 489        18.0    OCO  INTERMEDIATE           31
# 490        19.0    OCO  INTERMEDIATE           31
# 491        20.0    OCO  INTERMEDIATE           31
# 492        21.0    OCO  INTERMEDIATE           31
# 493        22.0    OCO  INTERMEDIATE           31
# 494        23.0    OCO  INTERMEDIATE           31
# 495        24.0    OCO  INTERMEDIATE           31
# 496        25.0    OCO  INTERMEDIATE           31
# 497        26.0    OCO  INTERMEDIATE           31
# 498        27.0    OCO  INTERMEDIATE           31
# 499        28.0    OCO        MEDIUM           31
# 500        29.0    OCO        MEDIUM           31
# 501        30.0    OCO        MEDIUM           31
# 502        31.0    OCO        MEDIUM           31
# 503        32.0    OCO          SOFT           31
# 504        33.0    OCO        MEDIUM           31
# 505        34.0    OCO        MEDIUM           31
# 506        35.0    OCO        MEDIUM           31
# 507        36.0    OCO        MEDIUM           31
# 508        37.0    OCO        MEDIUM           31
# 509        38.0    OCO        MEDIUM           31
# 510        39.0    OCO        MEDIUM           31
# 511        40.0    OCO        MEDIUM           31
# 512        41.0    OCO        MEDIUM           31
# 513        42.0    OCO        MEDIUM           31
# 514        43.0    OCO        MEDIUM           31
# 515        44.0    OCO        MEDIUM           31
# 516        45.0    OCO        MEDIUM           31
# 517        46.0    OCO        MEDIUM           31
# 518        47.0    OCO        MEDIUM           31
# 519        48.0    OCO        MEDIUM           31
# 520        49.0    OCO        MEDIUM           31
# 521        50.0    OCO        MEDIUM           31
# 522        51.0    OCO        MEDIUM           31
# 523        52.0    OCO        MEDIUM           31
# 524        53.0    OCO        MEDIUM           31
# 525        54.0    OCO        MEDIUM           31
# 526        55.0    OCO        MEDIUM           31
# 527        56.0    OCO        MEDIUM           31
# 528        57.0    OCO        MEDIUM           31
# 529        58.0    OCO        MEDIUM           31
# 530        59.0    OCO        MEDIUM           31
# 531        60.0    OCO        MEDIUM           31
# 532        61.0    OCO        MEDIUM           31
# 533        62.0    OCO        MEDIUM           31
# 534        63.0    OCO        MEDIUM           31
# 535         1.0    STR  INTERMEDIATE           18
# 536         2.0    STR  INTERMEDIATE           18
# 537         3.0    STR  INTERMEDIATE           18
# 538         4.0    STR  INTERMEDIATE           18
# 539         5.0    STR  INTERMEDIATE           18
# 540         6.0    STR  INTERMEDIATE           18
# 541         7.0    STR  INTERMEDIATE           18
# 542         8.0    STR  INTERMEDIATE           18
# 543         9.0    STR  INTERMEDIATE           18
# 544        10.0    STR  INTERMEDIATE           18
# 545        11.0    STR  INTERMEDIATE           18
# 546        12.0    STR  INTERMEDIATE           18
# 547        13.0    STR  INTERMEDIATE           18
# 548        14.0    STR  INTERMEDIATE           18
# 549        15.0    STR  INTERMEDIATE           18
# 550        16.0    STR  INTERMEDIATE           18
# 551        17.0    STR  INTERMEDIATE           18
# 552        18.0    STR  INTERMEDIATE           18
# 553        19.0    STR  INTERMEDIATE           18
# 554        20.0    STR  INTERMEDIATE           18
# 555        21.0    STR  INTERMEDIATE           18
# 556        22.0    STR  INTERMEDIATE           18
# 557        23.0    STR  INTERMEDIATE           18
# 558        24.0    STR  INTERMEDIATE           18
# 559        25.0    STR  INTERMEDIATE           18
# 560        26.0    STR  INTERMEDIATE           18
# 561        27.0    STR  INTERMEDIATE           18
# 562        28.0    STR        MEDIUM           18
# 563        29.0    STR        MEDIUM           18
# 564        30.0    STR        MEDIUM           18
# 565        31.0    STR        MEDIUM           18
# 566        32.0    STR        MEDIUM           18
# 567        33.0    STR        MEDIUM           18
# 568        34.0    STR       UNKNOWN           18
# 569        35.0    STR       UNKNOWN           18
# 570        36.0    STR       UNKNOWN           18
# 571        37.0    STR       UNKNOWN           18
# 572        38.0    STR        MEDIUM           18
# 573        39.0    STR        MEDIUM           18
# 574        40.0    STR        MEDIUM           18
# 575        41.0    STR        MEDIUM           18
# 576        42.0    STR        MEDIUM           18
# 577        43.0    STR        MEDIUM           18
# 578        44.0    STR        MEDIUM           18
# 579        45.0    STR        MEDIUM           18
# 580        46.0    STR        MEDIUM           18
# 581        47.0    STR        MEDIUM           18
# 582        48.0    STR        MEDIUM           18
# 583        49.0    STR        MEDIUM           18
# 584        50.0    STR        MEDIUM           18
# 585        51.0    STR        MEDIUM           18
# 586        52.0    STR        MEDIUM           18
# 587        53.0    STR        MEDIUM           18
# 588        54.0    STR        MEDIUM           18
# 589        55.0    STR        MEDIUM           18
# 590        56.0    STR        MEDIUM           18
# 591        57.0    STR        MEDIUM           18
# 592        58.0    STR        MEDIUM           18
# 593        59.0    STR        MEDIUM           18
# 594        60.0    STR        MEDIUM           18
# 595        61.0    STR        MEDIUM           18
# 596        62.0    STR        MEDIUM           18
# 597        63.0    STR        MEDIUM           18
# 598         1.0    SAI  INTERMEDIATE           55
# 599         2.0    SAI  INTERMEDIATE           55
# 600         3.0    SAI  INTERMEDIATE           55
# 601         4.0    SAI  INTERMEDIATE           55
# 602         5.0    SAI  INTERMEDIATE           55
# 603         6.0    SAI  INTERMEDIATE           55
# 604         7.0    SAI  INTERMEDIATE           55
# 605         8.0    SAI  INTERMEDIATE           55
# 606         9.0    SAI  INTERMEDIATE           55
# 607        10.0    SAI  INTERMEDIATE           55
# 608        11.0    SAI  INTERMEDIATE           55
# 609        12.0    SAI  INTERMEDIATE           55
# 610        13.0    SAI  INTERMEDIATE           55
# 611        14.0    SAI  INTERMEDIATE           55
# 612        15.0    SAI  INTERMEDIATE           55
# 613        16.0    SAI  INTERMEDIATE           55
# 614        17.0    SAI  INTERMEDIATE           55
# 615        18.0    SAI  INTERMEDIATE           55
# 616        19.0    SAI  INTERMEDIATE           55
# 617        20.0    SAI  INTERMEDIATE           55
# 618        21.0    SAI  INTERMEDIATE           55
# 619        22.0    SAI  INTERMEDIATE           55
# 620        23.0    SAI  INTERMEDIATE           55
# 621        24.0    SAI  INTERMEDIATE           55
# 622        25.0    SAI  INTERMEDIATE           55
# 623        26.0    SAI  INTERMEDIATE           55
# 624        27.0    SAI  INTERMEDIATE           55
# 625        28.0    SAI        MEDIUM           55
# 626        29.0    SAI        MEDIUM           55
# 627        30.0    SAI        MEDIUM           55
# 628        31.0    SAI        MEDIUM           55
# 629        32.0    SAI        MEDIUM           55
# 630        33.0    SAI        MEDIUM           55
# 631        34.0    SAI        MEDIUM           55
# 632        35.0    SAI        MEDIUM           55
# 633        36.0    SAI        MEDIUM           55
# 634        37.0    SAI        MEDIUM           55
# 635        38.0    SAI        MEDIUM           55
# 636        39.0    SAI        MEDIUM           55
# 637        40.0    SAI        MEDIUM           55
# 638        41.0    SAI        MEDIUM           55
# 639        42.0    SAI        MEDIUM           55
# 640        43.0    SAI        MEDIUM           55
# 641        44.0    SAI        MEDIUM           55
# 642        45.0    SAI        MEDIUM           55
# 643        46.0    SAI        MEDIUM           55
# 644        47.0    SAI        MEDIUM           55
# 645        48.0    SAI        MEDIUM           55
# 646        49.0    SAI        MEDIUM           55
# 647        50.0    SAI        MEDIUM           55
# 648        51.0    SAI        MEDIUM           55
# 649        52.0    SAI        MEDIUM           55
# 650        53.0    SAI        MEDIUM           55
# 651        54.0    SAI        MEDIUM           55
# 652        55.0    SAI        MEDIUM           55
# 653        56.0    SAI        MEDIUM           55
# 654        57.0    SAI        MEDIUM           55
# 655        58.0    SAI        MEDIUM           55
# 656        59.0    SAI        MEDIUM           55
# 657        60.0    SAI        MEDIUM           55
# 658        61.0    SAI        MEDIUM           55
# 659        62.0    SAI        MEDIUM           55
# 660        63.0    SAI        MEDIUM           55
# 661         1.0    RUS  INTERMEDIATE           63
# 662         2.0    RUS  INTERMEDIATE           63
# 663         3.0    RUS  INTERMEDIATE           63
# 664         4.0    RUS  INTERMEDIATE           63
# 665         5.0    RUS  INTERMEDIATE           63
# 666         6.0    RUS  INTERMEDIATE           63
# 667         7.0    RUS  INTERMEDIATE           63
# 668         8.0    RUS  INTERMEDIATE           63
# 669         9.0    RUS  INTERMEDIATE           63
# 670        10.0    RUS  INTERMEDIATE           63
# 671        11.0    RUS  INTERMEDIATE           63
# 672        12.0    RUS  INTERMEDIATE           63
# 673        13.0    RUS  INTERMEDIATE           63
# 674        14.0    RUS  INTERMEDIATE           63
# 675        15.0    RUS  INTERMEDIATE           63
# 676        16.0    RUS  INTERMEDIATE           63
# 677        17.0    RUS  INTERMEDIATE           63
# 678        18.0    RUS  INTERMEDIATE           63
# 679        19.0    RUS  INTERMEDIATE           63
# 680        20.0    RUS  INTERMEDIATE           63
# 681        21.0    RUS  INTERMEDIATE           63
# 682        22.0    RUS  INTERMEDIATE           63
# 683        23.0    RUS  INTERMEDIATE           63
# 684        24.0    RUS  INTERMEDIATE           63
# 685        25.0    RUS  INTERMEDIATE           63
# 686        26.0    RUS  INTERMEDIATE           63
# 687        27.0    RUS        MEDIUM           63
# 688        28.0    RUS        MEDIUM           63
# 689        29.0    RUS        MEDIUM           63
# 690        30.0    RUS        MEDIUM           63
# 691        31.0    RUS        MEDIUM           63
# 692         1.0    VET  INTERMEDIATE            5
# 693         2.0    VET  INTERMEDIATE            5
# 694         3.0    VET  INTERMEDIATE            5
# 695         4.0    VET  INTERMEDIATE            5
# 696         5.0    VET  INTERMEDIATE            5
# 697         6.0    VET  INTERMEDIATE            5
# 698         7.0    VET  INTERMEDIATE            5
# 699         8.0    VET  INTERMEDIATE            5
# 700         9.0    VET  INTERMEDIATE            5
# 701        10.0    VET  INTERMEDIATE            5
# 702        11.0    VET  INTERMEDIATE            5
# 703        12.0    VET  INTERMEDIATE            5
# 704        13.0    VET  INTERMEDIATE            5
# 705        14.0    VET  INTERMEDIATE            5
# 706        15.0    VET  INTERMEDIATE            5
# 707        16.0    VET  INTERMEDIATE            5
# 708        17.0    VET  INTERMEDIATE            5
# 709        18.0    VET  INTERMEDIATE            5
# 710        19.0    VET  INTERMEDIATE            5
# 711        20.0    VET  INTERMEDIATE            5
# 712        21.0    VET        MEDIUM            5
# 713        22.0    VET        MEDIUM            5
# 714        23.0    VET        MEDIUM            5
# 715        24.0    VET        MEDIUM            5
# 716        25.0    VET        MEDIUM            5
# 717        26.0    VET        MEDIUM            5
# 718        27.0    VET        MEDIUM            5
# 719        28.0    VET        MEDIUM            5
# 720        29.0    VET        MEDIUM            5
# 721        30.0    VET        MEDIUM            5
# 722        31.0    VET        MEDIUM            5
# 723        32.0    VET        MEDIUM            5
# 724        33.0    VET          SOFT            5
# 725        34.0    VET       UNKNOWN            5
# 726        35.0    VET       UNKNOWN            5
# 727        36.0    VET       UNKNOWN            5
# 728        37.0    VET       UNKNOWN            5
# 729        38.0    VET          SOFT            5
# 730        39.0    VET          SOFT            5
# 731        40.0    VET          SOFT            5
# 732        41.0    VET          SOFT            5
# 733        42.0    VET          SOFT            5
# 734        43.0    VET          SOFT            5
# 735        44.0    VET          SOFT            5
# 736        45.0    VET          SOFT            5
# 737        46.0    VET          SOFT            5
# 738        47.0    VET          SOFT            5
# 739        48.0    VET          SOFT            5
# 740        49.0    VET          SOFT            5
# 741        50.0    VET          SOFT            5
# 742        51.0    VET          SOFT            5
# 743        52.0    VET          SOFT            5
# 744        53.0    VET          SOFT            5
# 745        54.0    VET          SOFT            5
# 746        55.0    VET          SOFT            5
# 747        56.0    VET          SOFT            5
# 748        57.0    VET          SOFT            5
# 749        58.0    VET          SOFT            5
# 750        59.0    VET          SOFT            5
# 751        60.0    VET          SOFT            5
# 752        61.0    VET          SOFT            5
# 753         0.0    LAT  INTERMEDIATE            6
# 754         1.0    ALO  INTERMEDIATE           14
# 755         2.0    ALO  INTERMEDIATE           14
# 756         3.0    ALO  INTERMEDIATE           14
# 757         4.0    ALO  INTERMEDIATE           14
# 758         5.0    ALO  INTERMEDIATE           14
# 759         6.0    ALO  INTERMEDIATE           14
# 760         7.0    ALO  INTERMEDIATE           14
# 761         8.0    ALO  INTERMEDIATE           14
# 762         9.0    ALO  INTERMEDIATE           14
# 763        10.0    ALO  INTERMEDIATE           14
# 764        11.0    ALO  INTERMEDIATE           14
# 765        12.0    ALO  INTERMEDIATE           14
# 766        13.0    ALO  INTERMEDIATE           14
# 767        14.0    ALO  INTERMEDIATE           14
# 768        15.0    ALO  INTERMEDIATE           14
# 769        16.0    ALO  INTERMEDIATE           14
# 770        17.0    ALO  INTERMEDIATE           14
# 771        18.0    ALO  INTERMEDIATE           14
# 772        19.0    ALO  INTERMEDIATE           14
# 773        20.0    ALO  INTERMEDIATE           14
# 774        21.0    ALO  INTERMEDIATE           14
# 775        22.0    ALO  INTERMEDIATE           14
# 776        23.0    ALO  INTERMEDIATE           14
# 777        24.0    ALO  INTERMEDIATE           14
# 778        25.0    ALO  INTERMEDIATE           14
# 779        26.0    ALO  INTERMEDIATE           14
# 780        27.0    ALO  INTERMEDIATE           14
# 781        28.0    ALO  INTERMEDIATE           14
# 782        29.0    ALO        MEDIUM           14
# 783        30.0    ALO        MEDIUM           14
# 784        31.0    ALO        MEDIUM           14
# 785        32.0    ALO        MEDIUM           14
# 786        33.0    ALO        MEDIUM           14
# 787        34.0    ALO        MEDIUM           14
# 788        35.0    ALO        MEDIUM           14
# 789        36.0    ALO        MEDIUM           14
# 790        37.0    ALO        MEDIUM           14
# 791        38.0    ALO        MEDIUM           14
# 792        39.0    ALO        MEDIUM           14
# 793        40.0    ALO        MEDIUM           14
# 794        41.0    ALO        MEDIUM           14
# 795        42.0    ALO        MEDIUM           14
# 796        43.0    ALO        MEDIUM           14
# 797        44.0    ALO        MEDIUM           14
# 798        45.0    ALO        MEDIUM           14
# 799        46.0    ALO        MEDIUM           14
# 800        47.0    ALO        MEDIUM           14
# 801        48.0    ALO        MEDIUM           14
# 802        49.0    ALO        MEDIUM           14
# 803        50.0    ALO        MEDIUM           14
# 804        51.0    ALO        MEDIUM           14
# 805        52.0    ALO        MEDIUM           14
# 806        53.0    ALO        MEDIUM           14
# 807        54.0    ALO        MEDIUM           14
# 808        55.0    ALO        MEDIUM           14
# 809        56.0    ALO        MEDIUM           14
# 810        57.0    ALO        MEDIUM           14
# 811        58.0    ALO        MEDIUM           14
# 812        59.0    ALO        MEDIUM           14
# 813        60.0    ALO        MEDIUM           14
# 814        61.0    ALO        MEDIUM           14
# 815        62.0    ALO        MEDIUM           14
# 816        63.0    ALO        MEDIUM           14
# 817         1.0    RAI  INTERMEDIATE            7
# 818         2.0    RAI  INTERMEDIATE            7
# 819         3.0    RAI  INTERMEDIATE            7
# 820         4.0    RAI  INTERMEDIATE            7
# 821         5.0    RAI  INTERMEDIATE            7
# 822         6.0    RAI  INTERMEDIATE            7
# 823         7.0    RAI  INTERMEDIATE            7
# 824         8.0    RAI  INTERMEDIATE            7
# 825         9.0    RAI  INTERMEDIATE            7
# 826        10.0    RAI  INTERMEDIATE            7
# 827        11.0    RAI  INTERMEDIATE            7
# 828        12.0    RAI  INTERMEDIATE            7
# 829        13.0    RAI  INTERMEDIATE            7
# 830        14.0    RAI  INTERMEDIATE            7
# 831        15.0    RAI  INTERMEDIATE            7
# 832        16.0    RAI  INTERMEDIATE            7
# 833        17.0    RAI  INTERMEDIATE            7
# 834        18.0    RAI  INTERMEDIATE            7
# 835        19.0    RAI  INTERMEDIATE            7
# 836        20.0    RAI  INTERMEDIATE            7
# 837        21.0    RAI  INTERMEDIATE            7
# 838        22.0    RAI  INTERMEDIATE            7
# 839        23.0    RAI  INTERMEDIATE            7
# 840        24.0    RAI  INTERMEDIATE            7
# 841        25.0    RAI  INTERMEDIATE            7
# 842        26.0    RAI  INTERMEDIATE            7
# 843        27.0    RAI        MEDIUM            7
# 844        28.0    RAI        MEDIUM            7
# 845        29.0    RAI        MEDIUM            7
# 846        30.0    RAI        MEDIUM            7
# 847        31.0    RAI        MEDIUM            7
# 848        32.0    RAI        MEDIUM            7
# 849        33.0    RAI        MEDIUM            7
# 850        34.0    RAI       UNKNOWN            7
# 851        35.0    RAI       UNKNOWN            7
# 852        36.0    RAI        MEDIUM            7
# 853        37.0    RAI        MEDIUM            7
# 854        38.0    RAI        MEDIUM            7
# 855        39.0    RAI        MEDIUM            7
# 856        40.0    RAI        MEDIUM            7
# 857        41.0    RAI        MEDIUM            7
# 858        42.0    RAI        MEDIUM            7
# 859        43.0    RAI        MEDIUM            7
# 860        44.0    RAI        MEDIUM            7
# 861        45.0    RAI        MEDIUM            7
# 862        46.0    RAI        MEDIUM            7
# 863        47.0    RAI        MEDIUM            7
# 864        48.0    RAI        MEDIUM            7
# 865        49.0    RAI        MEDIUM            7
# 866        50.0    RAI        MEDIUM            7
# 867        51.0    RAI        MEDIUM            7
# 868        52.0    RAI        MEDIUM            7
# 869        53.0    RAI        MEDIUM            7
# 870        54.0    RAI        MEDIUM            7
# 871        55.0    RAI        MEDIUM            7
# 872        56.0    RAI        MEDIUM            7
# 873        57.0    RAI        MEDIUM            7
# 874        58.0    RAI        MEDIUM            7
# 875        59.0    RAI        MEDIUM            7
# 876        60.0    RAI        MEDIUM            7
# 877        61.0    RAI        MEDIUM            7
# 878        62.0    RAI        MEDIUM            7
# 879        63.0    RAI        MEDIUM            7
# 880         1.0    GIO  INTERMEDIATE           99
# 881         2.0    GIO  INTERMEDIATE           99
# 882         3.0    GIO  INTERMEDIATE           99
# 883         4.0    GIO  INTERMEDIATE           99
# 884         5.0    GIO  INTERMEDIATE           99
# 885         6.0    GIO  INTERMEDIATE           99
# 886         7.0    GIO  INTERMEDIATE           99
# 887         8.0    GIO  INTERMEDIATE           99
# 888         9.0    GIO  INTERMEDIATE           99
# 889        10.0    GIO  INTERMEDIATE           99
# 890        11.0    GIO  INTERMEDIATE           99
# 891        12.0    GIO  INTERMEDIATE           99
# 892        13.0    GIO  INTERMEDIATE           99
# 893        14.0    GIO  INTERMEDIATE           99
# 894        15.0    GIO  INTERMEDIATE           99
# 895        16.0    GIO  INTERMEDIATE           99
# 896        17.0    GIO  INTERMEDIATE           99
# 897        18.0    GIO  INTERMEDIATE           99
# 898        19.0    GIO  INTERMEDIATE           99
# 899        20.0    GIO  INTERMEDIATE           99
# 900        21.0    GIO  INTERMEDIATE           99
# 901        22.0    GIO  INTERMEDIATE           99
# 902        23.0    GIO  INTERMEDIATE           99
# 903        24.0    GIO  INTERMEDIATE           99
# 904        25.0    GIO  INTERMEDIATE           99
# 905        26.0    GIO  INTERMEDIATE           99
# 906        27.0    GIO  INTERMEDIATE           99
# 907        28.0    GIO        MEDIUM           99
# 908        29.0    GIO        MEDIUM           99
# 909        30.0    GIO        MEDIUM           99
# 910        31.0    GIO        MEDIUM           99
# 911        32.0    GIO        MEDIUM           99
# 912        33.0    GIO        MEDIUM           99
# 913        34.0    GIO       UNKNOWN           99
# 914        35.0    GIO       UNKNOWN           99
# 915        36.0    GIO        MEDIUM           99
# 916        37.0    GIO        MEDIUM           99
# 917        38.0    GIO        MEDIUM           99
# 918        39.0    GIO        MEDIUM           99
# 919        40.0    GIO        MEDIUM           99
# 920        41.0    GIO        MEDIUM           99
# 921        42.0    GIO        MEDIUM           99
# 922        43.0    GIO        MEDIUM           99
# 923        44.0    GIO        MEDIUM           99
# 924        45.0    GIO        MEDIUM           99
# 925        46.0    GIO        MEDIUM           99
# 926        47.0    GIO        MEDIUM           99
# 927        48.0    GIO        MEDIUM           99
# 928        49.0    GIO        MEDIUM           99
# 929        50.0    GIO        MEDIUM           99
# 930        51.0    GIO        MEDIUM           99
# 931        52.0    GIO        MEDIUM           99
# 932        53.0    GIO        MEDIUM           99
# 933        54.0    GIO        MEDIUM           99
# 934        55.0    GIO        MEDIUM           99
# 935        56.0    GIO        MEDIUM           99
# 936        57.0    GIO        MEDIUM           99
# 937        58.0    GIO        MEDIUM           99
# 938        59.0    GIO        MEDIUM           99
# 939        60.0    GIO        MEDIUM           99
# 940        61.0    GIO        MEDIUM           99
# 941        62.0    GIO        MEDIUM           99
# 942         1.0    MSC           WET           47
# 943         2.0    MSC           WET           47
# 944         3.0    MSC           WET           47
# 945         4.0    MSC           WET           47
# 946         5.0    MSC           WET           47
# 947         6.0    MSC  INTERMEDIATE           47
# 948         7.0    MSC  INTERMEDIATE           47
# 949         8.0    MSC  INTERMEDIATE           47
# 950         9.0    MSC  INTERMEDIATE           47
# 951        10.0    MSC  INTERMEDIATE           47
# 952        11.0    MSC  INTERMEDIATE           47
# 953        12.0    MSC  INTERMEDIATE           47
# 954        13.0    MSC  INTERMEDIATE           47
# 955        14.0    MSC  INTERMEDIATE           47
# 956        15.0    MSC  INTERMEDIATE           47
# 957        16.0    MSC  INTERMEDIATE           47
# 958        17.0    MSC  INTERMEDIATE           47
# 959        18.0    MSC  INTERMEDIATE           47
# 960        19.0    MSC  INTERMEDIATE           47
# 961        20.0    MSC  INTERMEDIATE           47
# 962        21.0    MSC  INTERMEDIATE           47
# 963        22.0    MSC          SOFT           47
# 964        23.0    MSC          SOFT           47
# 965        24.0    MSC          SOFT           47
# 966        25.0    MSC          SOFT           47
# 967        26.0    MSC          SOFT           47
# 968        27.0    MSC          SOFT           47
# 969        28.0    MSC          SOFT           47
# 970        29.0    MSC          SOFT           47
# 971        30.0    MSC          SOFT           47
# 972        31.0    MSC          SOFT           47
# 973        32.0    MSC        MEDIUM           47
# 974        33.0    MSC       UNKNOWN           47
# 975        34.0    MSC       UNKNOWN           47
# 976        35.0    MSC        MEDIUM           47
# 977        36.0    MSC        MEDIUM           47
# 978        37.0    MSC        MEDIUM           47
# 979        38.0    MSC        MEDIUM           47
# 980        39.0    MSC        MEDIUM           47
# 981        40.0    MSC        MEDIUM           47
# 982        41.0    MSC        MEDIUM           47
# 983        42.0    MSC        MEDIUM           47
# 984        43.0    MSC        MEDIUM           47
# 985        44.0    MSC        MEDIUM           47
# 986        45.0    MSC        MEDIUM           47
# 987        46.0    MSC        MEDIUM           47
# 988        47.0    MSC        MEDIUM           47
# 989        48.0    MSC        MEDIUM           47
# 990        49.0    MSC        MEDIUM           47
# 991        50.0    MSC        MEDIUM           47
# 992        51.0    MSC        MEDIUM           47
# 993        52.0    MSC        MEDIUM           47
# 994        53.0    MSC        MEDIUM           47
# 995        54.0    MSC        MEDIUM           47
# 996        55.0    MSC        MEDIUM           47
# 997        56.0    MSC        MEDIUM           47
# 998        57.0    MSC        MEDIUM           47
# 999        58.0    MSC        MEDIUM           47
# 1000       59.0    MSC        MEDIUM           47
# 1001       60.0    MSC        MEDIUM           47
# 1002       61.0    MSC        MEDIUM           47
# 1003        1.0    MAZ           WET            9
# 1004        2.0    MAZ           WET            9
# 1005        3.0    MAZ           WET            9
# 1006        4.0    MAZ           WET            9
# 1007        5.0    MAZ           WET            9
# 1008        6.0    MAZ           WET            9
# 1009        7.0    MAZ           WET            9
# 1010        8.0    MAZ           WET            9
# 1011        9.0    MAZ           WET            9
# 1012       10.0    MAZ           WET            9
# 1013       11.0    MAZ           WET            9
# 1014       12.0    MAZ           WET            9
# 1015       13.0    MAZ  INTERMEDIATE            9
# 1016       14.0    MAZ  INTERMEDIATE            9
# 1017       15.0    MAZ  INTERMEDIATE            9
# 1018       16.0    MAZ  INTERMEDIATE            9
# 1019       17.0    MAZ  INTERMEDIATE            9
# 1020       18.0    MAZ  INTERMEDIATE            9
# 1021       19.0    MAZ  INTERMEDIATE            9
# 1022       20.0    MAZ  INTERMEDIATE            9
# 1023       21.0    MAZ  INTERMEDIATE            9
# 1024       22.0    MAZ  INTERMEDIATE            9
# 1025       23.0    MAZ  INTERMEDIATE            9
# 1026       24.0    MAZ          SOFT            9
# 1027       25.0    MAZ          SOFT            9
# 1028       26.0    MAZ          SOFT            9
# 1029       27.0    MAZ          SOFT            9
# 1030       28.0    MAZ          SOFT            9
# 1031       29.0    MAZ          SOFT            9
# 1032       30.0    MAZ          SOFT            9
# 1033       31.0    MAZ          SOFT            9
# 1034       32.0    MAZ        MEDIUM            9
# 1035       33.0    MAZ       UNKNOWN            9
# 1036       34.0    MAZ       UNKNOWN            9
# 1037       35.0    MAZ        MEDIUM            9
# 1038       36.0    MAZ        MEDIUM            9
# 1039       37.0    MAZ        MEDIUM            9
# 1040       38.0    MAZ        MEDIUM            9
# 1041       39.0    MAZ        MEDIUM            9
# 1042       40.0    MAZ        MEDIUM            9
# 1043       41.0    MAZ        MEDIUM            9
# 1044       42.0    MAZ        MEDIUM            9
# 1045       43.0    MAZ        MEDIUM            9
# 1046       44.0    MAZ        MEDIUM            9
# 1047       45.0    MAZ        MEDIUM            9
# 1048       46.0    MAZ        MEDIUM            9
# 1049       47.0    MAZ        MEDIUM            9
# 1050       48.0    MAZ        MEDIUM            9
# 1051       49.0    MAZ        MEDIUM            9
# 1052       50.0    MAZ        MEDIUM            9
# 1053       51.0    MAZ        MEDIUM            9
# 1054       52.0    MAZ        MEDIUM            9
# 1055       53.0    MAZ        MEDIUM            9
# 1056       54.0    MAZ        MEDIUM            9
# 1057       55.0    MAZ        MEDIUM            9
# 1058       56.0    MAZ        MEDIUM            9
# 1059       57.0    MAZ        MEDIUM            9
# 1060       58.0    MAZ        MEDIUM            9
# 1061       59.0    MAZ        MEDIUM            9
# 1062       60.0    MAZ        MEDIUM            9
# 1063       61.0    MAZ        MEDIUM            9
# 1064        1.0    TSU  INTERMEDIATE           22
# 1065        2.0    TSU  INTERMEDIATE           22
# 1066        3.0    TSU  INTERMEDIATE           22
# 1067        4.0    TSU  INTERMEDIATE           22
# 1068        5.0    TSU  INTERMEDIATE           22
# 1069        6.0    TSU  INTERMEDIATE           22
# 1070        7.0    TSU  INTERMEDIATE           22
# 1071        8.0    TSU  INTERMEDIATE           22
# 1072        9.0    TSU  INTERMEDIATE           22
# 1073       10.0    TSU  INTERMEDIATE           22
# 1074       11.0    TSU  INTERMEDIATE           22
# 1075       12.0    TSU  INTERMEDIATE           22
# 1076       13.0    TSU  INTERMEDIATE           22
# 1077       14.0    TSU  INTERMEDIATE           22
# 1078       15.0    TSU  INTERMEDIATE           22
# 1079       16.0    TSU  INTERMEDIATE           22
# 1080       17.0    TSU  INTERMEDIATE           22
# 1081       18.0    TSU  INTERMEDIATE           22
# 1082       19.0    TSU  INTERMEDIATE           22
# 1083       20.0    TSU  INTERMEDIATE           22
# 1084       21.0    TSU  INTERMEDIATE           22
# 1085       22.0    TSU  INTERMEDIATE           22
# 1086       23.0    TSU  INTERMEDIATE           22
# 1087       24.0    TSU  INTERMEDIATE           22
# 1088       25.0    TSU  INTERMEDIATE           22
# 1089       26.0    TSU        MEDIUM           22
# 1090       27.0    TSU        MEDIUM           22
# 1091       28.0    TSU        MEDIUM           22
# 1092       29.0    TSU        MEDIUM           22
# 1093       30.0    TSU        MEDIUM           22
# 1094       31.0    TSU        MEDIUM           22
# 1095       32.0    TSU        MEDIUM           22
# 1096       33.0    TSU          SOFT           22
# 1097       34.0    TSU          SOFT           22
# 1098       35.0    TSU          SOFT           22
# 1099       36.0    TSU          SOFT           22
# 1100       37.0    TSU          SOFT           22
# 1101       38.0    TSU          SOFT           22
# 1102       39.0    TSU          SOFT           22
# 1103       40.0    TSU          SOFT           22
# 1104       41.0    TSU          SOFT           22
# 1105       42.0    TSU          SOFT           22
# 1106       43.0    TSU          SOFT           22
# 1107       44.0    TSU          SOFT           22
# 1108       45.0    TSU          SOFT           22
# 1109       46.0    TSU          SOFT           22
# 1110       47.0    TSU          SOFT           22
# 1111       48.0    TSU          SOFT           22
# 1112       49.0    TSU          SOFT           22
# 1113       50.0    TSU          SOFT           22
# 1114       51.0    TSU          SOFT           22
# 1115       52.0    TSU          SOFT           22
# 1116       53.0    TSU          SOFT           22
# 1117       54.0    TSU          SOFT           22
# 1118       55.0    TSU          SOFT           22
# 1119       56.0    TSU          SOFT           22
# 1120       57.0    TSU          SOFT           22
# 1121       58.0    TSU          SOFT           22
# 1122       59.0    TSU          SOFT           22
# 1123       60.0    TSU          SOFT           22
# 1124       61.0    TSU          SOFT           22
# 1125       62.0    TSU          SOFT           22
# 1126       63.0    TSU          SOFT           22

# %%
# connect both races 
pd.concat([laps_info, laps_2_info])
# Out:
#       LapNumber Driver      Compound DriverNumber
# 0           1.0    VER        MEDIUM           33
# 1           2.0    VER        MEDIUM           33
# 2           3.0    VER        MEDIUM           33
# 3           4.0    VER        MEDIUM           33
# 4           5.0    VER        MEDIUM           33
# 5           6.0    VER        MEDIUM           33
# 6           7.0    VER        MEDIUM           33
# 7           8.0    VER        MEDIUM           33
# 8           9.0    VER        MEDIUM           33
# 9          10.0    VER        MEDIUM           33
# 10         11.0    VER        MEDIUM           33
# 11         12.0    VER        MEDIUM           33
# 12         13.0    VER        MEDIUM           33
# 13         14.0    VER        MEDIUM           33
# 14         15.0    VER        MEDIUM           33
# 15         16.0    VER        MEDIUM           33
# 16         17.0    VER        MEDIUM           33
# 17         18.0    VER        MEDIUM           33
# 18         19.0    VER        MEDIUM           33
# 19         20.0    VER        MEDIUM           33
# 20         21.0    VER        MEDIUM           33
# 21         22.0    VER        MEDIUM           33
# 22         23.0    VER        MEDIUM           33
# 23         24.0    VER        MEDIUM           33
# 24         25.0    VER        MEDIUM           33
# 25         26.0    VER        MEDIUM           33
# 26         27.0    VER        MEDIUM           33
# 27         28.0    VER        MEDIUM           33
# 28         29.0    VER        MEDIUM           33
# 29         30.0    VER        MEDIUM           33
# 30         31.0    VER        MEDIUM           33
# 31         32.0    VER        MEDIUM           33
# 32         33.0    VER        MEDIUM           33
# 33         34.0    VER        MEDIUM           33
# 34         35.0    VER        MEDIUM           33
# 35         36.0    VER        MEDIUM           33
# 36         37.0    VER        MEDIUM           33
# 37         38.0    VER        MEDIUM           33
# 38         39.0    VER        MEDIUM           33
# 39         40.0    VER          HARD           33
# 40         41.0    VER          HARD           33
# 41         42.0    VER          HARD           33
# 42         43.0    VER          HARD           33
# 43         44.0    VER          HARD           33
# 44         45.0    VER          HARD           33
# 45         46.0    VER          HARD           33
# 46         47.0    VER          HARD           33
# 47         48.0    VER          HARD           33
# 48         49.0    VER          HARD           33
# 49         50.0    VER          HARD           33
# 50         51.0    VER          HARD           33
# 51         52.0    VER          HARD           33
# 52         53.0    VER          HARD           33
# 53         54.0    VER          HARD           33
# 54         55.0    VER          HARD           33
# 55         56.0    VER          HARD           33
# 56          1.0    HAM        MEDIUM           44
# 57          2.0    HAM        MEDIUM           44
# 58          3.0    HAM        MEDIUM           44
# 59          4.0    HAM        MEDIUM           44
# 60          5.0    HAM        MEDIUM           44
# 61          6.0    HAM        MEDIUM           44
# 62          7.0    HAM        MEDIUM           44
# 63          8.0    HAM        MEDIUM           44
# 64          9.0    HAM        MEDIUM           44
# 65         10.0    HAM        MEDIUM           44
# 66         11.0    HAM        MEDIUM           44
# 67         12.0    HAM        MEDIUM           44
# 68         13.0    HAM        MEDIUM           44
# 69         14.0    HAM          HARD           44
# 70         15.0    HAM          HARD           44
# 71         16.0    HAM          HARD           44
# 72         17.0    HAM          HARD           44
# 73         18.0    HAM          HARD           44
# 74         19.0    HAM          HARD           44
# 75         20.0    HAM          HARD           44
# 76         21.0    HAM          HARD           44
# 77         22.0    HAM          HARD           44
# 78         23.0    HAM          HARD           44
# 79         24.0    HAM          HARD           44
# 80         25.0    HAM          HARD           44
# 81         26.0    HAM          HARD           44
# 82         27.0    HAM          HARD           44
# 83         28.0    HAM          HARD           44
# 84         29.0    HAM          HARD           44
# 85         30.0    HAM          HARD           44
# 86         31.0    HAM          HARD           44
# 87         32.0    HAM          HARD           44
# 88         33.0    HAM          HARD           44
# 89         34.0    HAM          HARD           44
# 90         35.0    HAM          HARD           44
# 91         36.0    HAM          HARD           44
# 92         37.0    HAM          HARD           44
# 93         38.0    HAM          HARD           44
# 94         39.0    HAM          HARD           44
# 95         40.0    HAM          HARD           44
# 96         41.0    HAM          HARD           44
# 97         42.0    HAM          HARD           44
# 98         43.0    HAM          HARD           44
# 99         44.0    HAM          HARD           44
# 100        45.0    HAM          HARD           44
# 101        46.0    HAM          HARD           44
# 102        47.0    HAM          HARD           44
# 103        48.0    HAM          HARD           44
# 104        49.0    HAM          HARD           44
# 105        50.0    HAM          HARD           44
# 106        51.0    HAM          HARD           44
# 107        52.0    HAM          HARD           44
# 108        53.0    HAM          HARD           44
# 109        54.0    HAM          HARD           44
# 110        55.0    HAM          HARD           44
# 111        56.0    HAM          HARD           44
# 112         1.0    BOT        MEDIUM           77
# 113         2.0    BOT        MEDIUM           77
# 114         3.0    BOT        MEDIUM           77
# 115         4.0    BOT        MEDIUM           77
# 116         5.0    BOT        MEDIUM           77
# 117         6.0    BOT        MEDIUM           77
# 118         7.0    BOT        MEDIUM           77
# 119         8.0    BOT        MEDIUM           77
# 120         9.0    BOT        MEDIUM           77
# 121        10.0    BOT        MEDIUM           77
# 122        11.0    BOT        MEDIUM           77
# 123        12.0    BOT        MEDIUM           77
# 124        13.0    BOT        MEDIUM           77
# 125        14.0    BOT        MEDIUM           77
# 126        15.0    BOT        MEDIUM           77
# 127        16.0    BOT        MEDIUM           77
# 128        17.0    BOT          HARD           77
# 129        18.0    BOT          HARD           77
# 130        19.0    BOT          HARD           77
# 131        20.0    BOT          HARD           77
# 132        21.0    BOT          HARD           77
# 133        22.0    BOT          HARD           77
# 134        23.0    BOT          HARD           77
# 135        24.0    BOT          HARD           77
# 136        25.0    BOT          HARD           77
# 137        26.0    BOT          HARD           77
# 138        27.0    BOT          HARD           77
# 139        28.0    BOT          HARD           77
# 140        29.0    BOT          HARD           77
# 141        30.0    BOT          HARD           77
# 142        31.0    BOT          HARD           77
# 143        32.0    BOT          HARD           77
# 144        33.0    BOT          HARD           77
# 145        34.0    BOT          HARD           77
# 146        35.0    BOT          HARD           77
# 147        36.0    BOT          HARD           77
# 148        37.0    BOT          HARD           77
# 149        38.0    BOT          HARD           77
# 150        39.0    BOT          HARD           77
# 151        40.0    BOT          HARD           77
# 152        41.0    BOT          HARD           77
# 153        42.0    BOT          HARD           77
# 154        43.0    BOT          HARD           77
# 155        44.0    BOT          HARD           77
# 156        45.0    BOT          HARD           77
# 157        46.0    BOT          HARD           77
# 158        47.0    BOT          HARD           77
# 159        48.0    BOT          HARD           77
# 160        49.0    BOT          HARD           77
# 161        50.0    BOT          HARD           77
# 162        51.0    BOT          HARD           77
# 163        52.0    BOT          HARD           77
# 164        53.0    BOT          HARD           77
# 165        54.0    BOT          HARD           77
# 166        55.0    BOT        MEDIUM           77
# 167        56.0    BOT        MEDIUM           77
# 168         1.0    LEC          SOFT           16
# 169         2.0    LEC          SOFT           16
# 170         3.0    LEC          SOFT           16
# 171         4.0    LEC          SOFT           16
# 172         5.0    LEC          SOFT           16
# 173         6.0    LEC          SOFT           16
# 174         7.0    LEC          SOFT           16
# 175         8.0    LEC          SOFT           16
# 176         9.0    LEC          SOFT           16
# 177        10.0    LEC          SOFT           16
# 178        11.0    LEC          SOFT           16
# 179        12.0    LEC          SOFT           16
# 180        13.0    LEC        MEDIUM           16
# 181        14.0    LEC        MEDIUM           16
# 182        15.0    LEC        MEDIUM           16
# 183        16.0    LEC        MEDIUM           16
# 184        17.0    LEC        MEDIUM           16
# 185        18.0    LEC        MEDIUM           16
# 186        19.0    LEC        MEDIUM           16
# 187        20.0    LEC        MEDIUM           16
# 188        21.0    LEC        MEDIUM           16
# 189        22.0    LEC        MEDIUM           16
# 190        23.0    LEC        MEDIUM           16
# 191        24.0    LEC        MEDIUM           16
# 192        25.0    LEC        MEDIUM           16
# 193        26.0    LEC        MEDIUM           16
# 194        27.0    LEC        MEDIUM           16
# 195        28.0    LEC        MEDIUM           16
# 196        29.0    LEC        MEDIUM           16
# 197        30.0    LEC        MEDIUM           16
# 198        31.0    LEC        MEDIUM           16
# 199        32.0    LEC        MEDIUM           16
# 200        33.0    LEC          HARD           16
# 201        34.0    LEC          HARD           16
# 202        35.0    LEC          HARD           16
# 203        36.0    LEC          HARD           16
# 204        37.0    LEC          HARD           16
# 205        38.0    LEC          HARD           16
# 206        39.0    LEC          HARD           16
# 207        40.0    LEC          HARD           16
# 208        41.0    LEC          HARD           16
# 209        42.0    LEC          HARD           16
# 210        43.0    LEC          HARD           16
# 211        44.0    LEC          HARD           16
# 212        45.0    LEC          HARD           16
# 213        46.0    LEC          HARD           16
# 214        47.0    LEC          HARD           16
# 215        48.0    LEC          HARD           16
# 216        49.0    LEC          HARD           16
# 217        50.0    LEC          HARD           16
# 218        51.0    LEC          HARD           16
# 219        52.0    LEC          HARD           16
# 220        53.0    LEC          HARD           16
# 221        54.0    LEC          HARD           16
# 222        55.0    LEC          HARD           16
# 223        56.0    LEC          HARD           16
# 224         1.0    GAS        MEDIUM           10
# 225         2.0    GAS        MEDIUM           10
# 226         3.0    GAS        MEDIUM           10
# 227         4.0    GAS        MEDIUM           10
# 228         5.0    GAS          HARD           10
# 229         6.0    GAS          HARD           10
# 230         7.0    GAS          HARD           10
# 231         8.0    GAS          HARD           10
# 232         9.0    GAS          HARD           10
# 233        10.0    GAS          HARD           10
# 234        11.0    GAS          HARD           10
# 235        12.0    GAS          HARD           10
# 236        13.0    GAS          HARD           10
# 237        14.0    GAS          HARD           10
# 238        15.0    GAS          HARD           10
# 239        16.0    GAS          HARD           10
# 240        17.0    GAS          HARD           10
# 241        18.0    GAS          HARD           10
# 242        19.0    GAS          HARD           10
# 243        20.0    GAS        MEDIUM           10
# 244        21.0    GAS        MEDIUM           10
# 245        22.0    GAS        MEDIUM           10
# 246        23.0    GAS        MEDIUM           10
# 247        24.0    GAS        MEDIUM           10
# 248        25.0    GAS        MEDIUM           10
# 249        26.0    GAS        MEDIUM           10
# 250        27.0    GAS        MEDIUM           10
# 251        28.0    GAS        MEDIUM           10
# 252        29.0    GAS        MEDIUM           10
# 253        30.0    GAS        MEDIUM           10
# 254        31.0    GAS        MEDIUM           10
# 255        32.0    GAS        MEDIUM           10
# 256        33.0    GAS        MEDIUM           10
# 257        34.0    GAS        MEDIUM           10
# 258        35.0    GAS        MEDIUM           10
# 259        36.0    GAS        MEDIUM           10
# 260        37.0    GAS        MEDIUM           10
# 261        38.0    GAS        MEDIUM           10
# 262        39.0    GAS        MEDIUM           10
# 263        40.0    GAS          HARD           10
# 264        41.0    GAS          HARD           10
# 265        42.0    GAS          HARD           10
# 266        43.0    GAS          HARD           10
# 267        44.0    GAS          HARD           10
# 268        45.0    GAS          HARD           10
# 269        46.0    GAS          HARD           10
# 270        47.0    GAS          HARD           10
# 271        48.0    GAS          HARD           10
# 272        49.0    GAS          HARD           10
# 273        50.0    GAS          HARD           10
# 274        51.0    GAS          HARD           10
# 275        52.0    GAS          HARD           10
# 276         1.0    RIC          SOFT            3
# 277         2.0    RIC          SOFT            3
# 278         3.0    RIC          SOFT            3
# 279         4.0    RIC          SOFT            3
# 280         5.0    RIC          SOFT            3
# 281         6.0    RIC          SOFT            3
# 282         7.0    RIC          SOFT            3
# 283         8.0    RIC          SOFT            3
# 284         9.0    RIC          SOFT            3
# 285        10.0    RIC          SOFT            3
# 286        11.0    RIC          SOFT            3
# 287        12.0    RIC          SOFT            3
# 288        13.0    RIC          SOFT            3
# 289        14.0    RIC        MEDIUM            3
# 290        15.0    RIC        MEDIUM            3
# 291        16.0    RIC        MEDIUM            3
# 292        17.0    RIC        MEDIUM            3
# 293        18.0    RIC        MEDIUM            3
# 294        19.0    RIC        MEDIUM            3
# 295        20.0    RIC        MEDIUM            3
# 296        21.0    RIC        MEDIUM            3
# 297        22.0    RIC        MEDIUM            3
# 298        23.0    RIC        MEDIUM            3
# 299        24.0    RIC        MEDIUM            3
# 300        25.0    RIC        MEDIUM            3
# 301        26.0    RIC        MEDIUM            3
# 302        27.0    RIC        MEDIUM            3
# 303        28.0    RIC        MEDIUM            3
# 304        29.0    RIC        MEDIUM            3
# 305        30.0    RIC        MEDIUM            3
# 306        31.0    RIC        MEDIUM            3
# 307        32.0    RIC        MEDIUM            3
# 308        33.0    RIC          HARD            3
# 309        34.0    RIC          HARD            3
# 310        35.0    RIC          HARD            3
# 311        36.0    RIC          HARD            3
# 312        37.0    RIC          HARD            3
# 313        38.0    RIC          HARD            3
# 314        39.0    RIC          HARD            3
# 315        40.0    RIC          HARD            3
# 316        41.0    RIC          HARD            3
# 317        42.0    RIC          HARD            3
# 318        43.0    RIC          HARD            3
# 319        44.0    RIC          HARD            3
# 320        45.0    RIC          HARD            3
# 321        46.0    RIC          HARD            3
# 322        47.0    RIC          HARD            3
# 323        48.0    RIC          HARD            3
# 324        49.0    RIC          HARD            3
# 325        50.0    RIC          HARD            3
# 326        51.0    RIC          HARD            3
# 327        52.0    RIC          HARD            3
# 328        53.0    RIC          HARD            3
# 329        54.0    RIC          HARD            3
# 330        55.0    RIC          HARD            3
# 331        56.0    RIC          HARD            3
# 332         1.0    NOR          SOFT            4
# 333         2.0    NOR          SOFT            4
# 334         3.0    NOR          SOFT            4
# 335         4.0    NOR          SOFT            4
# 336         5.0    NOR          SOFT            4
# 337         6.0    NOR          SOFT            4
# 338         7.0    NOR          SOFT            4
# 339         8.0    NOR          SOFT            4
# 340         9.0    NOR          SOFT            4
# 341        10.0    NOR          SOFT            4
# 342        11.0    NOR          SOFT            4
# 343        12.0    NOR          SOFT            4
# 344        13.0    NOR        MEDIUM            4
# 345        14.0    NOR        MEDIUM            4
# 346        15.0    NOR        MEDIUM            4
# 347        16.0    NOR        MEDIUM            4
# 348        17.0    NOR        MEDIUM            4
# 349        18.0    NOR        MEDIUM            4
# 350        19.0    NOR        MEDIUM            4
# 351        20.0    NOR        MEDIUM            4
# 352        21.0    NOR        MEDIUM            4
# 353        22.0    NOR        MEDIUM            4
# 354        23.0    NOR        MEDIUM            4
# 355        24.0    NOR        MEDIUM            4
# 356        25.0    NOR        MEDIUM            4
# 357        26.0    NOR        MEDIUM            4
# 358        27.0    NOR        MEDIUM            4
# 359        28.0    NOR        MEDIUM            4
# 360        29.0    NOR        MEDIUM            4
# 361        30.0    NOR        MEDIUM            4
# 362        31.0    NOR        MEDIUM            4
# 363        32.0    NOR        MEDIUM            4
# 364        33.0    NOR        MEDIUM            4
# 365        34.0    NOR          HARD            4
# 366        35.0    NOR          HARD            4
# 367        36.0    NOR          HARD            4
# 368        37.0    NOR          HARD            4
# 369        38.0    NOR          HARD            4
# 370        39.0    NOR          HARD            4
# 371        40.0    NOR          HARD            4
# 372        41.0    NOR          HARD            4
# 373        42.0    NOR          HARD            4
# 374        43.0    NOR          HARD            4
# 375        44.0    NOR          HARD            4
# 376        45.0    NOR          HARD            4
# 377        46.0    NOR          HARD            4
# 378        47.0    NOR          HARD            4
# 379        48.0    NOR          HARD            4
# 380        49.0    NOR          HARD            4
# 381        50.0    NOR          HARD            4
# 382        51.0    NOR          HARD            4
# 383        52.0    NOR          HARD            4
# 384        53.0    NOR          HARD            4
# 385        54.0    NOR          HARD            4
# 386        55.0    NOR          HARD            4
# 387        56.0    NOR          HARD            4
# 388         1.0    SAI          SOFT           55
# 389         2.0    SAI          SOFT           55
# 390         3.0    SAI          SOFT           55
# 391         4.0    SAI          SOFT           55
# 392         5.0    SAI          SOFT           55
# 393         6.0    SAI          SOFT           55
# 394         7.0    SAI          SOFT           55
# 395         8.0    SAI          SOFT           55
# 396         9.0    SAI          SOFT           55
# 397        10.0    SAI          SOFT           55
# 398        11.0    SAI          SOFT           55
# 399        12.0    SAI          SOFT           55
# 400        13.0    SAI          SOFT           55
# 401        14.0    SAI          SOFT           55
# 402        15.0    SAI          SOFT           55
# 403        16.0    SAI        MEDIUM           55
# 404        17.0    SAI        MEDIUM           55
# 405        18.0    SAI        MEDIUM           55
# 406        19.0    SAI        MEDIUM           55
# 407        20.0    SAI        MEDIUM           55
# 408        21.0    SAI        MEDIUM           55
# 409        22.0    SAI        MEDIUM           55
# 410        23.0    SAI        MEDIUM           55
# 411        24.0    SAI        MEDIUM           55
# 412        25.0    SAI        MEDIUM           55
# 413        26.0    SAI        MEDIUM           55
# 414        27.0    SAI        MEDIUM           55
# 415        28.0    SAI        MEDIUM           55
# 416        29.0    SAI        MEDIUM           55
# 417        30.0    SAI        MEDIUM           55
# 418        31.0    SAI        MEDIUM           55
# 419        32.0    SAI        MEDIUM           55
# 420        33.0    SAI        MEDIUM           55
# 421        34.0    SAI        MEDIUM           55
# 422        35.0    SAI        MEDIUM           55
# 423        36.0    SAI        MEDIUM           55
# 424        37.0    SAI        MEDIUM           55
# 425        38.0    SAI          HARD           55
# 426        39.0    SAI          HARD           55
# 427        40.0    SAI          HARD           55
# 428        41.0    SAI          HARD           55
# 429        42.0    SAI          HARD           55
# 430        43.0    SAI          HARD           55
# 431        44.0    SAI          HARD           55
# 432        45.0    SAI          HARD           55
# 433        46.0    SAI          HARD           55
# 434        47.0    SAI          HARD           55
# 435        48.0    SAI          HARD           55
# 436        49.0    SAI          HARD           55
# 437        50.0    SAI          HARD           55
# 438        51.0    SAI          HARD           55
# 439        52.0    SAI          HARD           55
# 440        53.0    SAI          HARD           55
# 441        54.0    SAI          HARD           55
# 442        55.0    SAI          HARD           55
# 443        56.0    SAI          HARD           55
# 444         1.0    ALO          SOFT           14
# 445         2.0    ALO          SOFT           14
# 446         3.0    ALO          SOFT           14
# 447         4.0    ALO          SOFT           14
# 448         5.0    ALO          SOFT           14
# 449         6.0    ALO          SOFT           14
# 450         7.0    ALO          SOFT           14
# 451         8.0    ALO          SOFT           14
# 452         9.0    ALO          SOFT           14
# 453        10.0    ALO          SOFT           14
# 454        11.0    ALO          SOFT           14
# 455        12.0    ALO        MEDIUM           14
# 456        13.0    ALO        MEDIUM           14
# 457        14.0    ALO        MEDIUM           14
# 458        15.0    ALO        MEDIUM           14
# 459        16.0    ALO        MEDIUM           14
# 460        17.0    ALO        MEDIUM           14
# 461        18.0    ALO        MEDIUM           14
# 462        19.0    ALO        MEDIUM           14
# 463        20.0    ALO        MEDIUM           14
# 464        21.0    ALO        MEDIUM           14
# 465        22.0    ALO        MEDIUM           14
# 466        23.0    ALO        MEDIUM           14
# 467        24.0    ALO        MEDIUM           14
# 468        25.0    ALO        MEDIUM           14
# 469        26.0    ALO        MEDIUM           14
# 470        27.0    ALO        MEDIUM           14
# 471        28.0    ALO        MEDIUM           14
# 472        29.0    ALO        MEDIUM           14
# 473        30.0    ALO          HARD           14
# 474        31.0    ALO          HARD           14
# 475        32.0    ALO          HARD           14
# 476         1.0    STR          SOFT           18
# 477         2.0    STR          SOFT           18
# 478         3.0    STR          SOFT           18
# 479         4.0    STR          SOFT           18
# 480         5.0    STR          SOFT           18
# 481         6.0    STR          SOFT           18
# 482         7.0    STR          SOFT           18
# 483         8.0    STR          SOFT           18
# 484         9.0    STR          SOFT           18
# 485        10.0    STR          SOFT           18
# 486        11.0    STR          SOFT           18
# 487        12.0    STR          SOFT           18
# 488        13.0    STR        MEDIUM           18
# 489        14.0    STR        MEDIUM           18
# 490        15.0    STR        MEDIUM           18
# 491        16.0    STR        MEDIUM           18
# 492        17.0    STR        MEDIUM           18
# 493        18.0    STR        MEDIUM           18
# 494        19.0    STR        MEDIUM           18
# 495        20.0    STR        MEDIUM           18
# 496        21.0    STR        MEDIUM           18
# 497        22.0    STR        MEDIUM           18
# 498        23.0    STR        MEDIUM           18
# 499        24.0    STR        MEDIUM           18
# 500        25.0    STR        MEDIUM           18
# 501        26.0    STR        MEDIUM           18
# 502        27.0    STR        MEDIUM           18
# 503        28.0    STR        MEDIUM           18
# 504        29.0    STR       UNKNOWN           18
# 505        30.0    STR          HARD           18
# 506        31.0    STR          HARD           18
# 507        32.0    STR          HARD           18
# 508        33.0    STR          HARD           18
# 509        34.0    STR          HARD           18
# 510        35.0    STR          HARD           18
# 511        36.0    STR          HARD           18
# 512        37.0    STR          HARD           18
# 513        38.0    STR          HARD           18
# 514        39.0    STR          HARD           18
# 515        40.0    STR          HARD           18
# 516        41.0    STR          HARD           18
# 517        42.0    STR          HARD           18
# 518        43.0    STR          HARD           18
# 519        44.0    STR          HARD           18
# 520        45.0    STR          HARD           18
# 521        46.0    STR          HARD           18
# 522        47.0    STR          HARD           18
# 523        48.0    STR          HARD           18
# 524        49.0    STR          HARD           18
# 525        50.0    STR          HARD           18
# 526        51.0    STR          HARD           18
# 527        52.0    STR          HARD           18
# 528        53.0    STR          HARD           18
# 529        54.0    STR          HARD           18
# 530        55.0    STR          HARD           18
# 531        56.0    STR          HARD           18
# 532         1.0    PER        MEDIUM           11
# 533         2.0    PER        MEDIUM           11
# 534         3.0    PER        MEDIUM           11
# 535         4.0    PER        MEDIUM           11
# 536         5.0    PER        MEDIUM           11
# 537         6.0    PER        MEDIUM           11
# 538         7.0    PER        MEDIUM           11
# 539         8.0    PER        MEDIUM           11
# 540         9.0    PER        MEDIUM           11
# 541        10.0    PER        MEDIUM           11
# 542        11.0    PER        MEDIUM           11
# 543        12.0    PER        MEDIUM           11
# 544        13.0    PER        MEDIUM           11
# 545        14.0    PER        MEDIUM           11
# 546        15.0    PER        MEDIUM           11
# 547        16.0    PER        MEDIUM           11
# 548        17.0    PER        MEDIUM           11
# 549        18.0    PER        MEDIUM           11
# 550        19.0    PER        MEDIUM           11
# 551        20.0    PER          HARD           11
# 552        21.0    PER          HARD           11
# 553        22.0    PER          HARD           11
# 554        23.0    PER          HARD           11
# 555        24.0    PER          HARD           11
# 556        25.0    PER          HARD           11
# 557        26.0    PER          HARD           11
# 558        27.0    PER          HARD           11
# 559        28.0    PER          HARD           11
# 560        29.0    PER          HARD           11
# 561        30.0    PER          HARD           11
# 562        31.0    PER          HARD           11
# 563        32.0    PER          HARD           11
# 564        33.0    PER          HARD           11
# 565        34.0    PER          HARD           11
# 566        35.0    PER          HARD           11
# 567        36.0    PER          HARD           11
# 568        37.0    PER          HARD           11
# 569        38.0    PER          HARD           11
# 570        39.0    PER        MEDIUM           11
# 571        40.0    PER        MEDIUM           11
# 572        41.0    PER        MEDIUM           11
# 573        42.0    PER        MEDIUM           11
# 574        43.0    PER        MEDIUM           11
# 575        44.0    PER        MEDIUM           11
# 576        45.0    PER        MEDIUM           11
# 577        46.0    PER        MEDIUM           11
# 578        47.0    PER        MEDIUM           11
# 579        48.0    PER        MEDIUM           11
# 580        49.0    PER        MEDIUM           11
# 581        50.0    PER        MEDIUM           11
# 582        51.0    PER        MEDIUM           11
# 583        52.0    PER        MEDIUM           11
# 584        53.0    PER        MEDIUM           11
# 585        54.0    PER        MEDIUM           11
# 586        55.0    PER        MEDIUM           11
# 587        56.0    PER        MEDIUM           11
# 588         1.0    GIO        MEDIUM           99
# 589         2.0    GIO        MEDIUM           99
# 590         3.0    GIO        MEDIUM           99
# 591         4.0    GIO        MEDIUM           99
# 592         5.0    GIO        MEDIUM           99
# 593         6.0    GIO        MEDIUM           99
# 594         7.0    GIO        MEDIUM           99
# 595         8.0    GIO        MEDIUM           99
# 596         9.0    GIO        MEDIUM           99
# 597        10.0    GIO        MEDIUM           99
# 598        11.0    GIO        MEDIUM           99
# 599        12.0    GIO        MEDIUM           99
# 600        13.0    GIO          HARD           99
# 601        14.0    GIO          HARD           99
# 602        15.0    GIO          HARD           99
# 603        16.0    GIO          HARD           99
# 604        17.0    GIO          HARD           99
# 605        18.0    GIO          HARD           99
# 606        19.0    GIO          HARD           99
# 607        20.0    GIO          HARD           99
# 608        21.0    GIO          HARD           99
# 609        22.0    GIO          HARD           99
# 610        23.0    GIO          HARD           99
# 611        24.0    GIO          HARD           99
# 612        25.0    GIO          HARD           99
# 613        26.0    GIO          HARD           99
# 614        27.0    GIO          HARD           99
# 615        28.0    GIO          HARD           99
# 616        29.0    GIO          HARD           99
# 617        30.0    GIO          HARD           99
# 618        31.0    GIO        MEDIUM           99
# 619        32.0    GIO        MEDIUM           99
# 620        33.0    GIO        MEDIUM           99
# 621        34.0    GIO        MEDIUM           99
# 622        35.0    GIO        MEDIUM           99
# 623        36.0    GIO        MEDIUM           99
# 624        37.0    GIO        MEDIUM           99
# 625        38.0    GIO        MEDIUM           99
# 626        39.0    GIO        MEDIUM           99
# 627        40.0    GIO        MEDIUM           99
# 628        41.0    GIO        MEDIUM           99
# 629        42.0    GIO        MEDIUM           99
# 630        43.0    GIO        MEDIUM           99
# 631        44.0    GIO        MEDIUM           99
# 632        45.0    GIO        MEDIUM           99
# 633        46.0    GIO        MEDIUM           99
# 634        47.0    GIO        MEDIUM           99
# 635        48.0    GIO        MEDIUM           99
# 636        49.0    GIO        MEDIUM           99
# 637        50.0    GIO        MEDIUM           99
# 638        51.0    GIO        MEDIUM           99
# 639        52.0    GIO        MEDIUM           99
# 640        53.0    GIO        MEDIUM           99
# 641        54.0    GIO        MEDIUM           99
# 642        55.0    GIO        MEDIUM           99
# 643         1.0    TSU        MEDIUM           22
# 644         2.0    TSU        MEDIUM           22
# 645         3.0    TSU        MEDIUM           22
# 646         4.0    TSU        MEDIUM           22
# 647         5.0    TSU        MEDIUM           22
# 648         6.0    TSU        MEDIUM           22
# 649         7.0    TSU        MEDIUM           22
# 650         8.0    TSU        MEDIUM           22
# 651         9.0    TSU        MEDIUM           22
# 652        10.0    TSU        MEDIUM           22
# 653        11.0    TSU        MEDIUM           22
# 654        12.0    TSU        MEDIUM           22
# 655        13.0    TSU        MEDIUM           22
# 656        14.0    TSU        MEDIUM           22
# 657        15.0    TSU        MEDIUM           22
# 658        16.0    TSU          HARD           22
# 659        17.0    TSU          HARD           22
# 660        18.0    TSU          HARD           22
# 661        19.0    TSU          HARD           22
# 662        20.0    TSU          HARD           22
# 663        21.0    TSU          HARD           22
# 664        22.0    TSU          HARD           22
# 665        23.0    TSU          HARD           22
# 666        24.0    TSU          HARD           22
# 667        25.0    TSU          HARD           22
# 668        26.0    TSU          HARD           22
# 669        27.0    TSU          HARD           22
# 670        28.0    TSU          HARD           22
# 671        29.0    TSU          HARD           22
# 672        30.0    TSU          HARD           22
# 673        31.0    TSU          HARD           22
# 674        32.0    TSU          HARD           22
# 675        33.0    TSU          HARD           22
# 676        34.0    TSU          HARD           22
# 677        35.0    TSU          HARD           22
# 678        36.0    TSU          HARD           22
# 679        37.0    TSU          HARD           22
# 680        38.0    TSU          HARD           22
# 681        39.0    TSU          HARD           22
# 682        40.0    TSU          HARD           22
# 683        41.0    TSU          HARD           22
# 684        42.0    TSU          HARD           22
# 685        43.0    TSU          HARD           22
# 686        44.0    TSU          HARD           22
# 687        45.0    TSU          HARD           22
# 688        46.0    TSU          HARD           22
# 689        47.0    TSU          HARD           22
# 690        48.0    TSU          HARD           22
# 691        49.0    TSU          HARD           22
# 692        50.0    TSU          HARD           22
# 693        51.0    TSU          HARD           22
# 694        52.0    TSU          HARD           22
# 695        53.0    TSU          HARD           22
# 696        54.0    TSU          HARD           22
# 697        55.0    TSU          HARD           22
# 698        56.0    TSU          HARD           22
# 699         1.0    RAI        MEDIUM            7
# 700         2.0    RAI        MEDIUM            7
# 701         3.0    RAI        MEDIUM            7
# 702         4.0    RAI        MEDIUM            7
# 703         5.0    RAI        MEDIUM            7
# 704         6.0    RAI        MEDIUM            7
# 705         7.0    RAI        MEDIUM            7
# 706         8.0    RAI        MEDIUM            7
# 707         9.0    RAI        MEDIUM            7
# 708        10.0    RAI        MEDIUM            7
# 709        11.0    RAI        MEDIUM            7
# 710        12.0    RAI        MEDIUM            7
# 711        13.0    RAI        MEDIUM            7
# 712        14.0    RAI          HARD            7
# 713        15.0    RAI          HARD            7
# 714        16.0    RAI          HARD            7
# 715        17.0    RAI          HARD            7
# 716        18.0    RAI          HARD            7
# 717        19.0    RAI          HARD            7
# 718        20.0    RAI          HARD            7
# 719        21.0    RAI          HARD            7
# 720        22.0    RAI          HARD            7
# 721        23.0    RAI          HARD            7
# 722        24.0    RAI          HARD            7
# 723        25.0    RAI          HARD            7
# 724        26.0    RAI          HARD            7
# 725        27.0    RAI          HARD            7
# 726        28.0    RAI          HARD            7
# 727        29.0    RAI          HARD            7
# 728        30.0    RAI        MEDIUM            7
# 729        31.0    RAI        MEDIUM            7
# 730        32.0    RAI        MEDIUM            7
# 731        33.0    RAI        MEDIUM            7
# 732        34.0    RAI        MEDIUM            7
# 733        35.0    RAI        MEDIUM            7
# 734        36.0    RAI        MEDIUM            7
# 735        37.0    RAI        MEDIUM            7
# 736        38.0    RAI        MEDIUM            7
# 737        39.0    RAI        MEDIUM            7
# 738        40.0    RAI        MEDIUM            7
# 739        41.0    RAI        MEDIUM            7
# 740        42.0    RAI        MEDIUM            7
# 741        43.0    RAI        MEDIUM            7
# 742        44.0    RAI        MEDIUM            7
# 743        45.0    RAI        MEDIUM            7
# 744        46.0    RAI        MEDIUM            7
# 745        47.0    RAI        MEDIUM            7
# 746        48.0    RAI        MEDIUM            7
# 747        49.0    RAI        MEDIUM            7
# 748        50.0    RAI        MEDIUM            7
# 749        51.0    RAI        MEDIUM            7
# 750        52.0    RAI        MEDIUM            7
# 751        53.0    RAI        MEDIUM            7
# 752        54.0    RAI        MEDIUM            7
# 753        55.0    RAI        MEDIUM            7
# 754        56.0    RAI        MEDIUM            7
# 755         1.0    RUS          SOFT           63
# 756         2.0    RUS          SOFT           63
# 757         3.0    RUS          SOFT           63
# 758         4.0    RUS          SOFT           63
# 759         5.0    RUS          SOFT           63
# 760         6.0    RUS          SOFT           63
# 761         7.0    RUS          SOFT           63
# 762         8.0    RUS          SOFT           63
# 763         9.0    RUS          SOFT           63
# 764        10.0    RUS          SOFT           63
# 765        11.0    RUS          SOFT           63
# 766        12.0    RUS          SOFT           63
# 767        13.0    RUS          SOFT           63
# 768        14.0    RUS        MEDIUM           63
# 769        15.0    RUS        MEDIUM           63
# 770        16.0    RUS        MEDIUM           63
# 771        17.0    RUS        MEDIUM           63
# 772        18.0    RUS        MEDIUM           63
# 773        19.0    RUS        MEDIUM           63
# 774        20.0    RUS        MEDIUM           63
# 775        21.0    RUS        MEDIUM           63
# 776        22.0    RUS        MEDIUM           63
# 777        23.0    RUS        MEDIUM           63
# 778        24.0    RUS        MEDIUM           63
# 779        25.0    RUS        MEDIUM           63
# 780        26.0    RUS        MEDIUM           63
# 781        27.0    RUS        MEDIUM           63
# 782        28.0    RUS        MEDIUM           63
# 783        29.0    RUS        MEDIUM           63
# 784        30.0    RUS        MEDIUM           63
# 785        31.0    RUS        MEDIUM           63
# 786        32.0    RUS        MEDIUM           63
# 787        33.0    RUS        MEDIUM           63
# 788        34.0    RUS        MEDIUM           63
# 789        35.0    RUS        MEDIUM           63
# 790        36.0    RUS        MEDIUM           63
# 791        37.0    RUS        MEDIUM           63
# 792        38.0    RUS        MEDIUM           63
# 793        39.0    RUS        MEDIUM           63
# 794        40.0    RUS        MEDIUM           63
# 795        41.0    RUS        MEDIUM           63
# 796        42.0    RUS        MEDIUM           63
# 797        43.0    RUS        MEDIUM           63
# 798        44.0    RUS        MEDIUM           63
# 799        45.0    RUS        MEDIUM           63
# 800        46.0    RUS        MEDIUM           63
# 801        47.0    RUS        MEDIUM           63
# 802        48.0    RUS        MEDIUM           63
# 803        49.0    RUS        MEDIUM           63
# 804        50.0    RUS        MEDIUM           63
# 805        51.0    RUS        MEDIUM           63
# 806        52.0    RUS        MEDIUM           63
# 807        53.0    RUS        MEDIUM           63
# 808        54.0    RUS        MEDIUM           63
# 809        55.0    RUS        MEDIUM           63
# 810         1.0    OCO          SOFT           31
# 811         2.0    OCO          SOFT           31
# 812         3.0    OCO          SOFT           31
# 813         4.0    OCO          SOFT           31
# 814         5.0    OCO          SOFT           31
# 815         6.0    OCO          SOFT           31
# 816         7.0    OCO          SOFT           31
# 817         8.0    OCO          SOFT           31
# 818         9.0    OCO          SOFT           31
# 819        10.0    OCO          SOFT           31
# 820        11.0    OCO          SOFT           31
# 821        12.0    OCO          SOFT           31
# 822        13.0    OCO          SOFT           31
# 823        14.0    OCO        MEDIUM           31
# 824        15.0    OCO        MEDIUM           31
# 825        16.0    OCO        MEDIUM           31
# 826        17.0    OCO        MEDIUM           31
# 827        18.0    OCO        MEDIUM           31
# 828        19.0    OCO        MEDIUM           31
# 829        20.0    OCO        MEDIUM           31
# 830        21.0    OCO        MEDIUM           31
# 831        22.0    OCO        MEDIUM           31
# 832        23.0    OCO        MEDIUM           31
# 833        24.0    OCO        MEDIUM           31
# 834        25.0    OCO        MEDIUM           31
# 835        26.0    OCO        MEDIUM           31
# 836        27.0    OCO        MEDIUM           31
# 837        28.0    OCO        MEDIUM           31
# 838        29.0    OCO        MEDIUM           31
# 839        30.0    OCO        MEDIUM           31
# 840        31.0    OCO        MEDIUM           31
# 841        32.0    OCO          HARD           31
# 842        33.0    OCO          HARD           31
# 843        34.0    OCO          HARD           31
# 844        35.0    OCO          HARD           31
# 845        36.0    OCO          HARD           31
# 846        37.0    OCO          HARD           31
# 847        38.0    OCO          HARD           31
# 848        39.0    OCO          HARD           31
# 849        40.0    OCO          HARD           31
# 850        41.0    OCO          HARD           31
# 851        42.0    OCO          HARD           31
# 852        43.0    OCO          HARD           31
# 853        44.0    OCO          HARD           31
# 854        45.0    OCO          HARD           31
# 855        46.0    OCO          HARD           31
# 856        47.0    OCO          HARD           31
# 857        48.0    OCO          HARD           31
# 858        49.0    OCO          HARD           31
# 859        50.0    OCO          HARD           31
# 860        51.0    OCO          HARD           31
# 861        52.0    OCO          HARD           31
# 862        53.0    OCO          HARD           31
# 863        54.0    OCO          HARD           31
# 864        55.0    OCO          HARD           31
# 865         1.0    LAT          SOFT            6
# 866         2.0    LAT          SOFT            6
# 867         3.0    LAT          SOFT            6
# 868         4.0    LAT          SOFT            6
# 869         5.0    LAT          SOFT            6
# 870         6.0    LAT          SOFT            6
# 871         7.0    LAT          SOFT            6
# 872         8.0    LAT          SOFT            6
# 873         9.0    LAT          SOFT            6
# 874        10.0    LAT          SOFT            6
# 875        11.0    LAT          SOFT            6
# 876        12.0    LAT          SOFT            6
# 877        13.0    LAT          SOFT            6
# 878        14.0    LAT          SOFT            6
# 879        15.0    LAT        MEDIUM            6
# 880        16.0    LAT        MEDIUM            6
# 881        17.0    LAT        MEDIUM            6
# 882        18.0    LAT        MEDIUM            6
# 883        19.0    LAT        MEDIUM            6
# 884        20.0    LAT        MEDIUM            6
# 885        21.0    LAT        MEDIUM            6
# 886        22.0    LAT        MEDIUM            6
# 887        23.0    LAT        MEDIUM            6
# 888        24.0    LAT        MEDIUM            6
# 889        25.0    LAT        MEDIUM            6
# 890        26.0    LAT        MEDIUM            6
# 891        27.0    LAT        MEDIUM            6
# 892        28.0    LAT        MEDIUM            6
# 893        29.0    LAT        MEDIUM            6
# 894        30.0    LAT        MEDIUM            6
# 895        31.0    LAT        MEDIUM            6
# 896        32.0    LAT        MEDIUM            6
# 897        33.0    LAT        MEDIUM            6
# 898        34.0    LAT        MEDIUM            6
# 899        35.0    LAT        MEDIUM            6
# 900        36.0    LAT        MEDIUM            6
# 901        37.0    LAT        MEDIUM            6
# 902        38.0    LAT        MEDIUM            6
# 903        39.0    LAT        MEDIUM            6
# 904        40.0    LAT        MEDIUM            6
# 905        41.0    LAT        MEDIUM            6
# 906        42.0    LAT        MEDIUM            6
# 907        43.0    LAT        MEDIUM            6
# 908        44.0    LAT        MEDIUM            6
# 909        45.0    LAT        MEDIUM            6
# 910        46.0    LAT        MEDIUM            6
# 911        47.0    LAT        MEDIUM            6
# 912        48.0    LAT        MEDIUM            6
# 913        49.0    LAT        MEDIUM            6
# 914        50.0    LAT        MEDIUM            6
# 915        51.0    LAT        MEDIUM            6
# 916         1.0    MSC        MEDIUM           47
# 917         2.0    MSC        MEDIUM           47
# 918         3.0    MSC        MEDIUM           47
# 919         4.0    MSC        MEDIUM           47
# 920         5.0    MSC        MEDIUM           47
# 921         6.0    MSC        MEDIUM           47
# 922         7.0    MSC        MEDIUM           47
# 923         8.0    MSC        MEDIUM           47
# 924         9.0    MSC        MEDIUM           47
# 925        10.0    MSC        MEDIUM           47
# 926        11.0    MSC        MEDIUM           47
# 927        12.0    MSC        MEDIUM           47
# 928        13.0    MSC        MEDIUM           47
# 929        14.0    MSC        MEDIUM           47
# 930        15.0    MSC        MEDIUM           47
# 931        16.0    MSC        MEDIUM           47
# 932        17.0    MSC        MEDIUM           47
# 933        18.0    MSC        MEDIUM           47
# 934        19.0    MSC        MEDIUM           47
# 935        20.0    MSC        MEDIUM           47
# 936        21.0    MSC        MEDIUM           47
# 937        22.0    MSC        MEDIUM           47
# 938        23.0    MSC        MEDIUM           47
# 939        24.0    MSC        MEDIUM           47
# 940        25.0    MSC        MEDIUM           47
# 941        26.0    MSC        MEDIUM           47
# 942        27.0    MSC        MEDIUM           47
# 943        28.0    MSC        MEDIUM           47
# 944        29.0    MSC        MEDIUM           47
# 945        30.0    MSC        MEDIUM           47
# 946        31.0    MSC        MEDIUM           47
# 947        32.0    MSC        MEDIUM           47
# 948        33.0    MSC        MEDIUM           47
# 949        34.0    MSC          HARD           47
# 950        35.0    MSC          HARD           47
# 951        36.0    MSC          HARD           47
# 952        37.0    MSC          HARD           47
# 953        38.0    MSC          HARD           47
# 954        39.0    MSC          HARD           47
# 955        40.0    MSC          HARD           47
# 956        41.0    MSC          HARD           47
# 957        42.0    MSC          HARD           47
# 958        43.0    MSC          HARD           47
# ...
# 807        54.0    ALO        MEDIUM           14
# 808        55.0    ALO        MEDIUM           14
# 809        56.0    ALO        MEDIUM           14
# 810        57.0    ALO        MEDIUM           14
# 811        58.0    ALO        MEDIUM           14
# 812        59.0    ALO        MEDIUM           14
# 813        60.0    ALO        MEDIUM           14
# 814        61.0    ALO        MEDIUM           14
# 815        62.0    ALO        MEDIUM           14
# 816        63.0    ALO        MEDIUM           14
# 817         1.0    RAI  INTERMEDIATE            7
# 818         2.0    RAI  INTERMEDIATE            7
# 819         3.0    RAI  INTERMEDIATE            7
# 820         4.0    RAI  INTERMEDIATE            7
# 821         5.0    RAI  INTERMEDIATE            7
# 822         6.0    RAI  INTERMEDIATE            7
# 823         7.0    RAI  INTERMEDIATE            7
# 824         8.0    RAI  INTERMEDIATE            7
# 825         9.0    RAI  INTERMEDIATE            7
# 826        10.0    RAI  INTERMEDIATE            7
# 827        11.0    RAI  INTERMEDIATE            7
# 828        12.0    RAI  INTERMEDIATE            7
# 829        13.0    RAI  INTERMEDIATE            7
# 830        14.0    RAI  INTERMEDIATE            7
# 831        15.0    RAI  INTERMEDIATE            7
# 832        16.0    RAI  INTERMEDIATE            7
# 833        17.0    RAI  INTERMEDIATE            7
# 834        18.0    RAI  INTERMEDIATE            7
# 835        19.0    RAI  INTERMEDIATE            7
# 836        20.0    RAI  INTERMEDIATE            7
# 837        21.0    RAI  INTERMEDIATE            7
# 838        22.0    RAI  INTERMEDIATE            7
# 839        23.0    RAI  INTERMEDIATE            7
# 840        24.0    RAI  INTERMEDIATE            7
# 841        25.0    RAI  INTERMEDIATE            7
# 842        26.0    RAI  INTERMEDIATE            7
# 843        27.0    RAI        MEDIUM            7
# 844        28.0    RAI        MEDIUM            7
# 845        29.0    RAI        MEDIUM            7
# 846        30.0    RAI        MEDIUM            7
# 847        31.0    RAI        MEDIUM            7
# 848        32.0    RAI        MEDIUM            7
# 849        33.0    RAI        MEDIUM            7
# 850        34.0    RAI       UNKNOWN            7
# 851        35.0    RAI       UNKNOWN            7
# 852        36.0    RAI        MEDIUM            7
# 853        37.0    RAI        MEDIUM            7
# 854        38.0    RAI        MEDIUM            7
# 855        39.0    RAI        MEDIUM            7
# 856        40.0    RAI        MEDIUM            7
# 857        41.0    RAI        MEDIUM            7
# 858        42.0    RAI        MEDIUM            7
# 859        43.0    RAI        MEDIUM            7
# 860        44.0    RAI        MEDIUM            7
# 861        45.0    RAI        MEDIUM            7
# 862        46.0    RAI        MEDIUM            7
# 863        47.0    RAI        MEDIUM            7
# 864        48.0    RAI        MEDIUM            7
# 865        49.0    RAI        MEDIUM            7
# 866        50.0    RAI        MEDIUM            7
# 867        51.0    RAI        MEDIUM            7
# 868        52.0    RAI        MEDIUM            7
# 869        53.0    RAI        MEDIUM            7
# 870        54.0    RAI        MEDIUM            7
# 871        55.0    RAI        MEDIUM            7
# 872        56.0    RAI        MEDIUM            7
# 873        57.0    RAI        MEDIUM            7
# 874        58.0    RAI        MEDIUM            7
# 875        59.0    RAI        MEDIUM            7
# 876        60.0    RAI        MEDIUM            7
# 877        61.0    RAI        MEDIUM            7
# 878        62.0    RAI        MEDIUM            7
# 879        63.0    RAI        MEDIUM            7
# 880         1.0    GIO  INTERMEDIATE           99
# 881         2.0    GIO  INTERMEDIATE           99
# 882         3.0    GIO  INTERMEDIATE           99
# 883         4.0    GIO  INTERMEDIATE           99
# 884         5.0    GIO  INTERMEDIATE           99
# 885         6.0    GIO  INTERMEDIATE           99
# 886         7.0    GIO  INTERMEDIATE           99
# 887         8.0    GIO  INTERMEDIATE           99
# 888         9.0    GIO  INTERMEDIATE           99
# 889        10.0    GIO  INTERMEDIATE           99
# 890        11.0    GIO  INTERMEDIATE           99
# 891        12.0    GIO  INTERMEDIATE           99
# 892        13.0    GIO  INTERMEDIATE           99
# 893        14.0    GIO  INTERMEDIATE           99
# 894        15.0    GIO  INTERMEDIATE           99
# 895        16.0    GIO  INTERMEDIATE           99
# 896        17.0    GIO  INTERMEDIATE           99
# 897        18.0    GIO  INTERMEDIATE           99
# 898        19.0    GIO  INTERMEDIATE           99
# 899        20.0    GIO  INTERMEDIATE           99
# 900        21.0    GIO  INTERMEDIATE           99
# 901        22.0    GIO  INTERMEDIATE           99
# 902        23.0    GIO  INTERMEDIATE           99
# 903        24.0    GIO  INTERMEDIATE           99
# 904        25.0    GIO  INTERMEDIATE           99
# 905        26.0    GIO  INTERMEDIATE           99
# 906        27.0    GIO  INTERMEDIATE           99
# 907        28.0    GIO        MEDIUM           99
# 908        29.0    GIO        MEDIUM           99
# 909        30.0    GIO        MEDIUM           99
# 910        31.0    GIO        MEDIUM           99
# 911        32.0    GIO        MEDIUM           99
# 912        33.0    GIO        MEDIUM           99
# 913        34.0    GIO       UNKNOWN           99
# 914        35.0    GIO       UNKNOWN           99
# 915        36.0    GIO        MEDIUM           99
# 916        37.0    GIO        MEDIUM           99
# 917        38.0    GIO        MEDIUM           99
# 918        39.0    GIO        MEDIUM           99
# 919        40.0    GIO        MEDIUM           99
# 920        41.0    GIO        MEDIUM           99
# 921        42.0    GIO        MEDIUM           99
# 922        43.0    GIO        MEDIUM           99
# 923        44.0    GIO        MEDIUM           99
# 924        45.0    GIO        MEDIUM           99
# 925        46.0    GIO        MEDIUM           99
# 926        47.0    GIO        MEDIUM           99
# 927        48.0    GIO        MEDIUM           99
# 928        49.0    GIO        MEDIUM           99
# 929        50.0    GIO        MEDIUM           99
# 930        51.0    GIO        MEDIUM           99
# 931        52.0    GIO        MEDIUM           99
# 932        53.0    GIO        MEDIUM           99
# 933        54.0    GIO        MEDIUM           99
# 934        55.0    GIO        MEDIUM           99
# 935        56.0    GIO        MEDIUM           99
# 936        57.0    GIO        MEDIUM           99
# 937        58.0    GIO        MEDIUM           99
# 938        59.0    GIO        MEDIUM           99
# 939        60.0    GIO        MEDIUM           99
# 940        61.0    GIO        MEDIUM           99
# 941        62.0    GIO        MEDIUM           99
# 942         1.0    MSC           WET           47
# 943         2.0    MSC           WET           47
# 944         3.0    MSC           WET           47
# 945         4.0    MSC           WET           47
# 946         5.0    MSC           WET           47
# 947         6.0    MSC  INTERMEDIATE           47
# 948         7.0    MSC  INTERMEDIATE           47
# 949         8.0    MSC  INTERMEDIATE           47
# 950         9.0    MSC  INTERMEDIATE           47
# 951        10.0    MSC  INTERMEDIATE           47
# 952        11.0    MSC  INTERMEDIATE           47
# 953        12.0    MSC  INTERMEDIATE           47
# 954        13.0    MSC  INTERMEDIATE           47
# 955        14.0    MSC  INTERMEDIATE           47
# 956        15.0    MSC  INTERMEDIATE           47
# 957        16.0    MSC  INTERMEDIATE           47
# 958        17.0    MSC  INTERMEDIATE           47
# 959        18.0    MSC  INTERMEDIATE           47
# 960        19.0    MSC  INTERMEDIATE           47
# 961        20.0    MSC  INTERMEDIATE           47
# 962        21.0    MSC  INTERMEDIATE           47
# 963        22.0    MSC          SOFT           47
# 964        23.0    MSC          SOFT           47
# 965        24.0    MSC          SOFT           47
# 966        25.0    MSC          SOFT           47
# 967        26.0    MSC          SOFT           47
# 968        27.0    MSC          SOFT           47
# 969        28.0    MSC          SOFT           47
# 970        29.0    MSC          SOFT           47
# 971        30.0    MSC          SOFT           47
# 972        31.0    MSC          SOFT           47
# 973        32.0    MSC        MEDIUM           47
# 974        33.0    MSC       UNKNOWN           47
# 975        34.0    MSC       UNKNOWN           47
# 976        35.0    MSC        MEDIUM           47
# 977        36.0    MSC        MEDIUM           47
# 978        37.0    MSC        MEDIUM           47
# 979        38.0    MSC        MEDIUM           47
# 980        39.0    MSC        MEDIUM           47
# 981        40.0    MSC        MEDIUM           47
# 982        41.0    MSC        MEDIUM           47
# 983        42.0    MSC        MEDIUM           47
# 984        43.0    MSC        MEDIUM           47
# 985        44.0    MSC        MEDIUM           47
# 986        45.0    MSC        MEDIUM           47
# 987        46.0    MSC        MEDIUM           47
# 988        47.0    MSC        MEDIUM           47
# 989        48.0    MSC        MEDIUM           47
# 990        49.0    MSC        MEDIUM           47
# 991        50.0    MSC        MEDIUM           47
# 992        51.0    MSC        MEDIUM           47
# 993        52.0    MSC        MEDIUM           47
# 994        53.0    MSC        MEDIUM           47
# 995        54.0    MSC        MEDIUM           47
# 996        55.0    MSC        MEDIUM           47
# 997        56.0    MSC        MEDIUM           47
# 998        57.0    MSC        MEDIUM           47
# 999        58.0    MSC        MEDIUM           47
# 1000       59.0    MSC        MEDIUM           47
# 1001       60.0    MSC        MEDIUM           47
# 1002       61.0    MSC        MEDIUM           47
# 1003        1.0    MAZ           WET            9
# 1004        2.0    MAZ           WET            9
# 1005        3.0    MAZ           WET            9
# 1006        4.0    MAZ           WET            9
# 1007        5.0    MAZ           WET            9
# 1008        6.0    MAZ           WET            9
# 1009        7.0    MAZ           WET            9
# 1010        8.0    MAZ           WET            9
# 1011        9.0    MAZ           WET            9
# 1012       10.0    MAZ           WET            9
# 1013       11.0    MAZ           WET            9
# 1014       12.0    MAZ           WET            9
# 1015       13.0    MAZ  INTERMEDIATE            9
# 1016       14.0    MAZ  INTERMEDIATE            9
# 1017       15.0    MAZ  INTERMEDIATE            9
# 1018       16.0    MAZ  INTERMEDIATE            9
# 1019       17.0    MAZ  INTERMEDIATE            9
# 1020       18.0    MAZ  INTERMEDIATE            9
# 1021       19.0    MAZ  INTERMEDIATE            9
# 1022       20.0    MAZ  INTERMEDIATE            9
# 1023       21.0    MAZ  INTERMEDIATE            9
# 1024       22.0    MAZ  INTERMEDIATE            9
# 1025       23.0    MAZ  INTERMEDIATE            9
# 1026       24.0    MAZ          SOFT            9
# 1027       25.0    MAZ          SOFT            9
# 1028       26.0    MAZ          SOFT            9
# 1029       27.0    MAZ          SOFT            9
# 1030       28.0    MAZ          SOFT            9
# 1031       29.0    MAZ          SOFT            9
# 1032       30.0    MAZ          SOFT            9
# 1033       31.0    MAZ          SOFT            9
# 1034       32.0    MAZ        MEDIUM            9
# 1035       33.0    MAZ       UNKNOWN            9
# 1036       34.0    MAZ       UNKNOWN            9
# 1037       35.0    MAZ        MEDIUM            9
# 1038       36.0    MAZ        MEDIUM            9
# 1039       37.0    MAZ        MEDIUM            9
# 1040       38.0    MAZ        MEDIUM            9
# 1041       39.0    MAZ        MEDIUM            9
# 1042       40.0    MAZ        MEDIUM            9
# 1043       41.0    MAZ        MEDIUM            9
# 1044       42.0    MAZ        MEDIUM            9
# 1045       43.0    MAZ        MEDIUM            9
# 1046       44.0    MAZ        MEDIUM            9
# 1047       45.0    MAZ        MEDIUM            9
# 1048       46.0    MAZ        MEDIUM            9
# 1049       47.0    MAZ        MEDIUM            9
# 1050       48.0    MAZ        MEDIUM            9
# 1051       49.0    MAZ        MEDIUM            9
# 1052       50.0    MAZ        MEDIUM            9
# 1053       51.0    MAZ        MEDIUM            9
# 1054       52.0    MAZ        MEDIUM            9
# 1055       53.0    MAZ        MEDIUM            9
# 1056       54.0    MAZ        MEDIUM            9
# 1057       55.0    MAZ        MEDIUM            9
# 1058       56.0    MAZ        MEDIUM            9
# 1059       57.0    MAZ        MEDIUM            9
# 1060       58.0    MAZ        MEDIUM            9
# 1061       59.0    MAZ        MEDIUM            9
# 1062       60.0    MAZ        MEDIUM            9
# 1063       61.0    MAZ        MEDIUM            9
# 1064        1.0    TSU  INTERMEDIATE           22
# 1065        2.0    TSU  INTERMEDIATE           22
# 1066        3.0    TSU  INTERMEDIATE           22
# 1067        4.0    TSU  INTERMEDIATE           22
# 1068        5.0    TSU  INTERMEDIATE           22
# 1069        6.0    TSU  INTERMEDIATE           22
# 1070        7.0    TSU  INTERMEDIATE           22
# 1071        8.0    TSU  INTERMEDIATE           22
# 1072        9.0    TSU  INTERMEDIATE           22
# 1073       10.0    TSU  INTERMEDIATE           22
# 1074       11.0    TSU  INTERMEDIATE           22
# 1075       12.0    TSU  INTERMEDIATE           22
# 1076       13.0    TSU  INTERMEDIATE           22
# 1077       14.0    TSU  INTERMEDIATE           22
# 1078       15.0    TSU  INTERMEDIATE           22
# 1079       16.0    TSU  INTERMEDIATE           22
# 1080       17.0    TSU  INTERMEDIATE           22
# 1081       18.0    TSU  INTERMEDIATE           22
# 1082       19.0    TSU  INTERMEDIATE           22
# 1083       20.0    TSU  INTERMEDIATE           22
# 1084       21.0    TSU  INTERMEDIATE           22
# 1085       22.0    TSU  INTERMEDIATE           22
# 1086       23.0    TSU  INTERMEDIATE           22
# 1087       24.0    TSU  INTERMEDIATE           22
# 1088       25.0    TSU  INTERMEDIATE           22
# 1089       26.0    TSU        MEDIUM           22
# 1090       27.0    TSU        MEDIUM           22
# 1091       28.0    TSU        MEDIUM           22
# 1092       29.0    TSU        MEDIUM           22
# 1093       30.0    TSU        MEDIUM           22
# 1094       31.0    TSU        MEDIUM           22
# 1095       32.0    TSU        MEDIUM           22
# 1096       33.0    TSU          SOFT           22
# 1097       34.0    TSU          SOFT           22
# 1098       35.0    TSU          SOFT           22
# 1099       36.0    TSU          SOFT           22
# 1100       37.0    TSU          SOFT           22
# 1101       38.0    TSU          SOFT           22
# 1102       39.0    TSU          SOFT           22
# 1103       40.0    TSU          SOFT           22
# 1104       41.0    TSU          SOFT           22
# 1105       42.0    TSU          SOFT           22
# 1106       43.0    TSU          SOFT           22
# 1107       44.0    TSU          SOFT           22
# 1108       45.0    TSU          SOFT           22
# 1109       46.0    TSU          SOFT           22
# 1110       47.0    TSU          SOFT           22
# 1111       48.0    TSU          SOFT           22
# 1112       49.0    TSU          SOFT           22
# 1113       50.0    TSU          SOFT           22
# 1114       51.0    TSU          SOFT           22
# 1115       52.0    TSU          SOFT           22
# 1116       53.0    TSU          SOFT           22
# 1117       54.0    TSU          SOFT           22
# 1118       55.0    TSU          SOFT           22
# 1119       56.0    TSU          SOFT           22
# 1120       57.0    TSU          SOFT           22
# 1121       58.0    TSU          SOFT           22
# 1122       59.0    TSU          SOFT           22
# 1123       60.0    TSU          SOFT           22
# 1124       61.0    TSU          SOFT           22
# 1125       62.0    TSU          SOFT           22
# 1126       63.0    TSU          SOFT           22
